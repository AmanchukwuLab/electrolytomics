# %% [markdown]
# ## LGBM regression on IE dataset
# ### Using functional group features & cross validation

# %% [markdown]
# **Created on 29th August, 2022; modified on 7th September; remodified on 13th February, 2024**

# %%
import warnings
warnings.filterwarnings('ignore')
#from sklearn.preprocessing import Imputer
# from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'
import seaborn as sns
import pandas as pd
import numpy as np
#import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso, LassoCV, \
    RidgeClassifier, Ridge
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR, SVC
from sklearn.gaussian_process import GaussianProcessRegressor, GaussianProcessClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel, \
RationalQuadratic, ExpSineSquared, DotProduct
from sklearn.feature_selection import RFE
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, \
precision_score, auc
import os, sys
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
import pickle
import optuna ## hyperparameter optimization
import lightgbm as lgb
from lightgbm import LGBMRegressor
import pickle

# %%
# %%bash
# pwd
# ls -ltr
# Out:
# /Users/riteshk/Library/CloudStorage/Box-Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/oxidative-stability_1.1/lgbm_trials/random-split
# total 32064
# -rw-------@  1 riteshk  staff  3960002 Feb 13 15:13 train_fgrp_feat.csv
# -rw-------@  1 riteshk  staff   495572 Feb 13 15:13 val_fgrp_feat.csv
# -rw-------@  1 riteshk  staff   497131 Feb 13 15:13 test_fgrp_feat.csv
# -rw-------@  1 riteshk  staff   714945 Feb 13 15:14 all_oxstab.csv
# -rw-r--r--   1 riteshk  staff   625054 Feb 13 17:47 shap_lgbm_random_summary_oxstab.eps
# -rw-r--r--   1 riteshk  staff  2640307 Feb 13 17:48 shap_lgbm_random_molar_refractivity_dependence_oxstab.eps
# -rw-r--r--   1 riteshk  staff  2636871 Feb 13 17:50 shap_lgbm_random_frag_F_dependence_oxstab.eps
# -rw-------@  1 riteshk  staff   326550 Feb 13 17:50 shap_lgbm_oxstab.ipynb
# drwxr-xr-x  18 riteshk  staff      576 Feb 14 11:24 old-model_zero_columns
# -rw-r--r--   1 riteshk  staff      433 Feb 14 11:41 best-paramters_lgbr_random.txt
# -rw-r--r--   1 riteshk  staff      866 Feb 14 11:41 best-paramters_lgbr_all.txt
# -rw-r--r--   1 riteshk  staff   855975 Feb 14 11:52 lgbm_oxstab_rand_fold_1.sav
# -rw-r--r--   1 riteshk  staff   850697 Feb 14 11:52 lgbm_oxstab_rand_fold_2.sav
# -rw-r--r--   1 riteshk  staff   833814 Feb 14 11:52 lgbm_oxstab_rand_fold_3.sav
# -rw-r--r--   1 riteshk  staff   858682 Feb 14 11:52 lgbm_oxstab_rand_fold_4.sav
# -rw-r--r--   1 riteshk  staff   848980 Feb 14 11:52 lgbm_oxstab_rand_fold_5.sav
# -rw-------@  1 riteshk  staff   238584 Feb 14 11:54 oxstab_lgbm_random.ipynb

# %%
df = pd.read_csv('all_oxstab.csv')
df
# Out:
#                                   smiles        IE
# 0                        C(C#CC(C)C)(C)C  5.481535
# 1                                C(=O)=O  9.433272
# 2                                      O  7.902121
# 3                          C(=C\C)/C(C)C  5.085723
# 4                      c1(c(ccc(c1)C)C)C  4.733493
# ...                                  ...       ...
# 18128  c1cc(c2c(c1)[nH]sn2N(=O)=O)C(=O)O  3.220508
# 18129     CC(=O)c1ccc2c(c1C#N)[nH]s[nH]2  3.620069
# 18130             CCn1c2ccc(cc2[nH]s1)Cl  3.308856
# 18131           CCc1ccc2c(c1O)[nH]s[nH]2  3.476727
# 18132              COc1ccc2c(c1)[nH]sn2O  3.846236
#
# [18133 rows x 2 columns]

# %% [markdown]
# Read the train, validation, and test sets

# %%
train_df = pd.read_csv('train_fgrp_feat.csv')
val_df = pd.read_csv('val_fgrp_feat.csv')
test_df = pd.read_csv('test_fgrp_feat.csv')
train_df
# Out:
#                                     smiles  fr_func_grp_1_solv  \
# 0                           COCCOc1cscc1OC                   0
# 1                 c1c(c2c(cc1)nccn2)C(=O)O                   0
# 2                 C=Cc1cccc2c1[nH]sn2OCCOC                   0
# 3                     c1ccc(cc1)C1(CCCC1)O                   0
# 4                       C(#N)C1=COC(=CO1)N                   0
# ...                                    ...                 ...
# 14500         CC(C)(C)c1cc(C#N)c2c(c1)ONO2                   0
# 14501                          C=Cc1cscc1F                   0
# 14502                         n1c(cncc1C)C                   0
# 14503  c1ccc(cc1)[C@@H]1[C@H](C(=O)O)SCCS1                   2
# 14504                         COc1ccc(O)s1                   0
#
#        fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 14500                   0                   0                   0
# 14501                   0                   0                   0
# 14502                   0                   0                   0
# 14503                   0                   0                   0
# 14504                   0                   0                   0
#
#        fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 14500                   0                   0                   0
# 14501                   0                   0                   0
# 14502                   0                   0                   0
# 14503                   0                   0                   0
# 14504                   0                   0                   0
#
#        fr_func_grp_8_solv  fr_func_grp_9_solv  ...    clogp  \
# 0                       0                   0  ...  1.78190
# 1                       0                   0  ...  1.32800
# 2                       0                   0  ...  2.70270
# 3                       0                   0  ...  2.44820
# 4                       0                   0  ...  0.15578
# ...                   ...                 ...  ...      ...
# 14500                   0                   0  ...  2.04658
# 14501                   0                   0  ...  2.53020
# 14502                   0                   0  ...  1.09344
# 14503                   0                   0  ...  2.66090
# 14504                   0                   0  ...  1.46230
#
#        molar_refractivity   tpsa  frac_sp3  hall_kier_alpha  labute_ASA  \
# 0                 48.2420  27.69  0.500000            -0.74   75.872171
# 1                 46.4973  63.08  0.000000            -1.97   73.873062
# 2                 68.0537  33.73  0.272727            -1.17   99.445369
# 3                 48.8068  20.23  0.454545            -0.82   73.044516
# 4                 28.1364  68.27  0.000000            -1.63   51.773543
# ...                   ...    ...       ...              ...         ...
# 14500             54.2487  54.28  0.363636            -1.73   88.327892
# 14501             34.3680   0.00  0.000000            -0.63   51.277583
# 14502             31.5060  25.78  0.333333            -0.92   48.600583
# 14503             65.5228  37.30  0.363636            -0.61   97.452258
# 14504             32.5358  29.46  0.200000            -0.70   51.344487
#
#        num_valence_electron  max_partial_charge  min_partial_charge        IE
# 0                        68            0.171467           -0.491993  4.306098
# 1                        64            0.337476           -0.477581  5.330098
# 2                        86            0.103226           -0.382191  3.957699
# 3                        64            0.089612           -0.385172  5.178552
# 4                        46            0.237928           -0.445084  3.910692
# ...                     ...                 ...                 ...       ...
# 14500                    78            0.213150           -0.369549  4.638594
# 14501                    42            0.140567           -0.205425  4.756748
# 14502                    42            0.055846           -0.260951  5.327466
# 14503                    80            0.317615           -0.480376  4.915535
# 14504                    44            0.176272           -0.499379  3.737842
#
# [14505 rows x 58 columns]

# %%
df = pd.concat([train_df, val_df, test_df], axis=0, ignore_index=True)
df.reset_index(drop=True, inplace=True)
zero_columns = list(df.columns[(df == 0).all()]) ## oxstab dataset has columns with only zero entries so have to remove them, otherwise causes problem with Sobol analysis
zero_columns
# Out:
# ['fr_func_grp_6_solv',
#  'fr_func_grp_16_solv',
#  'fr_func_grp_22_solv',
#  'fr_func_grp_24_solv',
#  'fr_func_grp_26_solv',
#  'fr_func_grp_28_solv',
#  'fr_func_grp_33_solv',
#  'fr_func_grp_38_solv',
#  'fr_func_grp_41_solv']

# %%
df.drop(columns=zero_columns, inplace=True)
train_df.drop(columns=zero_columns, inplace=True)
val_df.drop(columns=zero_columns, inplace=True)
test_df.drop(columns=zero_columns, inplace=True)
df.reset_index(drop=True, inplace=True)
train_df.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
X_train = train_df.iloc[:,1:-1]
y_train = train_df.iloc[:,-1]
X_val = val_df.iloc[:,1:-1]
y_val = val_df.iloc[:,-1]
X_test = test_df.iloc[:,1:-1]
y_test = test_df.iloc[:,-1]

std_scale = preprocessing.StandardScaler().fit(X_train)
X_train_std = std_scale.transform(X_train)
X_train_std = pd.DataFrame(X_train_std, columns=X_train.columns)
X_test_std  = std_scale.transform(X_test)
X_test_std = pd.DataFrame(X_test_std, columns=X_train.columns)
X_val_std  = std_scale.transform(X_val)
X_val_std = pd.DataFrame(X_val_std, columns=X_train.columns)

X_train_ = np.array(X_train_std)
X_val_ = np.array(X_val_std)
X_test_ = np.array(X_test_std)
X_train_.shape
# Out:
# (14505, 47)

# %%
def objective(trial):
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    param = {
        "objective": "regression",
        "metric": "root_mean_squared_error",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 100),
        "num_iterations": trial.suggest_int("num_iterations", 50, 500),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "max_bin": trial.suggest_int("max_bin", 2, 50),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.1, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.1, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 5, 100),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0.1, 1.0),
        "learning_rate": trial.suggest_float("learning_rate", 1e-2, 0.9),
        "min_sum_hessian_in_leaf": trial.suggest_float("min_sum_hessian_in_leaf", 0.1, 0.9)
    }

    gbm = LGBMRegressor(**param)
    cv = cross_val_score(gbm, X_train_, y_train, cv=kf, scoring='neg_root_mean_squared_error')
    return -cv.mean()

# %%
fname = 'best-paramters_lgbr_random.txt'
f = open(fname, 'w')
f1 = open('best-paramters_lgbr_all.txt', 'a')
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=200)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))
    f.write("  Value: {}\n".format(trial.value))
    f1.write("  Value: {}\n".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value)) 
        f.write("    {}: {}\n".format(key, value))
        f1.write("    {}: {}\n".format(key, value))

f.write("\n")
f1.write("\n")
f.close()
f1.close()
# Out:
# [I 2024-02-14 11:56:38,450] A new study created in memory with name: no-name-a94f0768-cfb4-40d6-9486-e6beff84b716
# [I 2024-02-14 11:56:38,987] Trial 0 finished with value: 0.6001481381528382 and parameters: {'lambda_l1': 3.4467854578742806e-06, 'lambda_l2': 5.7549366182366186e-08, 'num_leaves': 89, 'num_iterations': 132, 'max_depth': 9, 'max_bin': 7, 'feature_fraction': 0.8067129371227151, 'bagging_fraction': 0.9124216607551318, 'bagging_freq': 1, 'min_data_in_leaf': 95, 'min_gain_to_split': 0.9208233364444045, 'learning_rate': 0.830075755337337, 'min_sum_hessian_in_leaf': 0.10883074417761751}. Best is trial 0 with value: 0.6001481381528382.
# [I 2024-02-14 11:56:41,024] Trial 1 finished with value: 0.6445171177238255 and parameters: {'lambda_l1': 1.0869125068411486e-06, 'lambda_l2': 0.002662106389632919, 'num_leaves': 5, 'num_iterations': 433, 'max_depth': 5, 'max_bin': 36, 'feature_fraction': 0.8434962344737861, 'bagging_fraction': 0.5020501049973511, 'bagging_freq': 10, 'min_data_in_leaf': 6, 'min_gain_to_split': 0.6206619490816317, 'learning_rate': 0.014280576382011278, 'min_sum_hessian_in_leaf': 0.252798887866215}. Best is trial 0 with value: 0.6001481381528382.
# [I 2024-02-14 11:56:41,646] Trial 2 finished with value: 0.5229708946255938 and parameters: {'lambda_l1': 0.7582152014875639, 'lambda_l2': 7.737039952872e-08, 'num_leaves': 32, 'num_iterations': 151, 'max_depth': 9, 'max_bin': 50, 'feature_fraction': 0.7180777985151389, 'bagging_fraction': 0.8432036000406279, 'bagging_freq': 4, 'min_data_in_leaf': 12, 'min_gain_to_split': 0.8343768408211991, 'learning_rate': 0.8944354263229449, 'min_sum_hessian_in_leaf': 0.8414910636431732}. Best is trial 2 with value: 0.5229708946255938.
# [I 2024-02-14 11:56:44,159] Trial 3 finished with value: 0.5171801227707941 and parameters: {'lambda_l1': 1.8180113738369364e-08, 'lambda_l2': 0.0008194847181257436, 'num_leaves': 47, 'num_iterations': 455, 'max_depth': 7, 'max_bin': 10, 'feature_fraction': 0.6539463803998251, 'bagging_fraction': 0.3122009920495319, 'bagging_freq': 1, 'min_data_in_leaf': 86, 'min_gain_to_split': 0.8115534154372943, 'learning_rate': 0.2357531653732429, 'min_sum_hessian_in_leaf': 0.5947584071405262}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:46,463] Trial 4 finished with value: 0.6048688140126962 and parameters: {'lambda_l1': 3.373215986582048e-08, 'lambda_l2': 0.00016992431930416948, 'num_leaves': 93, 'num_iterations': 280, 'max_depth': 9, 'max_bin': 25, 'feature_fraction': 0.8131577785155109, 'bagging_fraction': 0.26284755333144866, 'bagging_freq': 2, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.6939326922929483, 'learning_rate': 0.8493029132618118, 'min_sum_hessian_in_leaf': 0.677139663200625}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:47,393] Trial 5 finished with value: 0.7397780993613836 and parameters: {'lambda_l1': 4.748298202050739e-07, 'lambda_l2': 6.390043130128577e-07, 'num_leaves': 24, 'num_iterations': 223, 'max_depth': 4, 'max_bin': 4, 'feature_fraction': 0.1499569302833575, 'bagging_fraction': 0.8467987007286277, 'bagging_freq': 4, 'min_data_in_leaf': 98, 'min_gain_to_split': 0.9832993072213012, 'learning_rate': 0.4059165434682915, 'min_sum_hessian_in_leaf': 0.29642528123856415}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:47,912] Trial 6 finished with value: 0.5939275164872907 and parameters: {'lambda_l1': 2.626756123829996e-05, 'lambda_l2': 4.7945010007777385e-05, 'num_leaves': 78, 'num_iterations': 56, 'max_depth': 4, 'max_bin': 28, 'feature_fraction': 0.5511888325030544, 'bagging_fraction': 0.28435930743085963, 'bagging_freq': 7, 'min_data_in_leaf': 75, 'min_gain_to_split': 0.9389225182889187, 'learning_rate': 0.10880260283948534, 'min_sum_hessian_in_leaf': 0.7646873098565724}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:48,961] Trial 7 finished with value: 0.5534838061428522 and parameters: {'lambda_l1': 3.515135730696804, 'lambda_l2': 0.021618992769519604, 'num_leaves': 36, 'num_iterations': 337, 'max_depth': 5, 'max_bin': 29, 'feature_fraction': 0.29428616527318646, 'bagging_fraction': 0.43069265396125034, 'bagging_freq': 5, 'min_data_in_leaf': 88, 'min_gain_to_split': 0.6383513706151189, 'learning_rate': 0.8981269646446935, 'min_sum_hessian_in_leaf': 0.8058525348602941}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:49,762] Trial 8 finished with value: 0.5652938339184929 and parameters: {'lambda_l1': 0.2838704155866398, 'lambda_l2': 2.3678561631320467, 'num_leaves': 93, 'num_iterations': 310, 'max_depth': 5, 'max_bin': 20, 'feature_fraction': 0.708538470064501, 'bagging_fraction': 0.17849371910777026, 'bagging_freq': 7, 'min_data_in_leaf': 95, 'min_gain_to_split': 0.45425194590218543, 'learning_rate': 0.653557684680051, 'min_sum_hessian_in_leaf': 0.6695739815496311}. Best is trial 3 with value: 0.5171801227707941.
# [I 2024-02-14 11:56:51,839] Trial 9 finished with value: 0.4767720256411426 and parameters: {'lambda_l1': 1.8688007139834888e-05, 'lambda_l2': 8.41962906706339e-06, 'num_leaves': 68, 'num_iterations': 440, 'max_depth': 9, 'max_bin': 15, 'feature_fraction': 0.43250427263172614, 'bagging_fraction': 0.9148243577074576, 'bagging_freq': 3, 'min_data_in_leaf': 36, 'min_gain_to_split': 0.5904605260169045, 'learning_rate': 0.32074610056132696, 'min_sum_hessian_in_leaf': 0.2198989657063958}. Best is trial 9 with value: 0.4767720256411426.
# [I 2024-02-14 11:56:53,629] Trial 10 finished with value: 0.5145348828217859 and parameters: {'lambda_l1': 0.0011803846296110977, 'lambda_l2': 5.823563117424206e-06, 'num_leaves': 67, 'num_iterations': 404, 'max_depth': 2, 'max_bin': 13, 'feature_fraction': 0.40876288278130724, 'bagging_fraction': 0.6910274791304873, 'bagging_freq': 3, 'min_data_in_leaf': 42, 'min_gain_to_split': 0.221038578004713, 'learning_rate': 0.3357086534211593, 'min_sum_hessian_in_leaf': 0.45151728079329234}. Best is trial 9 with value: 0.4767720256411426.
# [I 2024-02-14 11:56:55,804] Trial 11 finished with value: 0.4957760973707258 and parameters: {'lambda_l1': 0.001538949689928869, 'lambda_l2': 3.0405090403592996e-06, 'num_leaves': 71, 'num_iterations': 495, 'max_depth': 2, 'max_bin': 15, 'feature_fraction': 0.414114234746405, 'bagging_fraction': 0.6610201209648847, 'bagging_freq': 3, 'min_data_in_leaf': 42, 'min_gain_to_split': 0.15647313013883388, 'learning_rate': 0.3692813655006133, 'min_sum_hessian_in_leaf': 0.4350196627149785}. Best is trial 9 with value: 0.4767720256411426.
# [I 2024-02-14 11:56:57,537] Trial 12 finished with value: 0.48915053989954516 and parameters: {'lambda_l1': 0.0011211966684931255, 'lambda_l2': 2.8166118084557168e-06, 'num_leaves': 66, 'num_iterations': 497, 'max_depth': 7, 'max_bin': 17, 'feature_fraction': 0.4170912822882054, 'bagging_fraction': 0.9992027594355983, 'bagging_freq': 6, 'min_data_in_leaf': 58, 'min_gain_to_split': 0.42566374798630124, 'learning_rate': 0.5142754091940376, 'min_sum_hessian_in_leaf': 0.4141696148279313}. Best is trial 9 with value: 0.4767720256411426.
# [I 2024-02-14 11:56:58,974] Trial 13 finished with value: 0.47909891533760973 and parameters: {'lambda_l1': 0.0001131668721576324, 'lambda_l2': 1.8463605798566674e-08, 'num_leaves': 58, 'num_iterations': 383, 'max_depth': 7, 'max_bin': 19, 'feature_fraction': 0.48736193243107895, 'bagging_fraction': 0.9844919082456083, 'bagging_freq': 7, 'min_data_in_leaf': 62, 'min_gain_to_split': 0.42704192561880444, 'learning_rate': 0.5289605966095726, 'min_sum_hessian_in_leaf': 0.3335378597741503}. Best is trial 9 with value: 0.4767720256411426.
# [I 2024-02-14 11:57:00,027] Trial 14 finished with value: 0.47117609331634946 and parameters: {'lambda_l1': 4.930418218137196e-05, 'lambda_l2': 2.5366142283426554e-08, 'num_leaves': 54, 'num_iterations': 374, 'max_depth': 10, 'max_bin': 22, 'feature_fraction': 0.9715197099304662, 'bagging_fraction': 0.9746621494871298, 'bagging_freq': 10, 'min_data_in_leaf': 62, 'min_gain_to_split': 0.5033526265918109, 'learning_rate': 0.5364221650759325, 'min_sum_hessian_in_leaf': 0.2946858743433822}. Best is trial 14 with value: 0.47117609331634946.
# [I 2024-02-14 11:57:00,987] Trial 15 finished with value: 0.47527281997707205 and parameters: {'lambda_l1': 1.5984650427350575e-05, 'lambda_l2': 1.4566642362561656e-08, 'num_leaves': 50, 'num_iterations': 360, 'max_depth': 10, 'max_bin': 36, 'feature_fraction': 0.9390960158459574, 'bagging_fraction': 0.7624995710039488, 'bagging_freq': 10, 'min_data_in_leaf': 26, 'min_gain_to_split': 0.5316584560197998, 'learning_rate': 0.6093366433015992, 'min_sum_hessian_in_leaf': 0.1907159545459433}. Best is trial 14 with value: 0.47117609331634946.
# [I 2024-02-14 11:57:01,982] Trial 16 finished with value: 0.48415706188441343 and parameters: {'lambda_l1': 0.012312524883036585, 'lambda_l2': 1.255971623711994e-08, 'num_leaves': 49, 'num_iterations': 361, 'max_depth': 10, 'max_bin': 38, 'feature_fraction': 0.9728095701301896, 'bagging_fraction': 0.7460528938769103, 'bagging_freq': 10, 'min_data_in_leaf': 21, 'min_gain_to_split': 0.5223154197363785, 'learning_rate': 0.6346982737216272, 'min_sum_hessian_in_leaf': 0.1148382883038484}. Best is trial 14 with value: 0.47117609331634946.
# [I 2024-02-14 11:57:02,832] Trial 17 finished with value: 0.4678579161472916 and parameters: {'lambda_l1': 0.00010894136282621602, 'lambda_l2': 1.9055090828375223e-07, 'num_leaves': 13, 'num_iterations': 218, 'max_depth': 10, 'max_bin': 40, 'feature_fraction': 0.9837252333967552, 'bagging_fraction': 0.6079024177595023, 'bagging_freq': 9, 'min_data_in_leaf': 25, 'min_gain_to_split': 0.31542440287598883, 'learning_rate': 0.6596973706023022, 'min_sum_hessian_in_leaf': 0.20655782344817353}. Best is trial 17 with value: 0.4678579161472916.
# [I 2024-02-14 11:57:03,810] Trial 18 finished with value: 0.47112818305994963 and parameters: {'lambda_l1': 0.00016469510167438714, 'lambda_l2': 3.7689343266451846e-07, 'num_leaves': 6, 'num_iterations': 224, 'max_depth': 8, 'max_bin': 48, 'feature_fraction': 0.9823755698765916, 'bagging_fraction': 0.6028910679301727, 'bagging_freq': 9, 'min_data_in_leaf': 70, 'min_gain_to_split': 0.30022544335670037, 'learning_rate': 0.7516626544177597, 'min_sum_hessian_in_leaf': 0.348969075696435}. Best is trial 17 with value: 0.4678579161472916.
# [I 2024-02-14 11:57:04,705] Trial 19 finished with value: 0.47365638379566677 and parameters: {'lambda_l1': 0.020149933774371753, 'lambda_l2': 2.518880586891292e-07, 'num_leaves': 4, 'num_iterations': 218, 'max_depth': 8, 'max_bin': 44, 'feature_fraction': 0.875765043265886, 'bagging_fraction': 0.5766000789469112, 'bagging_freq': 8, 'min_data_in_leaf': 77, 'min_gain_to_split': 0.29396913305461486, 'learning_rate': 0.7357161590594917, 'min_sum_hessian_in_leaf': 0.37458511132301153}. Best is trial 17 with value: 0.4678579161472916.
# [I 2024-02-14 11:57:05,536] Trial 20 finished with value: 0.4833609340116075 and parameters: {'lambda_l1': 0.0002889305707459394, 'lambda_l2': 3.47807230678659e-07, 'num_leaves': 15, 'num_iterations': 210, 'max_depth': 8, 'max_bin': 50, 'feature_fraction': 0.9846696066237777, 'bagging_fraction': 0.5706037586580591, 'bagging_freq': 9, 'min_data_in_leaf': 73, 'min_gain_to_split': 0.3307009750490345, 'learning_rate': 0.7466858518581121, 'min_sum_hessian_in_leaf': 0.4854166322259809}. Best is trial 17 with value: 0.4678579161472916.
# [I 2024-02-14 11:57:07,353] Trial 21 finished with value: 0.4228050499282473 and parameters: {'lambda_l1': 0.00010968791476956039, 'lambda_l2': 1.5949886886839042e-07, 'num_leaves': 16, 'num_iterations': 262, 'max_depth': 10, 'max_bin': 43, 'feature_fraction': 0.9825657342198534, 'bagging_fraction': 0.6308707769765339, 'bagging_freq': 9, 'min_data_in_leaf': 65, 'min_gain_to_split': 0.10299340470408971, 'learning_rate': 0.5133445944781962, 'min_sum_hessian_in_leaf': 0.3204978286884052}. Best is trial 21 with value: 0.4228050499282473.
# [I 2024-02-14 11:57:09,130] Trial 22 finished with value: 0.4389663124855693 and parameters: {'lambda_l1': 0.00016001714384658616, 'lambda_l2': 4.7342847034931764e-07, 'num_leaves': 16, 'num_iterations': 257, 'max_depth': 8, 'max_bin': 43, 'feature_fraction': 0.9059741364604699, 'bagging_fraction': 0.6155099808692874, 'bagging_freq': 8, 'min_data_in_leaf': 51, 'min_gain_to_split': 0.11810311833651066, 'learning_rate': 0.7225086339020703, 'min_sum_hessian_in_leaf': 0.37955588073057484}. Best is trial 21 with value: 0.4228050499282473.
# [I 2024-02-14 11:57:11,175] Trial 23 finished with value: 0.42004619589867387 and parameters: {'lambda_l1': 4.663376401687111e-06, 'lambda_l2': 1.6396853987774027e-07, 'num_leaves': 18, 'num_iterations': 271, 'max_depth': 10, 'max_bin': 41, 'feature_fraction': 0.8982423124798133, 'bagging_fraction': 0.4905733066881069, 'bagging_freq': 8, 'min_data_in_leaf': 51, 'min_gain_to_split': 0.10098429114262976, 'learning_rate': 0.476002999038492, 'min_sum_hessian_in_leaf': 0.3777615949375938}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:13,347] Trial 24 finished with value: 0.42957907877589097 and parameters: {'lambda_l1': 2.58725956864218e-06, 'lambda_l2': 1.1597797055027717e-06, 'num_leaves': 23, 'num_iterations': 279, 'max_depth': 8, 'max_bin': 44, 'feature_fraction': 0.8879039427786363, 'bagging_fraction': 0.4315590323934342, 'bagging_freq': 8, 'min_data_in_leaf': 50, 'min_gain_to_split': 0.11275198015554219, 'learning_rate': 0.46364735974879256, 'min_sum_hessian_in_leaf': 0.527804411853322}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:15,618] Trial 25 finished with value: 0.4245902272437097 and parameters: {'lambda_l1': 4.225930832142816e-06, 'lambda_l2': 1.4986816926677201e-06, 'num_leaves': 27, 'num_iterations': 297, 'max_depth': 9, 'max_bin': 33, 'feature_fraction': 0.8930201246657914, 'bagging_fraction': 0.44912902940670024, 'bagging_freq': 8, 'min_data_in_leaf': 51, 'min_gain_to_split': 0.10390266423757971, 'learning_rate': 0.44901197072778776, 'min_sum_hessian_in_leaf': 0.5177328160735757}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:17,203] Trial 26 finished with value: 0.4491661577105126 and parameters: {'lambda_l1': 2.0970434270717918e-07, 'lambda_l2': 1.954328255988437e-05, 'num_leaves': 36, 'num_iterations': 314, 'max_depth': 10, 'max_bin': 33, 'feature_fraction': 0.7844381291527367, 'bagging_fraction': 0.5001071933211896, 'bagging_freq': 6, 'min_data_in_leaf': 57, 'min_gain_to_split': 0.2198744422144402, 'learning_rate': 0.428799129498905, 'min_sum_hessian_in_leaf': 0.5299348024676218}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:18,355] Trial 27 finished with value: 0.45808706903768676 and parameters: {'lambda_l1': 5.372531345190144e-06, 'lambda_l2': 9.324558696696915e-08, 'num_leaves': 26, 'num_iterations': 168, 'max_depth': 9, 'max_bin': 32, 'feature_fraction': 0.883867108610992, 'bagging_fraction': 0.4074256396365199, 'bagging_freq': 8, 'min_data_in_leaf': 66, 'min_gain_to_split': 0.18001888368078522, 'learning_rate': 0.47016224825240516, 'min_sum_hessian_in_leaf': 0.48118862702544607}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:20,153] Trial 28 finished with value: 0.44084994925671894 and parameters: {'lambda_l1': 1.2186696313342824e-07, 'lambda_l2': 2.9455713642745705e-06, 'num_leaves': 39, 'num_iterations': 257, 'max_depth': 10, 'max_bin': 41, 'feature_fraction': 0.9141367010304828, 'bagging_fraction': 0.4891065767178822, 'bagging_freq': 9, 'min_data_in_leaf': 47, 'min_gain_to_split': 0.12796380665920262, 'learning_rate': 0.5383309306518396, 'min_sum_hessian_in_leaf': 0.3934386515106193}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:23,259] Trial 29 finished with value: 0.44948865666067955 and parameters: {'lambda_l1': 3.294034268178784e-06, 'lambda_l2': 6.845022785904306e-08, 'num_leaves': 28, 'num_iterations': 314, 'max_depth': 9, 'max_bin': 46, 'feature_fraction': 0.7728876064946055, 'bagging_fraction': 0.3787343349351067, 'bagging_freq': 7, 'min_data_in_leaf': 34, 'min_gain_to_split': 0.10354397469913919, 'learning_rate': 0.5631358518307729, 'min_sum_hessian_in_leaf': 0.31014917494026956}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:24,405] Trial 30 finished with value: 0.4445945334942799 and parameters: {'lambda_l1': 9.58668624530958e-07, 'lambda_l2': 6.339451912024774e-08, 'num_leaves': 20, 'num_iterations': 110, 'max_depth': 6, 'max_bin': 33, 'feature_fraction': 0.8362678677053299, 'bagging_fraction': 0.5344058383272271, 'bagging_freq': 6, 'min_data_in_leaf': 57, 'min_gain_to_split': 0.19981260038817933, 'learning_rate': 0.4693257822822992, 'min_sum_hessian_in_leaf': 0.42202728623540753}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:26,764] Trial 31 finished with value: 0.4247339166074194 and parameters: {'lambda_l1': 4.504525787532556e-06, 'lambda_l2': 1.7713764113300565e-06, 'num_leaves': 12, 'num_iterations': 288, 'max_depth': 8, 'max_bin': 43, 'feature_fraction': 0.9061194483934945, 'bagging_fraction': 0.4482119919843829, 'bagging_freq': 8, 'min_data_in_leaf': 49, 'min_gain_to_split': 0.10808899256851556, 'learning_rate': 0.4730689881549439, 'min_sum_hessian_in_leaf': 0.5353191423519357}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:28,522] Trial 32 finished with value: 0.4291543535008798 and parameters: {'lambda_l1': 7.552768171990813e-06, 'lambda_l2': 1.426058133334952e-06, 'num_leaves': 10, 'num_iterations': 254, 'max_depth': 9, 'max_bin': 38, 'feature_fraction': 0.8432206509457346, 'bagging_fraction': 0.4800228294671019, 'bagging_freq': 8, 'min_data_in_leaf': 45, 'min_gain_to_split': 0.1652232720629857, 'learning_rate': 0.41349206179943254, 'min_sum_hessian_in_leaf': 0.5703525730629498}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:29,461] Trial 33 finished with value: 0.46157819681958 and parameters: {'lambda_l1': 2.0194522851120666e-06, 'lambda_l2': 9.719255908954848e-07, 'num_leaves': 9, 'num_iterations': 183, 'max_depth': 9, 'max_bin': 41, 'feature_fraction': 0.8932375124153047, 'bagging_fraction': 0.5168098800362093, 'bagging_freq': 9, 'min_data_in_leaf': 55, 'min_gain_to_split': 0.24360426195539164, 'learning_rate': 0.5834527119140543, 'min_sum_hessian_in_leaf': 0.47928715551186685}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:30,929] Trial 34 finished with value: 0.45279274833257765 and parameters: {'lambda_l1': 1.2774937494889448e-05, 'lambda_l2': 1.3013153381423257e-07, 'num_leaves': 20, 'num_iterations': 290, 'max_depth': 10, 'max_bin': 36, 'feature_fraction': 0.9392847524881072, 'bagging_fraction': 0.3673785983993564, 'bagging_freq': 7, 'min_data_in_leaf': 66, 'min_gain_to_split': 0.17171338407014564, 'learning_rate': 0.49842854739315107, 'min_sum_hessian_in_leaf': 0.3620541002044514}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:32,378] Trial 35 finished with value: 0.45563134039702485 and parameters: {'lambda_l1': 7.885958283292126e-07, 'lambda_l2': 2.820108462854466e-05, 'num_leaves': 29, 'num_iterations': 328, 'max_depth': 7, 'max_bin': 47, 'feature_fraction': 0.7605027108121729, 'bagging_fraction': 0.46566188483047777, 'bagging_freq': 5, 'min_data_in_leaf': 32, 'min_gain_to_split': 0.2505462216824668, 'learning_rate': 0.5815503879841483, 'min_sum_hessian_in_leaf': 0.5971065120103007}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:34,606] Trial 36 finished with value: 0.42094906630902995 and parameters: {'lambda_l1': 4.569494086648926e-05, 'lambda_l2': 3.420180682297084e-08, 'num_leaves': 43, 'num_iterations': 244, 'max_depth': 9, 'max_bin': 31, 'feature_fraction': 0.8257246501294828, 'bagging_fraction': 0.5401216435110882, 'bagging_freq': 9, 'min_data_in_leaf': 80, 'min_gain_to_split': 0.10288417687807763, 'learning_rate': 0.3796281279914822, 'min_sum_hessian_in_leaf': 0.437356658249735}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:36,501] Trial 37 finished with value: 0.43103764872269973 and parameters: {'lambda_l1': 4.2403907318208636e-05, 'lambda_l2': 4.7166025441504844e-08, 'num_leaves': 43, 'num_iterations': 244, 'max_depth': 9, 'max_bin': 30, 'feature_fraction': 0.8098715477799051, 'bagging_fraction': 0.5295194758369146, 'bagging_freq': 9, 'min_data_in_leaf': 84, 'min_gain_to_split': 0.15477985501799488, 'learning_rate': 0.27462784699416615, 'min_sum_hessian_in_leaf': 0.26952930356054405}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:37,553] Trial 38 finished with value: 0.47403892232817135 and parameters: {'lambda_l1': 4.2023888134581585e-05, 'lambda_l2': 1.0906221827517086e-08, 'num_leaves': 34, 'num_iterations': 192, 'max_depth': 6, 'max_bin': 26, 'feature_fraction': 0.8504064523884248, 'bagging_fraction': 0.3372854488211616, 'bagging_freq': 10, 'min_data_in_leaf': 79, 'min_gain_to_split': 0.19862594337161876, 'learning_rate': 0.3794169883717018, 'min_sum_hessian_in_leaf': 0.4532754959152374}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:39,727] Trial 39 finished with value: 0.42909914540037575 and parameters: {'lambda_l1': 9.48819215281129e-06, 'lambda_l2': 3.598164433781596e-08, 'num_leaves': 40, 'num_iterations': 130, 'max_depth': 9, 'max_bin': 32, 'feature_fraction': 0.6674922636627523, 'bagging_fraction': 0.5549289188769464, 'bagging_freq': 10, 'min_data_in_leaf': 91, 'min_gain_to_split': 0.10132314233408923, 'learning_rate': 0.4140357465701674, 'min_sum_hessian_in_leaf': 0.3313888019609269}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:43,214] Trial 40 finished with value: 0.4211043292403406 and parameters: {'lambda_l1': 3.681980418847469e-07, 'lambda_l2': 1.5412143012082333e-07, 'num_leaves': 44, 'num_iterations': 235, 'max_depth': 10, 'max_bin': 38, 'feature_fraction': 0.7295089195417583, 'bagging_fraction': 0.40347037302098565, 'bagging_freq': 1, 'min_data_in_leaf': 82, 'min_gain_to_split': 0.2642801899695029, 'learning_rate': 0.21553429586509276, 'min_sum_hessian_in_leaf': 0.4040828626260795}. Best is trial 23 with value: 0.42004619589867387.
# [I 2024-02-14 11:57:47,831] Trial 41 finished with value: 0.40726662148110454 and parameters: {'lambda_l1': 2.470148872625259e-07, 'lambda_l2': 1.21344872081282e-07, 'num_leaves': 44, 'num_iterations': 237, 'max_depth': 10, 'max_bin': 39, 'feature_fraction': 0.7374964960880266, 'bagging_fraction': 0.4003332552749976, 'bagging_freq': 1, 'min_data_in_leaf': 84, 'min_gain_to_split': 0.1497885151009883, 'learning_rate': 0.19770302734890066, 'min_sum_hessian_in_leaf': 0.40415690906963075}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:57:51,318] Trial 42 finished with value: 0.4154738752413554 and parameters: {'lambda_l1': 4.3935541694456743e-08, 'lambda_l2': 1.5081984918955145e-07, 'num_leaves': 60, 'num_iterations': 158, 'max_depth': 10, 'max_bin': 38, 'feature_fraction': 0.7383131795624149, 'bagging_fraction': 0.4008074390075787, 'bagging_freq': 1, 'min_data_in_leaf': 82, 'min_gain_to_split': 0.15361017237039465, 'learning_rate': 0.20350728199129103, 'min_sum_hessian_in_leaf': 0.3980013806350465}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:57:53,009] Trial 43 finished with value: 0.45602800246474606 and parameters: {'lambda_l1': 1.6934091774106452e-08, 'lambda_l2': 1.4162958450062242e-07, 'num_leaves': 60, 'num_iterations': 94, 'max_depth': 10, 'max_bin': 36, 'feature_fraction': 0.7057991410240616, 'bagging_fraction': 0.31942484835507934, 'bagging_freq': 1, 'min_data_in_leaf': 82, 'min_gain_to_split': 0.27141175372512355, 'learning_rate': 0.19337156699945213, 'min_sum_hessian_in_leaf': 0.40150063492494237}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:57:55,250] Trial 44 finished with value: 0.448936274490061 and parameters: {'lambda_l1': 2.26606693269376e-07, 'lambda_l2': 4.140848809244568e-08, 'num_leaves': 77, 'num_iterations': 151, 'max_depth': 10, 'max_bin': 39, 'feature_fraction': 0.7487434277944098, 'bagging_fraction': 0.26718248626155505, 'bagging_freq': 1, 'min_data_in_leaf': 92, 'min_gain_to_split': 0.21665439205090425, 'learning_rate': 0.17459245669177392, 'min_sum_hessian_in_leaf': 0.4356274382281174}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:57:58,937] Trial 45 finished with value: 0.44876349245664704 and parameters: {'lambda_l1': 8.956904070536678e-08, 'lambda_l2': 4.4593667838461013e-07, 'num_leaves': 45, 'num_iterations': 191, 'max_depth': 10, 'max_bin': 28, 'feature_fraction': 0.660469548809778, 'bagging_fraction': 0.40197586848331046, 'bagging_freq': 2, 'min_data_in_leaf': 99, 'min_gain_to_split': 0.15683953154829808, 'learning_rate': 0.0878975406223289, 'min_sum_hessian_in_leaf': 0.355583176800791}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:57:59,996] Trial 46 finished with value: 0.4962461891045399 and parameters: {'lambda_l1': 4.95971704370994e-08, 'lambda_l2': 2.8059573843160733e-08, 'num_leaves': 60, 'num_iterations': 167, 'max_depth': 3, 'max_bin': 24, 'feature_fraction': 0.6181848503472133, 'bagging_fraction': 0.35254050047694696, 'bagging_freq': 2, 'min_data_in_leaf': 80, 'min_gain_to_split': 0.2503973851988413, 'learning_rate': 0.2880027830688462, 'min_sum_hessian_in_leaf': 0.399746625810823}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:58:01,214] Trial 47 finished with value: 0.47539049282034307 and parameters: {'lambda_l1': 4.6725716443986405e-07, 'lambda_l2': 7.009777891792457e-06, 'num_leaves': 85, 'num_iterations': 76, 'max_depth': 9, 'max_bin': 35, 'feature_fraction': 0.8060772984339387, 'bagging_fraction': 0.3018784985339681, 'bagging_freq': 2, 'min_data_in_leaf': 87, 'min_gain_to_split': 0.341732975900839, 'learning_rate': 0.2539461766087648, 'min_sum_hessian_in_leaf': 0.453719362470844}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:58:04,816] Trial 48 finished with value: 0.5519223965119221 and parameters: {'lambda_l1': 3.614910218737234e-08, 'lambda_l2': 7.257346157569343e-07, 'num_leaves': 54, 'num_iterations': 234, 'max_depth': 10, 'max_bin': 5, 'feature_fraction': 0.7187300678701245, 'bagging_fraction': 0.40167876689886073, 'bagging_freq': 1, 'min_data_in_leaf': 73, 'min_gain_to_split': 0.14944400413547493, 'learning_rate': 0.3198444271972918, 'min_sum_hessian_in_leaf': 0.27481337447297705}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:58:07,089] Trial 49 finished with value: 0.47473426633708815 and parameters: {'lambda_l1': 1.4764007597961115e-08, 'lambda_l2': 6.669014252471013e-08, 'num_leaves': 54, 'num_iterations': 203, 'max_depth': 9, 'max_bin': 30, 'feature_fraction': 0.7473120604716582, 'bagging_fraction': 0.18360062126739934, 'bagging_freq': 4, 'min_data_in_leaf': 96, 'min_gain_to_split': 0.18449718493809197, 'learning_rate': 0.21929526132069294, 'min_sum_hessian_in_leaf': 0.40753309046551334}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:58:08,237] Trial 50 finished with value: 0.48778744553734377 and parameters: {'lambda_l1': 4.088677107529599e-07, 'lambda_l2': 1.0810671326653297e-08, 'num_leaves': 64, 'num_iterations': 130, 'max_depth': 4, 'max_bin': 38, 'feature_fraction': 0.803493556902659, 'bagging_fraction': 0.47514838803829795, 'bagging_freq': 2, 'min_data_in_leaf': 89, 'min_gain_to_split': 0.35211701697249775, 'learning_rate': 0.13879628261052862, 'min_sum_hessian_in_leaf': 0.3724217612194272}. Best is trial 41 with value: 0.40726662148110454.
# [I 2024-02-14 11:58:13,681] Trial 51 finished with value: 0.3932649468750292 and parameters: {'lambda_l1': 1.8324002036458457e-06, 'lambda_l2': 1.669393248105384e-07, 'num_leaves': 32, 'num_iterations': 273, 'max_depth': 10, 'max_bin': 42, 'feature_fraction': 0.8507947087283774, 'bagging_fraction': 0.4415816289199605, 'bagging_freq': 1, 'min_data_in_leaf': 69, 'min_gain_to_split': 0.14031330518608182, 'learning_rate': 0.23052914121412335, 'min_sum_hessian_in_leaf': 0.32405188380519095}. Best is trial 51 with value: 0.3932649468750292.
# [I 2024-02-14 11:58:18,800] Trial 52 finished with value: 0.3996214384240307 and parameters: {'lambda_l1': 1.2004067290815612e-06, 'lambda_l2': 2.3978459973193483e-07, 'num_leaves': 42, 'num_iterations': 272, 'max_depth': 10, 'max_bin': 41, 'feature_fraction': 0.846936492932247, 'bagging_fraction': 0.42463049640898437, 'bagging_freq': 1, 'min_data_in_leaf': 84, 'min_gain_to_split': 0.1451041141761142, 'learning_rate': 0.23770442382824508, 'min_sum_hessian_in_leaf': 0.32652773515657546}. Best is trial 51 with value: 0.3932649468750292.
# [I 2024-02-14 11:58:24,090] Trial 53 finished with value: 0.39309100360647903 and parameters: {'lambda_l1': 1.0204746937224607e-06, 'lambda_l2': 2.9734935207780175e-07, 'num_leaves': 39, 'num_iterations': 271, 'max_depth': 10, 'max_bin': 41, 'feature_fraction': 0.8425188083382804, 'bagging_fraction': 0.4377475429179409, 'bagging_freq': 1, 'min_data_in_leaf': 70, 'min_gain_to_split': 0.14595706833993366, 'learning_rate': 0.2502745585464798, 'min_sum_hessian_in_leaf': 0.3016433378151562}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:28,358] Trial 54 finished with value: 0.4030900737759864 and parameters: {'lambda_l1': 1.6109670676474552e-06, 'lambda_l2': 2.9242240704069624e-07, 'num_leaves': 31, 'num_iterations': 274, 'max_depth': 10, 'max_bin': 46, 'feature_fraction': 0.8544007887084809, 'bagging_fraction': 0.43041990018244286, 'bagging_freq': 1, 'min_data_in_leaf': 70, 'min_gain_to_split': 0.2117628541902163, 'learning_rate': 0.24968718823648778, 'min_sum_hessian_in_leaf': 0.24222991986193043}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:32,976] Trial 55 finished with value: 0.4082533048706994 and parameters: {'lambda_l1': 1.4558754158004423e-06, 'lambda_l2': 3.938249120130222e-07, 'num_leaves': 48, 'num_iterations': 303, 'max_depth': 10, 'max_bin': 46, 'feature_fraction': 0.849970588082503, 'bagging_fraction': 0.34845329738061315, 'bagging_freq': 1, 'min_data_in_leaf': 70, 'min_gain_to_split': 0.21010893986302032, 'learning_rate': 0.2568666303878713, 'min_sum_hessian_in_leaf': 0.2367984529889336}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:37,184] Trial 56 finished with value: 0.41443122988398945 and parameters: {'lambda_l1': 1.5046987782113895e-06, 'lambda_l2': 4.92780333360824e-07, 'num_leaves': 31, 'num_iterations': 345, 'max_depth': 10, 'max_bin': 50, 'feature_fraction': 0.84271026411311, 'bagging_fraction': 0.3494702958193518, 'bagging_freq': 3, 'min_data_in_leaf': 69, 'min_gain_to_split': 0.24040597548169473, 'learning_rate': 0.2558023348362076, 'min_sum_hessian_in_leaf': 0.2427111074289398}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:41,351] Trial 57 finished with value: 0.4037497093391734 and parameters: {'lambda_l1': 9.993582636761619e-07, 'lambda_l2': 4.111272842773001e-06, 'num_leaves': 38, 'num_iterations': 331, 'max_depth': 9, 'max_bin': 46, 'feature_fraction': 0.8599765467323, 'bagging_fraction': 0.4428620945260634, 'bagging_freq': 2, 'min_data_in_leaf': 75, 'min_gain_to_split': 0.1970913063380502, 'learning_rate': 0.2965032130138117, 'min_sum_hessian_in_leaf': 0.28901747400091}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:45,942] Trial 58 finished with value: 0.40360902061479687 and parameters: {'lambda_l1': 8.075357000183364e-07, 'lambda_l2': 3.718441417272348e-06, 'num_leaves': 38, 'num_iterations': 333, 'max_depth': 9, 'max_bin': 48, 'feature_fraction': 0.9400884608568977, 'bagging_fraction': 0.4367471621744529, 'bagging_freq': 2, 'min_data_in_leaf': 75, 'min_gain_to_split': 0.18575093366780035, 'learning_rate': 0.3045741937118717, 'min_sum_hessian_in_leaf': 0.3027339875746398}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:48,030] Trial 59 finished with value: 0.4229050394685022 and parameters: {'lambda_l1': 1.8499645208333264e-06, 'lambda_l2': 5.667394403718315e-06, 'num_leaves': 38, 'num_iterations': 329, 'max_depth': 8, 'max_bin': 48, 'feature_fraction': 0.9447235608943529, 'bagging_fraction': 0.4418995734127121, 'bagging_freq': 3, 'min_data_in_leaf': 61, 'min_gain_to_split': 0.28111169437215255, 'learning_rate': 0.30090484381649296, 'min_sum_hessian_in_leaf': 0.29479815746222754}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:52,693] Trial 60 finished with value: 0.40897894443303073 and parameters: {'lambda_l1': 7.444336651697288e-07, 'lambda_l2': 7.343042732922399e-05, 'num_leaves': 36, 'num_iterations': 421, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.9992905690363046, 'bagging_fraction': 0.4354784043579818, 'bagging_freq': 2, 'min_data_in_leaf': 75, 'min_gain_to_split': 0.202679806424033, 'learning_rate': 0.34525799152316294, 'min_sum_hessian_in_leaf': 0.17373242733798588}. Best is trial 53 with value: 0.39309100360647903.
# [I 2024-02-14 11:58:57,782] Trial 61 finished with value: 0.3929107757060896 and parameters: {'lambda_l1': 1.7987194040991207e-07, 'lambda_l2': 8.591159393533633e-07, 'num_leaves': 33, 'num_iterations': 277, 'max_depth': 9, 'max_bin': 49, 'feature_fraction': 0.7902050751809853, 'bagging_fraction': 0.46288687564394243, 'bagging_freq': 1, 'min_data_in_leaf': 76, 'min_gain_to_split': 0.1364621026921839, 'learning_rate': 0.23580366972242942, 'min_sum_hessian_in_leaf': 0.328871480425059}. Best is trial 61 with value: 0.3929107757060896.
# [I 2024-02-14 11:59:03,271] Trial 62 finished with value: 0.39122131960716355 and parameters: {'lambda_l1': 6.892447119136691e-07, 'lambda_l2': 7.926562943593679e-07, 'num_leaves': 32, 'num_iterations': 349, 'max_depth': 9, 'max_bin': 48, 'feature_fraction': 0.8632021972671902, 'bagging_fraction': 0.4619268526850202, 'bagging_freq': 2, 'min_data_in_leaf': 76, 'min_gain_to_split': 0.13641141830949904, 'learning_rate': 0.24140788943643504, 'min_sum_hessian_in_leaf': 0.267983752580948}. Best is trial 62 with value: 0.39122131960716355.
# [I 2024-02-14 11:59:08,464] Trial 63 finished with value: 0.39008648092385595 and parameters: {'lambda_l1': 1.2397505106476035e-07, 'lambda_l2': 9.324507033345616e-07, 'num_leaves': 25, 'num_iterations': 377, 'max_depth': 8, 'max_bin': 49, 'feature_fraction': 0.7840955118120192, 'bagging_fraction': 0.5144341649493762, 'bagging_freq': 2, 'min_data_in_leaf': 71, 'min_gain_to_split': 0.13470583807855324, 'learning_rate': 0.2354252914610867, 'min_sum_hessian_in_leaf': 0.32222034087381185}. Best is trial 63 with value: 0.39008648092385595.
# [I 2024-02-14 11:59:13,567] Trial 64 finished with value: 0.392296446022396 and parameters: {'lambda_l1': 1.098630251342009e-07, 'lambda_l2': 8.205633257267004e-07, 'num_leaves': 31, 'num_iterations': 375, 'max_depth': 7, 'max_bin': 50, 'feature_fraction': 0.7868015102059133, 'bagging_fraction': 0.4908669945718887, 'bagging_freq': 3, 'min_data_in_leaf': 69, 'min_gain_to_split': 0.1280307501488641, 'learning_rate': 0.15413061655476987, 'min_sum_hessian_in_leaf': 0.3290539048832556}. Best is trial 63 with value: 0.39008648092385595.
# [I 2024-02-14 11:59:18,949] Trial 65 finished with value: 0.38930732939175544 and parameters: {'lambda_l1': 1.0177792039999616e-07, 'lambda_l2': 7.794338170602126e-07, 'num_leaves': 32, 'num_iterations': 394, 'max_depth': 7, 'max_bin': 50, 'feature_fraction': 0.783548214514447, 'bagging_fraction': 0.5099105288521686, 'bagging_freq': 3, 'min_data_in_leaf': 64, 'min_gain_to_split': 0.13483497116945636, 'learning_rate': 0.16303925089301136, 'min_sum_hessian_in_leaf': 0.3373735081423692}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:24,158] Trial 66 finished with value: 0.39356165234312124 and parameters: {'lambda_l1': 7.870582706582513e-08, 'lambda_l2': 8.234818406979111e-07, 'num_leaves': 22, 'num_iterations': 389, 'max_depth': 7, 'max_bin': 50, 'feature_fraction': 0.7850256015911751, 'bagging_fraction': 0.5087497923582279, 'bagging_freq': 4, 'min_data_in_leaf': 63, 'min_gain_to_split': 0.1325115630061152, 'learning_rate': 0.15856562625989312, 'min_sum_hessian_in_leaf': 0.34220948257577855}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:29,754] Trial 67 finished with value: 0.3905283504445468 and parameters: {'lambda_l1': 1.3813383711949134e-07, 'lambda_l2': 2.237787735478336e-06, 'num_leaves': 25, 'num_iterations': 405, 'max_depth': 7, 'max_bin': 48, 'feature_fraction': 0.7804742269198024, 'bagging_fraction': 0.5686181682333505, 'bagging_freq': 4, 'min_data_in_leaf': 67, 'min_gain_to_split': 0.1319646594769547, 'learning_rate': 0.11429253243156628, 'min_sum_hessian_in_leaf': 0.27463628655547384}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:36,164] Trial 68 finished with value: 0.3897216381495481 and parameters: {'lambda_l1': 1.0357524516113179e-08, 'lambda_l2': 1.9324277575770155e-06, 'num_leaves': 25, 'num_iterations': 451, 'max_depth': 7, 'max_bin': 49, 'feature_fraction': 0.7868327452780643, 'bagging_fraction': 0.5630136983177915, 'bagging_freq': 4, 'min_data_in_leaf': 59, 'min_gain_to_split': 0.1293475879148777, 'learning_rate': 0.09766256611997359, 'min_sum_hessian_in_leaf': 0.2631137209690146}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:41,892] Trial 69 finished with value: 0.4000633315433476 and parameters: {'lambda_l1': 2.3155949383175285e-08, 'lambda_l2': 1.9406824756327404e-06, 'num_leaves': 24, 'num_iterations': 432, 'max_depth': 7, 'max_bin': 49, 'feature_fraction': 0.7809015258896519, 'bagging_fraction': 0.5695082066171611, 'bagging_freq': 4, 'min_data_in_leaf': 60, 'min_gain_to_split': 0.18217217262953012, 'learning_rate': 0.09023976672129524, 'min_sum_hessian_in_leaf': 0.27240733230017417}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:48,200] Trial 70 finished with value: 0.4024738570368475 and parameters: {'lambda_l1': 1.313803546280407e-07, 'lambda_l2': 1.2978802875137477e-05, 'num_leaves': 27, 'num_iterations': 471, 'max_depth': 6, 'max_bin': 48, 'feature_fraction': 0.6951379287092041, 'bagging_fraction': 0.5949487127554692, 'bagging_freq': 3, 'min_data_in_leaf': 55, 'min_gain_to_split': 0.12561433838791172, 'learning_rate': 0.060046043891283846, 'min_sum_hessian_in_leaf': 0.2160388560890703}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:53,417] Trial 71 finished with value: 0.39218508761056 and parameters: {'lambda_l1': 1.1025519149391865e-08, 'lambda_l2': 8.375389772804777e-07, 'num_leaves': 25, 'num_iterations': 397, 'max_depth': 7, 'max_bin': 49, 'feature_fraction': 0.8020707462858172, 'bagging_fraction': 0.5025417066378848, 'bagging_freq': 5, 'min_data_in_leaf': 64, 'min_gain_to_split': 0.13290548209524922, 'learning_rate': 0.13343910116669017, 'min_sum_hessian_in_leaf': 0.2657450024915364}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 11:59:58,414] Trial 72 finished with value: 0.3958559267384777 and parameters: {'lambda_l1': 1.0395829042435033e-08, 'lambda_l2': 2.208076696015278e-06, 'num_leaves': 20, 'num_iterations': 403, 'max_depth': 7, 'max_bin': 50, 'feature_fraction': 0.802123628539547, 'bagging_fraction': 0.5045203624817761, 'bagging_freq': 5, 'min_data_in_leaf': 65, 'min_gain_to_split': 0.12731377985450867, 'learning_rate': 0.1311146302910952, 'min_sum_hessian_in_leaf': 0.2562581658165579}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:03,422] Trial 73 finished with value: 0.395595714509724 and parameters: {'lambda_l1': 2.4528188900242224e-08, 'lambda_l2': 1.0987628898935358e-06, 'num_leaves': 25, 'num_iterations': 454, 'max_depth': 7, 'max_bin': 45, 'feature_fraction': 0.7713018827294831, 'bagging_fraction': 0.55024035405208, 'bagging_freq': 3, 'min_data_in_leaf': 67, 'min_gain_to_split': 0.16954622439838823, 'learning_rate': 0.17128015862186252, 'min_sum_hessian_in_leaf': 0.19386226990458322}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:10,325] Trial 74 finished with value: 0.4259398688565571 and parameters: {'lambda_l1': 4.7092941793907995e-08, 'lambda_l2': 7.327994038751237e-07, 'num_leaves': 32, 'num_iterations': 372, 'max_depth': 8, 'max_bin': 49, 'feature_fraction': 0.819996304093664, 'bagging_fraction': 0.5217405582158854, 'bagging_freq': 4, 'min_data_in_leaf': 59, 'min_gain_to_split': 0.23229463432311484, 'learning_rate': 0.03159539537019847, 'min_sum_hessian_in_leaf': 0.348068128229625}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:15,216] Trial 75 finished with value: 0.40006520845925736 and parameters: {'lambda_l1': 6.920734802726327e-08, 'lambda_l2': 1.209096430211252e-05, 'num_leaves': 29, 'num_iterations': 401, 'max_depth': 6, 'max_bin': 47, 'feature_fraction': 0.7657594645825933, 'bagging_fraction': 0.4801862376249963, 'bagging_freq': 4, 'min_data_in_leaf': 63, 'min_gain_to_split': 0.13171314961374753, 'learning_rate': 0.11733175723111439, 'min_sum_hessian_in_leaf': 0.27291783994782065}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:18,558] Trial 76 finished with value: 0.40018884081306094 and parameters: {'lambda_l1': 1.1960596429203485e-07, 'lambda_l2': 2.679414618440385e-06, 'num_leaves': 17, 'num_iterations': 413, 'max_depth': 8, 'max_bin': 44, 'feature_fraction': 0.8770669571565237, 'bagging_fraction': 0.6349573925556933, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.17310650044387904, 'learning_rate': 0.1484518200775869, 'min_sum_hessian_in_leaf': 0.30965909509307293}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:23,092] Trial 77 finished with value: 0.40781022146593165 and parameters: {'lambda_l1': 1.1113117799696657e-08, 'lambda_l2': 1.3024926397569725e-06, 'num_leaves': 22, 'num_iterations': 359, 'max_depth': 7, 'max_bin': 49, 'feature_fraction': 0.7919078794498203, 'bagging_fraction': 0.5670432637949298, 'bagging_freq': 3, 'min_data_in_leaf': 77, 'min_gain_to_split': 0.2242517318416313, 'learning_rate': 0.10749413408044103, 'min_sum_hessian_in_leaf': 0.2284334187554364}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:26,962] Trial 78 finished with value: 0.4014615075790552 and parameters: {'lambda_l1': 2.6920840595685048e-08, 'lambda_l2': 5.436676886148685e-06, 'num_leaves': 34, 'num_iterations': 388, 'max_depth': 5, 'max_bin': 47, 'feature_fraction': 0.8240052452341609, 'bagging_fraction': 0.5857507070728151, 'bagging_freq': 3, 'min_data_in_leaf': 73, 'min_gain_to_split': 0.12378357665697663, 'learning_rate': 0.16608976222113234, 'min_sum_hessian_in_leaf': 0.2616904979421046}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:32,042] Trial 79 finished with value: 0.3964302059605381 and parameters: {'lambda_l1': 1.699479072420347e-07, 'lambda_l2': 6.910951295795528e-07, 'num_leaves': 19, 'num_iterations': 476, 'max_depth': 7, 'max_bin': 45, 'feature_fraction': 0.6930272712005235, 'bagging_fraction': 0.5422678510006502, 'bagging_freq': 4, 'min_data_in_leaf': 53, 'min_gain_to_split': 0.1679881371129028, 'learning_rate': 0.1838256955905121, 'min_sum_hessian_in_leaf': 0.35765967705354623}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:37,245] Trial 80 finished with value: 0.39790599553478967 and parameters: {'lambda_l1': 7.326108642336007e-08, 'lambda_l2': 1.8367875434183828e-06, 'num_leaves': 34, 'num_iterations': 435, 'max_depth': 8, 'max_bin': 48, 'feature_fraction': 0.7749677703175702, 'bagging_fraction': 0.5149987154391045, 'bagging_freq': 5, 'min_data_in_leaf': 67, 'min_gain_to_split': 0.18993871336084173, 'learning_rate': 0.1518957065632229, 'min_sum_hessian_in_leaf': 0.2874637824343369}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:41,443] Trial 81 finished with value: 0.3965553014274367 and parameters: {'lambda_l1': 2.688089115268381e-07, 'lambda_l2': 3.185680084384934e-07, 'num_leaves': 28, 'num_iterations': 351, 'max_depth': 6, 'max_bin': 50, 'feature_fraction': 0.823627465137273, 'bagging_fraction': 0.464348887443169, 'bagging_freq': 2, 'min_data_in_leaf': 72, 'min_gain_to_split': 0.1345836757581237, 'learning_rate': 0.21622108213125057, 'min_sum_hessian_in_leaf': 0.3222333486626893}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:46,215] Trial 82 finished with value: 0.3938269509276722 and parameters: {'lambda_l1': 1.494755468672615e-07, 'lambda_l2': 5.249234252336369e-07, 'num_leaves': 25, 'num_iterations': 370, 'max_depth': 7, 'max_bin': 44, 'feature_fraction': 0.8737803796839775, 'bagging_fraction': 0.4883162492601282, 'bagging_freq': 3, 'min_data_in_leaf': 64, 'min_gain_to_split': 0.15736474035670486, 'learning_rate': 0.1886966224114395, 'min_sum_hessian_in_leaf': 0.30575696408084935}. Best is trial 65 with value: 0.38930732939175544.
# [I 2024-02-14 12:00:53,120] Trial 83 finished with value: 0.38543223966881823 and parameters: {'lambda_l1': 3.2551667081739827e-08, 'lambda_l2': 1.097512902798107e-06, 'num_leaves': 30, 'num_iterations': 422, 'max_depth': 8, 'max_bin': 47, 'feature_fraction': 0.7512512583466024, 'bagging_fraction': 0.5300628419589026, 'bagging_freq': 2, 'min_data_in_leaf': 77, 'min_gain_to_split': 0.10129978436685122, 'learning_rate': 0.12536287717705824, 'min_sum_hessian_in_leaf': 0.24778133159829352}. Best is trial 83 with value: 0.38543223966881823.
# [I 2024-02-14 12:00:59,270] Trial 84 finished with value: 0.4305771364024508 and parameters: {'lambda_l1': 3.23876904010877e-08, 'lambda_l2': 3.3999888399645125e-06, 'num_leaves': 22, 'num_iterations': 421, 'max_depth': 8, 'max_bin': 10, 'feature_fraction': 0.7571428503946787, 'bagging_fraction': 0.532645521772346, 'bagging_freq': 2, 'min_data_in_leaf': 78, 'min_gain_to_split': 0.10055776064008529, 'learning_rate': 0.1310621065531436, 'min_sum_hessian_in_leaf': 0.2562402046543216}. Best is trial 83 with value: 0.38543223966881823.
# [I 2024-02-14 12:01:05,977] Trial 85 finished with value: 0.3965943930840311 and parameters: {'lambda_l1': 5.2877724699314574e-08, 'lambda_l2': 1.3784070347913542e-06, 'num_leaves': 30, 'num_iterations': 453, 'max_depth': 7, 'max_bin': 47, 'feature_fraction': 0.7200357021057165, 'bagging_fraction': 0.5619174729353011, 'bagging_freq': 5, 'min_data_in_leaf': 72, 'min_gain_to_split': 0.1300149992210822, 'learning_rate': 0.07667645762683432, 'min_sum_hessian_in_leaf': 0.21997686590242546}. Best is trial 83 with value: 0.38543223966881823.
# [I 2024-02-14 12:01:10,220] Trial 86 finished with value: 0.41117561114205614 and parameters: {'lambda_l1': 1.9334571749284544e-08, 'lambda_l2': 8.824668772331361e-06, 'num_leaves': 13, 'num_iterations': 382, 'max_depth': 8, 'max_bin': 49, 'feature_fraction': 0.7953962003119747, 'bagging_fraction': 0.5898752907144412, 'bagging_freq': 4, 'min_data_in_leaf': 58, 'min_gain_to_split': 0.1129952162805768, 'learning_rate': 0.10065242798308593, 'min_sum_hessian_in_leaf': 0.27918550721343877}. Best is trial 83 with value: 0.38543223966881823.
# [I 2024-02-14 12:01:15,285] Trial 87 finished with value: 0.3984103188227399 and parameters: {'lambda_l1': 1.0060333405478105e-08, 'lambda_l2': 8.66368354106247e-07, 'num_leaves': 35, 'num_iterations': 412, 'max_depth': 6, 'max_bin': 43, 'feature_fraction': 0.7371887176529109, 'bagging_fraction': 0.5035349465202325, 'bagging_freq': 3, 'min_data_in_leaf': 67, 'min_gain_to_split': 0.1691769527484473, 'learning_rate': 0.1304147059205668, 'min_sum_hessian_in_leaf': 0.33706492634721497}. Best is trial 83 with value: 0.38543223966881823.
# ...
# [I 2024-02-14 12:08:23,317] Trial 172 finished with value: 0.38471711111691725 and parameters: {'lambda_l1': 1.4974230755675515e-07, 'lambda_l2': 1.0429567198650719e-08, 'num_leaves': 54, 'num_iterations': 480, 'max_depth': 6, 'max_bin': 44, 'feature_fraction': 0.9667620517638724, 'bagging_fraction': 0.6876157518123996, 'bagging_freq': 1, 'min_data_in_leaf': 87, 'min_gain_to_split': 0.11666163462953588, 'learning_rate': 0.18846822404161448, 'min_sum_hessian_in_leaf': 0.34318221393130816}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:29,530] Trial 173 finished with value: 0.38559344165393566 and parameters: {'lambda_l1': 1.0565484718337485e-07, 'lambda_l2': 3.1035266515995593e-07, 'num_leaves': 44, 'num_iterations': 474, 'max_depth': 7, 'max_bin': 39, 'feature_fraction': 0.9842253594215878, 'bagging_fraction': 0.5844862368769357, 'bagging_freq': 1, 'min_data_in_leaf': 86, 'min_gain_to_split': 0.11670468054756568, 'learning_rate': 0.13881539605335286, 'min_sum_hessian_in_leaf': 0.37559118421948134}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:35,011] Trial 174 finished with value: 0.38752547563825523 and parameters: {'lambda_l1': 2.3281550585030328e-07, 'lambda_l2': 1.1763421549425855e-07, 'num_leaves': 49, 'num_iterations': 483, 'max_depth': 7, 'max_bin': 45, 'feature_fraction': 0.9430030979150584, 'bagging_fraction': 0.7181802774233237, 'bagging_freq': 1, 'min_data_in_leaf': 90, 'min_gain_to_split': 0.1372183116250283, 'learning_rate': 0.1577630276407296, 'min_sum_hessian_in_leaf': 0.40197945828027665}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:40,163] Trial 175 finished with value: 0.38109015621121667 and parameters: {'lambda_l1': 3.4297300476235316e-07, 'lambda_l2': 3.213407877228877e-08, 'num_leaves': 52, 'num_iterations': 462, 'max_depth': 6, 'max_bin': 41, 'feature_fraction': 0.9126308108738912, 'bagging_fraction': 0.6370362357817901, 'bagging_freq': 1, 'min_data_in_leaf': 78, 'min_gain_to_split': 0.10179698782248296, 'learning_rate': 0.21316987606978258, 'min_sum_hessian_in_leaf': 0.3144416628882216}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:43,566] Trial 176 finished with value: 0.4109468279970514 and parameters: {'lambda_l1': 1.0198085394761422e-07, 'lambda_l2': 7.086974798143191e-08, 'num_leaves': 51, 'num_iterations': 463, 'max_depth': 6, 'max_bin': 43, 'feature_fraction': 0.9038529770695354, 'bagging_fraction': 0.6198104855076002, 'bagging_freq': 1, 'min_data_in_leaf': 78, 'min_gain_to_split': 0.30989569619451585, 'learning_rate': 0.1920224331558823, 'min_sum_hessian_in_leaf': 0.2837257993718105}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:48,846] Trial 177 finished with value: 0.3808785064129473 and parameters: {'lambda_l1': 3.691259793920991e-07, 'lambda_l2': 1.7876372563664964e-07, 'num_leaves': 47, 'num_iterations': 494, 'max_depth': 6, 'max_bin': 42, 'feature_fraction': 0.9329177084087359, 'bagging_fraction': 0.642261766779569, 'bagging_freq': 1, 'min_data_in_leaf': 39, 'min_gain_to_split': 0.1287100678864566, 'learning_rate': 0.2105189914992931, 'min_sum_hessian_in_leaf': 0.31781641032624064}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:54,318] Trial 178 finished with value: 0.388305804286936 and parameters: {'lambda_l1': 5.327868105393498e-07, 'lambda_l2': 1.7726878340766733e-08, 'num_leaves': 45, 'num_iterations': 500, 'max_depth': 7, 'max_bin': 40, 'feature_fraction': 0.9222411548794288, 'bagging_fraction': 0.6675791841232215, 'bagging_freq': 1, 'min_data_in_leaf': 89, 'min_gain_to_split': 0.1322956172500171, 'learning_rate': 0.21049557557027854, 'min_sum_hessian_in_leaf': 0.3143068941845735}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:08:59,353] Trial 179 finished with value: 0.3922030426181982 and parameters: {'lambda_l1': 3.415639893878291e-07, 'lambda_l2': 2.1164951213450152e-07, 'num_leaves': 42, 'num_iterations': 483, 'max_depth': 6, 'max_bin': 45, 'feature_fraction': 0.9110090958244822, 'bagging_fraction': 0.6051252579873421, 'bagging_freq': 1, 'min_data_in_leaf': 82, 'min_gain_to_split': 0.15698427261793682, 'learning_rate': 0.1646249647244426, 'min_sum_hessian_in_leaf': 0.2920970539015023}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:03,555] Trial 180 finished with value: 0.39316859075804206 and parameters: {'lambda_l1': 1.4735124016106067e-07, 'lambda_l2': 3.0229704976324644e-08, 'num_leaves': 51, 'num_iterations': 469, 'max_depth': 5, 'max_bin': 43, 'feature_fraction': 0.9472391688190188, 'bagging_fraction': 0.6454710642314643, 'bagging_freq': 1, 'min_data_in_leaf': 92, 'min_gain_to_split': 0.11931920245100987, 'learning_rate': 0.21786756836182683, 'min_sum_hessian_in_leaf': 0.3198289011839114}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:09,239] Trial 181 finished with value: 0.37749235367364636 and parameters: {'lambda_l1': 3.910020215188138e-07, 'lambda_l2': 1.5161800770062389e-07, 'num_leaves': 47, 'num_iterations': 492, 'max_depth': 6, 'max_bin': 42, 'feature_fraction': 0.9998189186792177, 'bagging_fraction': 0.6520971755561867, 'bagging_freq': 1, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.1180213687443217, 'learning_rate': 0.18394952412053955, 'min_sum_hessian_in_leaf': 0.3360447249844115}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:14,943] Trial 182 finished with value: 0.37721237258560303 and parameters: {'lambda_l1': 2.196348518734367e-07, 'lambda_l2': 3.4978090602944986e-07, 'num_leaves': 46, 'num_iterations': 493, 'max_depth': 6, 'max_bin': 41, 'feature_fraction': 0.9611136671055709, 'bagging_fraction': 0.6262627508062792, 'bagging_freq': 1, 'min_data_in_leaf': 38, 'min_gain_to_split': 0.11808272961458344, 'learning_rate': 0.18893123196371436, 'min_sum_hessian_in_leaf': 0.3528632080716403}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:20,628] Trial 183 finished with value: 0.38227976693925253 and parameters: {'lambda_l1': 2.2763389094651282e-07, 'lambda_l2': 2.6857451832671427e-07, 'num_leaves': 49, 'num_iterations': 491, 'max_depth': 6, 'max_bin': 42, 'feature_fraction': 0.9663369884909496, 'bagging_fraction': 0.5893305179564041, 'bagging_freq': 1, 'min_data_in_leaf': 40, 'min_gain_to_split': 0.13899869639308196, 'learning_rate': 0.18371692478424173, 'min_sum_hessian_in_leaf': 0.33264847135250764}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:25,955] Trial 184 finished with value: 0.38191328463059027 and parameters: {'lambda_l1': 8.334532362247884e-07, 'lambda_l2': 5.982358679799699e-07, 'num_leaves': 47, 'num_iterations': 479, 'max_depth': 6, 'max_bin': 42, 'feature_fraction': 0.9655695641075236, 'bagging_fraction': 0.5828779712243639, 'bagging_freq': 1, 'min_data_in_leaf': 41, 'min_gain_to_split': 0.14426677345403333, 'learning_rate': 0.1840894122103748, 'min_sum_hessian_in_leaf': 0.353315390127269}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:31,227] Trial 185 finished with value: 0.3831129192924566 and parameters: {'lambda_l1': 8.34189873963935e-07, 'lambda_l2': 6.343053315303505e-07, 'num_leaves': 47, 'num_iterations': 479, 'max_depth': 7, 'max_bin': 42, 'feature_fraction': 0.9689167420698499, 'bagging_fraction': 0.60124115183654, 'bagging_freq': 1, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.16889271736775346, 'learning_rate': 0.1818422301159438, 'min_sum_hessian_in_leaf': 0.3076050980403431}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:36,074] Trial 186 finished with value: 0.3887996701675582 and parameters: {'lambda_l1': 1.1029169486181075e-07, 'lambda_l2': 4.1936834341593103e-07, 'num_leaves': 44, 'num_iterations': 460, 'max_depth': 6, 'max_bin': 42, 'feature_fraction': 0.9631231915002063, 'bagging_fraction': 0.5828800646830872, 'bagging_freq': 1, 'min_data_in_leaf': 41, 'min_gain_to_split': 0.19330379829827654, 'learning_rate': 0.14388064704838666, 'min_sum_hessian_in_leaf': 0.3494706466654714}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:37,702] Trial 187 finished with value: 0.48180375516773993 and parameters: {'lambda_l1': 2.0301646203469625e-07, 'lambda_l2': 3.4569377209619636e-07, 'num_leaves': 49, 'num_iterations': 469, 'max_depth': 2, 'max_bin': 41, 'feature_fraction': 0.9315576780165, 'bagging_fraction': 0.6285186569976331, 'bagging_freq': 1, 'min_data_in_leaf': 39, 'min_gain_to_split': 0.14390343327396277, 'learning_rate': 0.17008652376069813, 'min_sum_hessian_in_leaf': 0.325890638504537}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:43,343] Trial 188 finished with value: 0.37912159948911234 and parameters: {'lambda_l1': 3.542090713894789e-07, 'lambda_l2': 6.42869455627104e-07, 'num_leaves': 47, 'num_iterations': 493, 'max_depth': 6, 'max_bin': 43, 'feature_fraction': 0.9612813777659965, 'bagging_fraction': 0.5923626795342443, 'bagging_freq': 1, 'min_data_in_leaf': 29, 'min_gain_to_split': 0.13564712175311588, 'learning_rate': 0.18770468506538543, 'min_sum_hessian_in_leaf': 0.2816864631965235}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:49,275] Trial 189 finished with value: 0.4051299551085643 and parameters: {'lambda_l1': 1.1526655786387688e-06, 'lambda_l2': 6.415174537819888e-07, 'num_leaves': 47, 'num_iterations': 494, 'max_depth': 7, 'max_bin': 15, 'feature_fraction': 0.894922100990195, 'bagging_fraction': 0.5939389531486662, 'bagging_freq': 1, 'min_data_in_leaf': 27, 'min_gain_to_split': 0.15076368451069339, 'learning_rate': 0.16220882644052814, 'min_sum_hessian_in_leaf': 0.2874147345224305}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:09:54,705] Trial 190 finished with value: 0.3868079781026751 and parameters: {'lambda_l1': 3.547248108512043e-07, 'lambda_l2': 5.737592042088581e-07, 'num_leaves': 45, 'num_iterations': 483, 'max_depth': 6, 'max_bin': 41, 'feature_fraction': 0.9615001197090617, 'bagging_fraction': 0.5709264559816948, 'bagging_freq': 1, 'min_data_in_leaf': 43, 'min_gain_to_split': 0.17239107360345543, 'learning_rate': 0.12712397874615203, 'min_sum_hessian_in_leaf': 0.30490845571615866}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:10:00,180] Trial 191 finished with value: 0.37921440313208865 and parameters: {'lambda_l1': 2.4479567556207783e-07, 'lambda_l2': 2.983836201371602e-07, 'num_leaves': 49, 'num_iterations': 477, 'max_depth': 6, 'max_bin': 43, 'feature_fraction': 0.9986468244637294, 'bagging_fraction': 0.5838863341350807, 'bagging_freq': 1, 'min_data_in_leaf': 35, 'min_gain_to_split': 0.13010900715592383, 'learning_rate': 0.19947320334401095, 'min_sum_hessian_in_leaf': 0.35571391208019626}. Best is trial 111 with value: 0.37711705657009625.
# [I 2024-02-14 12:10:05,824] Trial 192 finished with value: 0.3765984512506253 and parameters: {'lambda_l1': 6.615391132414117e-07, 'lambda_l2': 3.1907163628802457e-07, 'num_leaves': 49, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 43, 'feature_fraction': 0.9957769701688443, 'bagging_fraction': 0.5832158471965193, 'bagging_freq': 1, 'min_data_in_leaf': 29, 'min_gain_to_split': 0.13206618700186268, 'learning_rate': 0.1970884217888203, 'min_sum_hessian_in_leaf': 0.3281115932823233}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:11,456] Trial 193 finished with value: 0.3781977208930248 and parameters: {'lambda_l1': 6.762195665381522e-07, 'lambda_l2': 3.2850829855571406e-07, 'num_leaves': 49, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 45, 'feature_fraction': 0.9985675898205847, 'bagging_fraction': 0.5813461609439791, 'bagging_freq': 1, 'min_data_in_leaf': 31, 'min_gain_to_split': 0.13031682014718315, 'learning_rate': 0.20010564277025716, 'min_sum_hessian_in_leaf': 0.2743537509070059}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:17,338] Trial 194 finished with value: 0.37904717814903244 and parameters: {'lambda_l1': 5.245852620258216e-07, 'lambda_l2': 3.0788686274183165e-07, 'num_leaves': 49, 'num_iterations': 499, 'max_depth': 6, 'max_bin': 45, 'feature_fraction': 0.9998445744130067, 'bagging_fraction': 0.5729920958665665, 'bagging_freq': 1, 'min_data_in_leaf': 33, 'min_gain_to_split': 0.13188766365368118, 'learning_rate': 0.19400183484019573, 'min_sum_hessian_in_leaf': 0.27691405045161566}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:23,009] Trial 195 finished with value: 0.38034625260404864 and parameters: {'lambda_l1': 7.023458610193711e-07, 'lambda_l2': 2.743019579696812e-07, 'num_leaves': 49, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 45, 'feature_fraction': 0.9561577949148691, 'bagging_fraction': 0.5731033210625093, 'bagging_freq': 1, 'min_data_in_leaf': 32, 'min_gain_to_split': 0.1377238338553862, 'learning_rate': 0.18755910459267972, 'min_sum_hessian_in_leaf': 0.2744062941902371}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:28,261] Trial 196 finished with value: 0.38078083216201686 and parameters: {'lambda_l1': 7.910546993506107e-07, 'lambda_l2': 2.8693985702344144e-07, 'num_leaves': 49, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 46, 'feature_fraction': 0.9513033038373093, 'bagging_fraction': 0.5802802573241913, 'bagging_freq': 1, 'min_data_in_leaf': 31, 'min_gain_to_split': 0.15897988200198954, 'learning_rate': 0.19576707058522178, 'min_sum_hessian_in_leaf': 0.27292556866562995}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:33,209] Trial 197 finished with value: 0.38400347667593393 and parameters: {'lambda_l1': 7.34186297236525e-07, 'lambda_l2': 3.7011258592945193e-07, 'num_leaves': 43, 'num_iterations': 498, 'max_depth': 6, 'max_bin': 46, 'feature_fraction': 0.9282708241084672, 'bagging_fraction': 0.5752318140604317, 'bagging_freq': 1, 'min_data_in_leaf': 30, 'min_gain_to_split': 0.17944463133056554, 'learning_rate': 0.19943632508066492, 'min_sum_hessian_in_leaf': 0.27638868675596123}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:38,785] Trial 198 finished with value: 0.3821773095576746 and parameters: {'lambda_l1': 6.784025930584016e-07, 'lambda_l2': 6.626023881706884e-07, 'num_leaves': 49, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 46, 'feature_fraction': 0.9519738958535671, 'bagging_fraction': 0.6118527146652069, 'bagging_freq': 1, 'min_data_in_leaf': 33, 'min_gain_to_split': 0.15809576294672717, 'learning_rate': 0.14783414904787057, 'min_sum_hessian_in_leaf': 0.2587861004783676}. Best is trial 192 with value: 0.3765984512506253.
# [I 2024-02-14 12:10:44,409] Trial 199 finished with value: 0.3784076582312105 and parameters: {'lambda_l1': 4.140200401063361e-07, 'lambda_l2': 1.0093938472545483e-06, 'num_leaves': 46, 'num_iterations': 500, 'max_depth': 6, 'max_bin': 45, 'feature_fraction': 0.9995802490855646, 'bagging_fraction': 0.5784186514825495, 'bagging_freq': 1, 'min_data_in_leaf': 30, 'min_gain_to_split': 0.13360548772539585, 'learning_rate': 0.20252519382136136, 'min_sum_hessian_in_leaf': 0.28167987267350225}. Best is trial 192 with value: 0.3765984512506253.
# Number of finished trials: 200
# Best trial:
#   Value: 0.3765984512506253
#   Params:
#     lambda_l1: 6.615391132414117e-07
#     lambda_l2: 3.1907163628802457e-07
#     num_leaves: 49
#     num_iterations: 500
#     max_depth: 6
#     max_bin: 43
#     feature_fraction: 0.9957769701688443
#     bagging_fraction: 0.5832158471965193
#     bagging_freq: 1
#     min_data_in_leaf: 29
#     min_gain_to_split: 0.13206618700186268
#     learning_rate: 0.1970884217888203
#     min_sum_hessian_in_leaf: 0.3281115932823233

# %%
def read_param():
    fname = 'best-paramters_lgbr_random.txt'
    f0 = open(fname,'r')
    b = []
    for line in f0.readlines():
        a = line.split()
        a_ = [a[i] for i in range(len(a))]
        b.append(a_)
    f0.close()
    p1 = float(b[1][1]); p2 = float(b[2][1]); p3 = int(b[3][1]); p4 = int(b[4][1])
    p5 = int(b[5][1]); p6 = int(b[6][1]); p7 = float(b[7][1]); p8 = float(b[8][1])
    p9 = int(b[9][1]); p10 = int(b[10][1]); p11 = float(b[11][1]); p12 = float(b[12][1])
    p13 = float(b[13][1])
    return p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13

# %%
p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13 = read_param()
params = {"objective": 'regression', "metric": "root_mean_squared_error", "boosting_type": "gbdt", 
         'lambda_l1': p1, 'lambda_l2': p2, 'num_leaves': p3, 'num_iterations': p4, 
         'max_depth': p5, 'max_bin': p6, 'feature_fraction': p7, 'bagging_fraction': p8,
         'bagging_freq': p9, 'min_data_in_leaf': p10, 'min_gain_to_split': p11, 'learning_rate': p12,
         'min_sum_hessian_in_leaf': p13}
print(p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13)
# Out:
# 6.615391132414117e-07 3.1907163628802457e-07 49 500 6 43 0.9957769701688443 0.5832158471965193 1 29 0.13206618700186268 0.1970884217888203 0.3281115932823233

# %%
## optimize over random states of KFold
rmse_cv_array = []
for i in range(0,100):
    print(f"Step {i}")
    # Initialize KFold cross-validation
    kf = KFold(n_splits=5, shuffle=True, random_state=i)
    # stratify_labels = df_train['CE_binned']
    lgbm = LGBMRegressor(**params, verbose=-1)
    # plsr = PLSRegression(n_components=ncomp, scale=True) ## don't use scale=True

    fold = 1
    # Loop over each fold
    rmse_val = []; rmse_train = []
    for train_index, val_index in kf.split(X_train_):
        # print("Fold {}".format(fold))
        # Split the data
        X_train_fold, X_val_fold = X_train_[train_index], X_train_[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Fit the model on the training data
        lgbm.fit(X_train_fold, y_train_fold)

        y_pred_val_fold = lgbm.predict(X_val_fold)
        r2 = r2_score(y_val_fold, y_pred_val_fold); rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_val_fold)); mae = mean_absolute_error(y_val_fold, y_pred_val_fold)
        # print(f"Train set CV, R2 score: {r2}, RMSE: {rmse}, MAE: {mae}")
        rmse_train.append(rmse)

        ## predict on validation test
        y_pred_val = lgbm.predict(X_val_)
        r2 = r2_score(y_val, y_pred_val); rmse = np.sqrt(mean_squared_error(y_val, y_pred_val)); mae = mean_absolute_error(y_val, y_pred_val)
        # print(f"Validation set, R2 score: {r2}, RMSE: {rmse}, MAE: {mae}")
        rmse_val.append(rmse)

        fold += 1
    # print(f"RMSE train: {np.mean(rmse_train)} & RMSE val: {np.mean(rmse_val)}")
    rmse_cv_array.append(np.mean(rmse_train))

ind = min(range(len(rmse_cv_array)), key=rmse_cv_array.__getitem__)
print(rmse_cv_array[ind])
# Out:
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Step 10
# Step 11
# Step 12
# Step 13
# Step 14
# Step 15
# Step 16
# Step 17
# Step 18
# Step 19
# Step 20
# Step 21
# Step 22
# Step 23
# Step 24
# Step 25
# Step 26
# Step 27
# Step 28
# Step 29
# Step 30
# Step 31
# Step 32
# Step 33
# Step 34
# Step 35
# Step 36
# Step 37
# Step 38
# Step 39
# Step 40
# Step 41
# Step 42
# Step 43
# Step 44
# Step 45
# Step 46
# Step 47
# Step 48
# Step 49
# Step 50
# Step 51
# Step 52
# Step 53
# Step 54
# Step 55
# Step 56
# Step 57
# Step 58
# Step 59
# Step 60
# Step 61
# Step 62
# Step 63
# Step 64
# Step 65
# Step 66
# Step 67
# Step 68
# Step 69
# Step 70
# Step 71
# Step 72
# Step 73
# Step 74
# Step 75
# Step 76
# Step 77
# Step 78
# Step 79
# Step 80
# Step 81
# Step 82
# Step 83
# Step 84
# Step 85
# Step 86
# Step 87
# Step 88
# Step 89
# Step 90
# Step 91
# Step 92
# Step 93
# Step 94
# Step 95
# Step 96
# Step 97
# Step 98
# Step 99
# 0.3737185937000777

# %%
## use the best random state to train the model
kf = KFold(n_splits=5, shuffle=True, random_state=ind)
# stratify_labels = df_train['CE_binned']

lgbm = LGBMRegressor(**params, verbose=-1)

fold = 1
# Loop over each fold
pred_train_array = []; pred_val_array = []; pred_test_array = []
for train_index, val_index in kf.split(X_train_):
    X_train_fold, X_val_fold = X_train_[train_index], X_train_[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Fit the model on the training data
    lgbm.fit(X_train_fold, y_train_fold)

    # Store the model
    # models.append(plsr)
    y_pred_val_fold = lgbm.predict(X_val_fold)
    r2 = r2_score(y_val_fold, y_pred_val_fold); rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_val_fold)); mae = mean_absolute_error(y_val_fold, y_pred_val_fold)
    
    y_pred_train = lgbm.predict(X_train_)
    pred_train_array.append(y_pred_train)

    ## predict on validation test
    y_pred_val = lgbm.predict(X_val_)
    pred_val_array.append(y_pred_val)

    # ## predict on test set
    y_pred_test = lgbm.predict(X_test_)
    pred_test_array.append(y_pred_test)

    ## save plsr model to pickle
    filename = f'./lgbm_oxstab_rand_fold_{fold}.sav'
    pickle.dump(lgbm, open(filename, 'wb'))
    fold += 1

## calculate the average of the predictions on train, val and test
y_pred_train_avg = np.mean(pred_train_array, axis=0); y_pred_val_avg = np.mean(pred_val_array, axis=0); y_pred_test_avg = np.mean(pred_test_array, axis=0)
r2_train = r2_score(y_train, y_pred_train_avg); rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train_avg)); mae_train = mean_absolute_error(y_train, y_pred_train_avg)
r2_val = r2_score(y_val, y_pred_val_avg); rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val_avg)); mae_val = mean_absolute_error(y_val, y_pred_val_avg)
r2_test = r2_score(y_test, y_pred_test_avg); rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test_avg)); mae_test = mean_absolute_error(y_test, y_pred_test_avg)
print(f"RMSE train: {rmse_train} & RMSE val: {rmse_val} & RMSE test: {rmse_test}")
print(f"R2 train: {r2_train} & R2 val: {r2_val} & R2 test: {r2_test}")
print(f"MAE train: {mae_train} & MAE val: {mae_val} & MAE test: {mae_test}")
# Out:
# RMSE train: 0.260319831179348 & RMSE val: 0.33705620395347025 & RMSE test: 0.34302621199127203
# R2 train: 0.9510957047013063 & R2 val: 0.9154312403096445 & R2 test: 0.9139721187672729
# MAE train: 0.1773897608760129 & MAE val: 0.2237328226067253 & MAE test: 0.22461921268782126

# %%
fig, ax = plt.subplots(figsize=(5,5))
xl = np.arange(0,11,1)
yl = np.arange(0,11,1)
plt.plot(yl, xl, linestyle='dashed', linewidth=2.0, color='black')  

# plt.tick_params(axis='both', direction='in')
plt.xlabel('True E$_{ox}$ vs Li/Li$^{+}$ (V)',fontsize=12)
plt.ylabel('ML-predicted E$_{ox}$ vs Li/Li$^{+}$ (V)',fontsize=12)
sns.scatterplot(x=y_train, y=y_pred_train, color="cyan", label='Train')
sns.scatterplot(x=y_val, y=y_pred_val, color="gray", label='Validation')
sns.scatterplot(x=y_test, y=y_pred_test, color="orange", label='Test')
# plt.grid()
plt.text(5, 2, 'RMSE = {:.3f} / {:.3f} / {:.3f}'.format(rmse_train, rmse_val, rmse_test), color='blue')
plt.text(5, 1, 'R$^2$ = {:.3f} / {:.3f} / {:.3f}'.format(r2_train, r2_val, r2_test), color='blue')
plt.show()
# filename = save_fig_path + 'fgrp_lgbm_cv_1.jpg'
# plt.savefig(filename, dpi=300)

# %% [markdown]
# **Predict on OOD**

# %%
df_ood = pd.read_csv('oxstab_ood_fgrp_feat.csv')
df_ood
# Out:
#                                               smiles  fr_func_grp_1_solv  \
# 0                             FC(F)(F)COCCOCC(F)(F)F                   0
# 1               FC(F)(F)C(F)(F)COCCOCC(F)(F)C(F)(F)F                   0
# 2                                        CCOCCOCCOCC                   0
# 3                          FC(F)(F)COCCOCCOCC(F)(F)F                   0
# 4            FC(F)(F)C(F)(F)COCCOCCOCC(F)(F)C(F)(F)F                   0
# 5                                     CCOCCOCCOCCOCC                   0
# 6                       FC(F)(F)COCCOCCOCCOCC(F)(F)F                   0
# 7         FC(F)(F)C(F)(F)COCCOCCOCCOCC(F)(F)C(F)(F)F                   0
# 8                                  CCOCCOCCOCCOCCOCC                   0
# 9                    FC(F)(F)COCCOCCOCCOCCOCC(F)(F)F                   0
# 10     FC(F)(F)C(F)(F)COCCOCCOCCOCCOCC(F)(F)C(F)(F)F                   0
# 11                              CCOCCOCCOCCOCCOCCOCC                   0
# 12                FC(F)(F)COCCOCCOCCOCCOCCOCC(F)(F)F                   0
# 13  FC(F)(F)C(F)(F)COCCOCCOCCOCCOCCOCC(F)(F)C(F)(F)F                   0
# 14                             COCCOCC(F)(F)C(F)(F)F                   0
# 15                      COCCOCC(F)(F)C(F)(F)C(F)(F)F                   0
# 16                                COCCOCC(F)(F)C(F)F                   0
# 17                                     FCCOCCOCCOCCF                   0
# 18                                 CCC[Si](OC)(OC)OC                   0
# 19                              CCCCCC[Si](OC)(OC)OC                   0
# 20                               COCCOCCO[Si](C)(C)C                   0
# 21                                   FCCOB(OCCF)OCCF                   0
# 22                     COCCOCC(COCCOC)(COCCOC)COCCOC                   0
# 23                                       COCCOCC(C)C                   0
# 24                                     COCCOC(C)(C)C                   0
# 25                                         CCCCOCCOC                   0
# 26                                        COCCOC(C)C                   0
# 27                                       CCOCCOC(C)C                   0
# 28                                   COCCOCCOCCOCCOC                   0
# 29                              CCOC1OCC(C(F)(F)F)O1                   0
# 30                                   FC(F)(F)C1COCO1                   0
# 31                                           FCCOCCF                   0
# 32                                        FCCOCC(F)F                   0
# 33                                     FCCOCC(F)(F)F                   0
# 34                                         COCC(C)OC                   0
# 35                                  COCC(OC)C(F)(F)F                   0
# 36                              CS(=O)(=O)OCC(F)(F)F                   0
# 37                                     CCOS(C)(=O)=O                   0
# 38                           CO[Si](C)(CCC(F)(F)F)OC                   0
# 39                                       CC1CCC(C)O1                   0
#
#     fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                    0                   0                   0
# 1                    0                   0                   0
# 2                    0                   0                   0
# 3                    0                   0                   0
# 4                    0                   0                   0
# 5                    0                   0                   0
# 6                    0                   0                   0
# 7                    0                   0                   0
# 8                    0                   0                   0
# 9                    0                   0                   0
# 10                   0                   0                   0
# 11                   0                   0                   0
# 12                   0                   0                   0
# 13                   0                   0                   0
# 14                   0                   0                   0
# 15                   0                   0                   0
# 16                   0                   0                   0
# 17                   0                   0                   0
# 18                   0                   0                   0
# 19                   0                   0                   0
# 20                   0                   0                   0
# 21                   0                   0                   1
# 22                   0                   0                   0
# 23                   0                   0                   0
# 24                   0                   0                   0
# 25                   0                   0                   0
# 26                   0                   0                   0
# 27                   0                   0                   0
# 28                   0                   0                   0
# 29                   0                   0                   0
# 30                   0                   0                   0
# 31                   0                   0                   0
# 32                   0                   0                   0
# 33                   0                   0                   0
# 34                   0                   0                   0
# 35                   0                   0                   0
# 36                   0                   0                   0
# 37                   0                   0                   0
# 38                   0                   0                   0
# 39                   0                   0                   0
#
#     fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                    0                   0                   0
# 1                    0                   0                   0
# 2                    0                   0                   0
# 3                    0                   0                   0
# 4                    0                   0                   0
# 5                    0                   0                   0
# 6                    0                   0                   0
# 7                    0                   0                   0
# 8                    0                   0                   0
# 9                    0                   0                   0
# 10                   0                   0                   0
# 11                   0                   0                   0
# 12                   0                   0                   0
# 13                   0                   0                   0
# 14                   0                   0                   0
# 15                   0                   0                   0
# 16                   0                   0                   0
# 17                   0                   0                   0
# 18                   0                   0                   0
# 19                   0                   0                   0
# 20                   0                   0                   0
# 21                   0                   0                   0
# 22                   0                   0                   0
# 23                   0                   0                   0
# 24                   0                   0                   0
# 25                   0                   0                   0
# 26                   0                   0                   0
# 27                   0                   0                   0
# 28                   0                   0                   0
# 29                   0                   0                   0
# 30                   0                   0                   0
# 31                   0                   0                   0
# 32                   0                   0                   0
# 33                   0                   0                   0
# 34                   0                   0                   0
# 35                   0                   0                   0
# 36                   0                   0                   0
# 37                   0                   0                   0
# 38                   0                   0                   0
# 39                   0                   0                   0
#
#     fr_func_grp_8_solv  fr_func_grp_9_solv  ...   clogp  molar_refractivity  \
# 0                    0                   0  ...  2.1442             33.7480
# 1                    0                   0  ...  3.4148             43.6420
# 2                    0                   0  ...  1.0760             43.8050
# 3                    0                   0  ...  2.1608             44.5670
# 4                    0                   0  ...  3.4314             54.4610
# 5                    0                   0  ...  1.0926             54.6240
# 6                    0                   0  ...  2.1774             55.3860
# 7                    0                   0  ...  3.4480             65.2800
# 8                    0                   0  ...  1.1092             65.4430
# 9                    0                   0  ...  2.1940             66.2050
# 10                   0                   0  ...  3.4646             76.0990
# 11                   0                   0  ...  1.1258             76.2620
# 12                   0                   0  ...  2.2106             77.0240
# 13                   0                   0  ...  3.4812             86.9180
# 14                   0                   0  ...  1.8470             33.6970
# 15                   0                   0  ...  2.4823             38.6440
# 16                   0                   0  ...  1.5498             33.6460
# 17                   0                   0  ...  0.9752             44.4070
# 18                   0                   0  ...  1.2745             41.8790
# 19                   0                   0  ...  2.4448             55.7300
# 20                   0                   0  ...  1.5009             51.9930
# 21                   0                   0  ...  0.9296             41.5350
# 22                   0                   0  ...  0.6248             93.2130
# 23                   0                   0  ...  1.3054             37.5330
# 24                   0                   0  ...  1.4479             37.5810
# 25                   0                   0  ...  1.4495             37.6030
# 26                   0                   0  ...  1.0578             32.9640
# 27                   0                   0  ...  1.4479             37.5810
# 28                   0                   0  ...  0.3290             56.2090
# 29                   0                   0  ...  1.2842             32.2940
# 30                   0                   0  ...  0.9216             21.7470
# 31                   0                   0  ...  0.9420             22.7690
# 32                   0                   0  ...  1.2376             22.7980
# 33                   0                   0  ...  1.5348             22.8490
# 34                   0                   0  ...  0.6677             28.3470
# 35                   0                   0  ...  1.2101             28.7280
# 36                   0                   0  ...  0.5249             26.8508
# 37                   0                   0  ... -0.0175             26.4698
# 38                   0                   0  ...  2.3036             41.1150
# 39                   0                   0  ...  1.5738             29.2430
#
#      tpsa  frac_sp3  hall_kier_alpha  labute_ASA  num_valence_electron  \
# 0   18.46       1.0        -0.500000   75.784264                    86
# 1   18.46       1.0        -0.780000  105.176290                   122
# 2   27.69       1.0        -0.120000   68.634482                    68
# 3   27.69       1.0        -0.540000   93.627694                   104
# 4   27.69       1.0        -0.820000  123.019720                   140
# 5   36.92       1.0        -0.160000   86.477911                    86
# 6   36.92       1.0        -0.580000  111.471123                   122
# 7   36.92       1.0        -0.860000  140.863149                   158
# 8   46.15       1.0        -0.200000  104.321340                   104
# 9   46.15       1.0        -0.620000  129.314553                   140
# 10  46.15       1.0        -0.900000  158.706579                   176
# 11  55.38       1.0        -0.240000  122.164770                   122
# 12  55.38       1.0        -0.660000  147.157982                   158
# 13  55.38       1.0        -0.940000  176.550008                   194
# 14  18.46       1.0        -0.430000   71.618729                    80
# 15  18.46       1.0        -0.570000   86.314742                    98
# 16  18.46       1.0        -0.360000   67.453194                    74
# 17  27.69       1.0        -0.260000   76.965552                    80
# 18  27.69       1.0         0.096883   63.655570                    62
# 19  27.69       1.0         0.096883   82.750396                    80
# 20  27.69       1.0         0.096883   76.138797                    74
# 21  27.69       1.0        -0.265065   75.328711                    78
# 22  73.84       1.0        -0.320000  151.486687                   152
# 23  18.46       1.0        -0.080000   57.155994                    56
# 24  18.46       1.0        -0.080000   57.155994                    56
# 25  18.46       1.0        -0.080000   57.155994                    56
# 26  18.46       1.0        -0.080000   50.791052                    50
# 27  18.46       1.0        -0.080000   57.155994                    56
# 28  46.15       1.0        -0.200000   91.591456                    92
# 29  27.69       1.0        -0.330000   67.395372                    72
# 30  18.46       1.0        -0.290000   49.551943                    54
# 31   9.23       1.0        -0.180000   41.278693                    44
# 32   9.23       1.0        -0.250000   45.444229                    50
# 33   9.23       1.0        -0.320000   49.609764                    56
# 34  18.46       1.0        -0.080000   44.426110                    44
# 35  18.46       1.0        -0.290000   56.922716                    62
# 36  43.37       1.0        -0.300000   55.913689                    62
# 37  43.37       1.0        -0.090000   43.417083                    44
# 38  18.46       1.0        -0.073117   70.915303                    74
# 39   9.23       1.0        -0.040000   44.671676                    42
#
#     max_partial_charge  min_partial_charge        IE
# 0             0.411279           -0.369644  6.259262
# 1             0.455266           -0.372419  6.277077
# 2             0.070112           -0.379347  5.587656
# 3             0.411279           -0.376668  6.003231
# 4             0.455266           -0.376668  6.018283
# 5             0.070114           -0.379347  5.939028
# 6             0.411279           -0.376668  5.757092
# 7             0.455266           -0.376668  5.759758
# 8             0.070114           -0.379347  5.916364
# 9             0.411279           -0.376668  5.722913
# 10            0.455266           -0.376668  5.722099
# 11            0.070114           -0.379347  5.901245
# 12            0.411279           -0.376668  5.693132
# 13            0.455266           -0.376668  5.693667
# 14            0.455266           -0.382298  5.910965
# 15            0.459463           -0.382298  5.911988
# 16            0.329662           -0.382298  5.789899
# 17            0.112737           -0.376668  5.748376
# 18            0.499627           -0.376825  5.856313
# 19            0.499638           -0.376825  5.776198
# 20            0.183333           -0.415285  5.487719
# 21            0.639186           -0.383145  6.735729
# 22            0.070014           -0.382298  5.292310
# 23            0.069992           -0.382298  5.508127
# 24            0.070693           -0.382297  6.456103
# 25            0.069979           -0.382298  5.384557
# 26            0.070328           -0.382297  5.452009
# 27            0.070343           -0.379346  5.311448
# 28            0.070114           -0.382298  5.387067
# 29            0.416616           -0.330223  6.290177
# 30            0.416506           -0.352339  6.511784
# 31            0.112737           -0.376029  6.382091
# 32            0.261082           -0.372818  6.512543
# 33            0.411280           -0.369325  6.780731
# 34            0.077601           -0.382008  5.434983
# 35            0.416374           -0.381627  5.895535
# 36            0.412742           -0.260725  7.426602
# 37            0.263877           -0.270613  6.999096
# 38            0.388527           -0.397718  5.993766
# 39            0.055113           -0.375566  5.654256
#
# [40 rows x 58 columns]

# %%
df_ood.drop(columns=zero_columns, inplace=True)
df_ood.reset_index(drop=True, inplace=True)

X_ood = df_ood.iloc[:,1:-1]
y_ood = df_ood.iloc[:,-1]

X_ood.shape
# Out:
# (40, 47)

# %%
X_ood_std  = std_scale.transform(X_ood)
X_ood_std = pd.DataFrame(X_ood_std, columns=X_ood.columns)
X_ood_ = np.array(X_ood_std)

# %%
pred_ood_array = []
for i in range(1,6):
    filename = f'./lgbm_oxstab_rand_fold_{i}.sav'
    lgbm = pickle.load(open(filename, 'rb'))
    y_pred_ood = lgbm.predict(X_ood_)
    pred_ood_array.append(y_pred_ood)

# %%
y_pred_ood_avg = np.mean(pred_ood_array, axis=0)
r2_ood = r2_score(y_ood, y_pred_ood_avg); rmse_ood = np.sqrt(mean_squared_error(y_ood, y_pred_ood_avg)); mae_ood = mean_absolute_error(y_ood, y_pred_ood_avg)
print(f"RMSE ood: {rmse_ood} & MAE ood: {mae_ood}")
# Out:
# RMSE ood: 0.6674226683021097 & MAE ood: 0.5486728465881479
