# %% [markdown]
# ## LGBM regression on complete multi-component data
# ### Using functional group features & cross validation

# %% [markdown]
# **Created on 29th August, 2022; modified on 7th September; remodified on 13th February, 2024**

# %%
import warnings
warnings.filterwarnings('ignore')
#from sklearn.preprocessing import Imputer
# from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'
from matplotlib.offsetbox import AnchoredText
import matplotlib.colors as mcolors
import seaborn as sns
import pandas as pd
import numpy as np
#import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso, LassoCV, \
    RidgeClassifier, Ridge
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR, SVC
from sklearn.gaussian_process import GaussianProcessRegressor, GaussianProcessClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel, \
RationalQuadratic, ExpSineSquared, DotProduct
from sklearn.feature_selection import RFE
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, \
precision_score, auc
import os, sys
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
import pickle
import optuna
import lightgbm as lgb
from lightgbm import LGBMRegressor
import pickle

# %%
# %%bash
# pwd
# ls -ltr
# Out:
# /Users/riteshk/Library/CloudStorage/Box-Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/lgbm_trials/stratified-split-2-cv_2
# total 10496
# -rw-------@ 1 riteshk  staff   104320 Feb 13 19:28 split_dataset_strat2_cond_sl.ipynb.ipynb
# -rw-r--r--  1 riteshk  staff  2722289 Feb 13 19:28 train_qsar_stratII_cond.csv
# -rw-r--r--  1 riteshk  staff   343456 Feb 13 19:28 val_qsar_stratII_cond.csv
# -rw-r--r--  1 riteshk  staff   342499 Feb 13 19:28 test_qsar_stratII_cond.csv
# -rw-r--r--  1 riteshk  staff   297217 Feb 13 20:30 lgbm_cond_strat2_fold_1.sav
# -rw-r--r--  1 riteshk  staff   307029 Feb 13 20:30 lgbm_cond_strat2_fold_2.sav
# -rw-r--r--  1 riteshk  staff   282029 Feb 13 20:30 lgbm_cond_strat2_fold_3.sav
# -rw-r--r--  1 riteshk  staff   320281 Feb 13 20:30 lgbm_cond_strat2_fold_4.sav
# -rw-r--r--  1 riteshk  staff   306683 Feb 13 20:30 lgbm_cond_strat2_fold_5.sav
# -rw-r--r--  1 riteshk  staff    58035 Feb 14 01:10 ood_qsar_fgrp_cond.csv
# -rw-------@ 1 riteshk  staff   272868 Feb 14 01:18 cond_lgbm_strat2.ipynb

# %%
df = pd.read_csv('../random-split/all_qsar_cond.csv')
df
# Out:
#                    solv_comb_sm  \
# 0           O=C1OCCO1.COC(=O)OC
# 1        O=C1OCCO1.CCCCOC(=O)OC
# 2      O=C1OCCO1.CC(C)COC(=O)OC
# 3      O=C1OCCO1.CCC(C)OC(=O)OC
# 4                   CCOC(=O)OCC
# ...                         ...
# 10191            CS(=O)C.COCCOC
# 10192            CS(=O)C.COCCOC
# 10193            CS(=O)C.COCCOC
# 10194            CS(=O)C.COCCOC
# 10195                   CS(=O)C
#
#                                           salt_smiles  fr_func_grp_1_solv  \
# 0                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 1                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 2                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 3                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 4      [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# ...                                               ...                 ...
# 10191                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 10192                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 10193                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 10194                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 10195  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
#
#        fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 10191                   0                   0                   0
# 10192                   0                   0                   0
# 10193                   0                   0                   0
# 10194                   0                   0                   0
# 10195                   0                   0                   0
#
#        fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 10191                   0                   0                   0
# 10192                   0                   0                   0
# 10193                   0                   0                   0
# 10194                   0                   0                   0
# 10195                   0                   0                   0
#
#        fr_func_grp_8_solv  ...  fr_func_grp_40_salt  fr_func_grp_41_salt  \
# 0                       0  ...                    0                    0
# 1                       0  ...                    0                    0
# 2                       0  ...                    0                    0
# 3                       0  ...                    0                    0
# 4                       0  ...                    0                    0
# ...                   ...  ...                  ...                  ...
# 10191                   0  ...                    0                    0
# 10192                   0  ...                    0                    0
# 10193                   0  ...                    0                    0
# 10194                   0  ...                    0                    0
# 10195                   0  ...                    0                    0
#
#        fr_func_grp_42_salt  fr_func_grp_43_salt  num_heavy_atom_salt  \
# 0                        0                    0                    8
# 1                        0                    0                    8
# 2                        0                    0                    8
# 3                        0                    0                    8
# 4                        0                    0                   16
# ...                    ...                  ...                  ...
# 10191                    0                    0                    8
# 10192                    0                    0                    8
# 10193                    0                    0                    8
# 10194                    0                    0                    8
# 10195                    0                    0                   16
#
#        num_rot_bond_salt     mw_salt  conc_salt  temperature  conductivity_log
# 0                      0  144.964181        1.0         25.0          1.068186
# 1                      0  144.964181        1.0         25.0          0.770852
# 2                      0  144.964181        1.0         25.0          0.732394
# 3                      0  144.964181        1.0         25.0          0.812913
# 4                      2  279.917842        1.0         10.0          0.322219
# ...                  ...         ...        ...          ...               ...
# 10191                  0  144.964181        0.1         30.0          0.672098
# 10192                  0  144.964181        0.5         30.0          1.139879
# 10193                  0  144.964181        1.0         30.0          1.204120
# 10194                  0  144.964181        1.5         30.0          1.167317
# 10195                  2  279.917842        1.0         25.0          0.324282
#
# [10196 rows x 106 columns]

# %% [markdown]
# Read the train, validation, and test sets

# %%
train_df = pd.read_csv('train_qsar_stratII_cond.csv')
val_df = pd.read_csv('val_qsar_stratII_cond.csv')
test_df = pd.read_csv('test_qsar_stratII_cond.csv')
test_df
# Out:
#                   solv_comb_sm  \
# 0       CC1COC(=O)O1.O=C1OCCO1
# 1       CC1COC(=O)O1.O=C1OCCO1
# 2     CC1COC(=O)O1.CCOC(=O)OCC
# 3       CC1COC(=O)O1.O=C1OCCO1
# 4                      C1CCOC1
# ...                        ...
# 1015  CC1COC(=O)O1.CCOC(=O)OCC
# 1016  CC1COC(=O)O1.CCOC(=O)OCC
# 1017       O=C1OCCO1.O=C1CCCO1
# 1018    C(CCC#N)CC#N.O=C1OCCO1
# 1019  CC1COC(=O)O1.CCOC(=O)OCC
#
#                                          salt_smiles  fr_func_grp_1_solv  \
# 0                    [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 1                    [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 2                           [Li+].F[P-](F)(F)(F)(F)F                   0
# 3                CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F                   0
# 4                               [Li+].[B-](F)(F)(F)F                   0
# ...                                              ...                 ...
# 1015                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 1016                 [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 1017              [Li+].[B-](C(C(F)(F)F)(F)F)(F)(F)F                   0
# 1018  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 1019        [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 1015                   0                   0                   0
# 1016                   0                   0                   0
# 1017                   0                   0                   0
# 1018                   0                   0                   0
# 1019                   0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 1015                   0                   0                   0
# 1016                   0                   0                   0
# 1017                   0                   0                   0
# 1018                   0                   0                   0
# 1019                   0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_41_salt  fr_func_grp_42_salt  \
# 0                      0  ...                    0                    0
# 1                      0  ...                    0                    0
# 2                      0  ...                    0                    0
# 3                      0  ...                    0                    0
# 4                      0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 1015                   0  ...                    0                    0
# 1016                   0  ...                    0                    0
# 1017                   0  ...                    0                    0
# 1018                   0  ...                    0                    0
# 1019                   0  ...                    0                    0
#
#       fr_func_grp_43_salt  num_heavy_atom_salt  num_rot_bond_salt     mw_salt  \
# 0                       1                   14                  0   87.003467
# 1                       1                   14                  0   87.003467
# 2                       0                    8                  0  144.964181
# 3                       1                   16                  0  144.964181
# 4                       0                    6                  0   87.003467
# ...                   ...                  ...                ...         ...
# 1015                    0                    8                  0  144.964181
# 1016                    1                   14                  0   87.003467
# 1017                    0                   12                  1  186.997080
# 1018                    0                   16                  2  279.917842
# 1019                    0                   14                  0  186.969171
#
#       conc_salt  temperature  conductivity_log  conductivity_log_bin
# 0      1.139535       60.000          1.455510                     6
# 1      0.500000       30.000          1.042752                     6
# 2      0.897900       49.200          0.965672                     5
# 3      0.511628        0.000          0.732234                     5
# 4      0.046877       30.000         -0.670613                     4
# ...         ...          ...               ...                   ...
# 1015   0.565800       39.300          0.956553                     5
# 1016   0.074903        0.000          0.018261                     5
# 1017   1.000000      -30.352          0.355643                     5
# 1018   1.000000      -10.000          0.000000                     4
# 1019   0.390000       19.500          0.595540                     5
#
# [1020 rows x 107 columns]

# %%
## removing 'fr_func_grp_20_salt' columns from the dataframes since it contains only zero as entries, which makes it incompatible with Sobol analysis
df.drop(columns='fr_func_grp_20_salt', inplace=True)
train_df.drop(columns='fr_func_grp_20_salt', inplace=True)
val_df.drop(columns='fr_func_grp_20_salt', inplace=True)
test_df.drop(columns='fr_func_grp_20_salt', inplace=True)
train_df
# Out:
#                            solv_comb_sm  \
# 0                CC1COC(=O)O1.O=C1OCCO1
# 1              CC1COC(=O)O1.CCOC(=O)OCC
# 2              CC1COC(=O)O1.CCOC(=O)OCC
# 3              CC1COC(=O)O1.CCOC(=O)OCC
# 4                      COCCOC.O=C1CCCO1
# ...                                 ...
# 8151           CC1COC(=O)O1.CCOC(=O)OCC
# 8152                       CC1COC(=O)O1
# 8153                       CC1COC(=O)O1
# 8154  CC1COC(=O)O1.CCOC(=O)OC.COC(=O)OC
# 8155                       CCOC(=O)OCCF
#
#                                        salt_smiles  fr_func_grp_1_solv  \
# 0              CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F                   0
# 1                  [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 2                  [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 3         [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 4                         [Li+].F[P-](F)(F)(F)(F)F                   0
# ...                                            ...                 ...
# 8151                      [Li+].F[P-](F)(F)(F)(F)F                   0
# 8152  [Li+].F[P-](F)(F)(F)(F)F.COCCOCCOC.COCCOCCOC                   0
# 8153                          [Li+].[B-](F)(F)(F)F                   0
# 8154      [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 8155                      [Li+].F[P-](F)(F)(F)(F)F                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8151                   0                   0                   0
# 8152                   0                   0                   0
# 8153                   0                   0                   0
# 8154                   0                   0                   0
# 8155                   0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8151                   0                   0                   0
# 8152                   0                   0                   0
# 8153                   0                   0                   0
# 8154                   0                   0                   0
# 8155                   0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_41_salt  fr_func_grp_42_salt  \
# 0                      0  ...                    0                    0
# 1                      0  ...                    0                    0
# 2                      0  ...                    0                    0
# 3                      0  ...                    0                    0
# 4                      0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 8151                   0  ...                    0                    0
# 8152                   0  ...                    0                    0
# 8153                   0  ...                    0                    0
# 8154                   0  ...                    0                    0
# 8155                   0  ...                    0                    0
#
#       fr_func_grp_43_salt  num_heavy_atom_salt  num_rot_bond_salt     mw_salt  \
# 0                       1                   16                  0  144.964181
# 1                       1                   14                  0   87.003467
# 2                       1                   14                  0   87.003467
# 3                       0                   14                  0  186.969171
# 4                       0                    8                  0  144.964181
# ...                   ...                  ...                ...         ...
# 8151                    0                    8                  0  144.964181
# 8152                    0                   26                  0  144.964181
# 8153                    0                    6                  0   87.003467
# 8154                    0                   14                  0  186.969171
# 8155                    0                    8                  0  144.964181
#
#       conc_salt  temperature  conductivity_log  conductivity_log_bin
# 0      0.190698       60.000          0.660961                     5
# 1      1.304688       60.000          1.379852                     6
# 2      1.154882       10.000          0.982081                     5
# 3      0.240000       29.400          0.598077                     5
# 4      0.081500       25.000          0.504063                     5
# ...         ...          ...               ...                   ...
# 8151   1.230000       49.200          0.990060                     5
# 8152   0.273190       25.000          0.627673                     5
# 8153   0.000947       25.000         -1.582382                     3
# 8154   0.800000      -20.000          0.158661                     5
# 8155   1.000000        9.855          0.188084                     5
#
# [8156 rows x 106 columns]

# %%
X_train = train_df.iloc[:,2:-2]
y_train = train_df.iloc[:,-2]
X_test = test_df.iloc[:,2:-2]
y_test = test_df.iloc[:,-2]
X_val = val_df.iloc[:,2:-2]
y_val = val_df.iloc[:,-2]
X_train
# Out:
#       fr_func_grp_1_solv  fr_func_grp_2_solv  fr_func_grp_3_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8151                   0                   0                   0
# 8152                   0                   0                   0
# 8153                   0                   0                   0
# 8154                   0                   0                   0
# 8155                   0                   0                   0
#
#       fr_func_grp_4_solv  fr_func_grp_5_solv  fr_func_grp_6_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8151                   0                   0                   0
# 8152                   0                   0                   0
# 8153                   0                   0                   0
# 8154                   0                   0                   0
# 8155                   0                   0                   0
#
#       fr_func_grp_7_solv  fr_func_grp_8_solv  fr_func_grp_9_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8151                   0                   0                   0
# 8152                   0                   0                   0
# 8153                   0                   0                   0
# 8154                   0                   0                   0
# 8155                   0                   0                   0
#
#       fr_func_grp_10_solv  ...  fr_func_grp_39_salt  fr_func_grp_40_salt  \
# 0                       0  ...                    0                    0
# 1                       0  ...                    0                    0
# 2                       0  ...                    0                    0
# 3                       0  ...                    0                    0
# 4                       2  ...                    0                    0
# ...                   ...  ...                  ...                  ...
# 8151                    0  ...                    0                    0
# 8152                    0  ...                    0                    0
# 8153                    0  ...                    0                    0
# 8154                    0  ...                    0                    0
# 8155                    0  ...                    0                    0
#
#       fr_func_grp_41_salt  fr_func_grp_42_salt  fr_func_grp_43_salt  \
# 0                       0                    0                    1
# 1                       0                    0                    1
# 2                       0                    0                    1
# 3                       0                    0                    0
# 4                       0                    0                    0
# ...                   ...                  ...                  ...
# 8151                    0                    0                    0
# 8152                    0                    0                    0
# 8153                    0                    0                    0
# 8154                    0                    0                    0
# 8155                    0                    0                    0
#
#       num_heavy_atom_salt  num_rot_bond_salt     mw_salt  conc_salt  \
# 0                      16                  0  144.964181   0.190698
# 1                      14                  0   87.003467   1.304688
# 2                      14                  0   87.003467   1.154882
# 3                      14                  0  186.969171   0.240000
# 4                       8                  0  144.964181   0.081500
# ...                   ...                ...         ...        ...
# 8151                    8                  0  144.964181   1.230000
# 8152                   26                  0  144.964181   0.273190
# 8153                    6                  0   87.003467   0.000947
# 8154                   14                  0  186.969171   0.800000
# 8155                    8                  0  144.964181   1.000000
#
#       temperature
# 0          60.000
# 1          60.000
# 2          10.000
# 3          29.400
# 4          25.000
# ...           ...
# 8151       49.200
# 8152       25.000
# 8153       25.000
# 8154      -20.000
# 8155        9.855
#
# [8156 rows x 102 columns]

# %% [markdown]
# #### Step 1: Bayesian hyperparameter optimization -- not optimizing again, for fair comparison among all splits

# %%
std_scale = preprocessing.StandardScaler().fit(X_train)
X_train_std = std_scale.transform(X_train)
X_train_std = pd.DataFrame(X_train_std, columns=X_train.columns)
X_test_std  = std_scale.transform(X_test)
X_test_std = pd.DataFrame(X_test_std, columns=X_train.columns)
X_val_std  = std_scale.transform(X_val)
X_val_std = pd.DataFrame(X_val_std, columns=X_train.columns)

# %%
X_train_ = np.array(X_train_std)
X_val_ = np.array(X_val_std)
X_test_ = np.array(X_test_std)

# %%
# def objective(trial):
#     kf = KFold(n_splits=5, shuffle=True, random_state=0)

#     param = {
#         "objective": "regression",
#         "metric": "root_mean_squared_error",
#         "verbosity": -1,
#         "boosting_type": "gbdt",
#         "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
#         "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
#         "num_leaves": trial.suggest_int("num_leaves", 2, 100),
#         "num_iterations": trial.suggest_int("num_iterations", 50, 500),
#         "max_depth": trial.suggest_int("max_depth", 2, 10),
#         "max_bin": trial.suggest_int("max_bin", 2, 50),
#         "feature_fraction": trial.suggest_float("feature_fraction", 0.1, 1.0),
#         "bagging_fraction": trial.suggest_float("bagging_fraction", 0.1, 1.0),
#         "bagging_freq": trial.suggest_int("bagging_freq", 1, 10),
#         "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 5, 100),
#         "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0.1, 1.0),
#         "learning_rate": trial.suggest_float("learning_rate", 1e-2, 0.9),
#         "min_sum_hessian_in_leaf": trial.suggest_float("min_sum_hessian_in_leaf", 0.1, 0.9)
#     }

#     gbm = LGBMRegressor(**param)
#     cv = cross_val_score(gbm, X_train_, y_train, cv=kf, scoring='neg_root_mean_squared_error')
#     return -cv.mean()

# %%
# fname = 'best-paramters_lgbr_random.txt'
# f = open(fname, 'w')
# f1 = open('best-paramters_lgbr_all.txt', 'a')
# if __name__ == "__main__":
#     study = optuna.create_study(direction="minimize")
#     study.optimize(objective, n_trials=200)

#     print("Number of finished trials: {}".format(len(study.trials)))

#     print("Best trial:")
#     trial = study.best_trial

#     print("  Value: {}".format(trial.value))
#     f.write("  Value: {}\n".format(trial.value))
#     f1.write("  Value: {}\n".format(trial.value))

#     print("  Params: ")
#     for key, value in trial.params.items():
#         print("    {}: {}".format(key, value)) 
#         f.write("    {}: {}\n".format(key, value))
#         f1.write("    {}: {}\n".format(key, value))

# f.write("\n")
# f1.write("\n")
# f.close()
# f1.close()
# Out:
# [I 2024-02-10 19:33:19,950] A new study created in memory with name: no-name-61854ffc-baa3-4321-b7cf-74a53ca0b236
# [I 2024-02-10 19:33:20,433] Trial 0 finished with value: 0.30221926626631185 and parameters: {'lambda_l1': 0.368438166370631, 'lambda_l2': 6.21081359525443e-07, 'num_leaves': 62, 'num_iterations': 77, 'max_depth': 4, 'max_bin': 30, 'feature_fraction': 0.9707318548094139, 'bagging_fraction': 0.9069891570424771, 'bagging_freq': 7, 'min_data_in_leaf': 26, 'min_gain_to_split': 0.932409634507929, 'learning_rate': 0.24216496556421602, 'min_sum_hessian_in_leaf': 0.7742395895641901}. Best is trial 0 with value: 0.30221926626631185.
# [I 2024-02-10 19:33:20,825] Trial 1 finished with value: 0.36383634694837835 and parameters: {'lambda_l1': 0.0002982307855932972, 'lambda_l2': 0.0002707742673421538, 'num_leaves': 23, 'num_iterations': 146, 'max_depth': 3, 'max_bin': 19, 'feature_fraction': 0.9769354635374254, 'bagging_fraction': 0.26808375838714243, 'bagging_freq': 10, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.6949695876147431, 'learning_rate': 0.28076990194197415, 'min_sum_hessian_in_leaf': 0.8119118276860897}. Best is trial 0 with value: 0.30221926626631185.
# [I 2024-02-10 19:33:21,556] Trial 2 finished with value: 0.345262813880674 and parameters: {'lambda_l1': 3.5621104685794196e-05, 'lambda_l2': 5.407846621178877e-07, 'num_leaves': 27, 'num_iterations': 234, 'max_depth': 4, 'max_bin': 50, 'feature_fraction': 0.2584716785621535, 'bagging_fraction': 0.16774272811040453, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.9050742857349435, 'learning_rate': 0.17121755334291855, 'min_sum_hessian_in_leaf': 0.404041260831568}. Best is trial 0 with value: 0.30221926626631185.
# [I 2024-02-10 19:33:22,294] Trial 3 finished with value: 0.32417197101494866 and parameters: {'lambda_l1': 0.5394414885572267, 'lambda_l2': 3.5877812021289465e-05, 'num_leaves': 10, 'num_iterations': 224, 'max_depth': 5, 'max_bin': 41, 'feature_fraction': 0.20140370589820983, 'bagging_fraction': 0.8550780791145447, 'bagging_freq': 4, 'min_data_in_leaf': 60, 'min_gain_to_split': 0.4476667252638976, 'learning_rate': 0.6501824556389042, 'min_sum_hessian_in_leaf': 0.5424718402860546}. Best is trial 0 with value: 0.30221926626631185.
# [I 2024-02-10 19:33:24,125] Trial 4 finished with value: 0.24332338649331797 and parameters: {'lambda_l1': 0.005545306573436437, 'lambda_l2': 2.4956842695159895e-05, 'num_leaves': 52, 'num_iterations': 261, 'max_depth': 4, 'max_bin': 22, 'feature_fraction': 0.3716234317309402, 'bagging_fraction': 0.4450698859763561, 'bagging_freq': 3, 'min_data_in_leaf': 6, 'min_gain_to_split': 0.10291069580867436, 'learning_rate': 0.2939873326827835, 'min_sum_hessian_in_leaf': 0.6858546029303872}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:27,175] Trial 5 finished with value: 0.2950653797936778 and parameters: {'lambda_l1': 2.7418333793379198e-08, 'lambda_l2': 1.2300591676673203e-08, 'num_leaves': 92, 'num_iterations': 412, 'max_depth': 9, 'max_bin': 41, 'feature_fraction': 0.6191421363241327, 'bagging_fraction': 0.17688593097987068, 'bagging_freq': 3, 'min_data_in_leaf': 35, 'min_gain_to_split': 0.10210649005914078, 'learning_rate': 0.7134606383919383, 'min_sum_hessian_in_leaf': 0.6465782987972722}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:28,314] Trial 6 finished with value: 0.3394090960185184 and parameters: {'lambda_l1': 0.003491976211132742, 'lambda_l2': 1.4435277709251333e-08, 'num_leaves': 6, 'num_iterations': 420, 'max_depth': 8, 'max_bin': 18, 'feature_fraction': 0.27173592108209066, 'bagging_fraction': 0.9611368465819125, 'bagging_freq': 1, 'min_data_in_leaf': 61, 'min_gain_to_split': 0.670324606261597, 'learning_rate': 0.7267230433211118, 'min_sum_hessian_in_leaf': 0.56802034472342}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:29,213] Trial 7 finished with value: 0.30963778180995233 and parameters: {'lambda_l1': 0.2725403128437235, 'lambda_l2': 5.5698119331405136e-08, 'num_leaves': 90, 'num_iterations': 121, 'max_depth': 5, 'max_bin': 18, 'feature_fraction': 0.6251727345405209, 'bagging_fraction': 0.47802253936796296, 'bagging_freq': 3, 'min_data_in_leaf': 26, 'min_gain_to_split': 0.45116742376905605, 'learning_rate': 0.13536758229837292, 'min_sum_hessian_in_leaf': 0.5393639022716132}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:30,617] Trial 8 finished with value: 0.3167536793131548 and parameters: {'lambda_l1': 1.2981618092682683e-05, 'lambda_l2': 0.080634703653771, 'num_leaves': 40, 'num_iterations': 465, 'max_depth': 8, 'max_bin': 21, 'feature_fraction': 0.33558803717168056, 'bagging_fraction': 0.9594194221228329, 'bagging_freq': 3, 'min_data_in_leaf': 26, 'min_gain_to_split': 0.38102769535521086, 'learning_rate': 0.628490892002856, 'min_sum_hessian_in_leaf': 0.197552710332368}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:31,222] Trial 9 finished with value: 0.31481031142838195 and parameters: {'lambda_l1': 4.211894134637252e-06, 'lambda_l2': 0.00228126829192979, 'num_leaves': 78, 'num_iterations': 248, 'max_depth': 4, 'max_bin': 24, 'feature_fraction': 0.6636736633126452, 'bagging_fraction': 0.89840913655461, 'bagging_freq': 9, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.8574731792575704, 'learning_rate': 0.7362015259418411, 'min_sum_hessian_in_leaf': 0.47873721430493527}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:32,264] Trial 10 finished with value: 0.5657331121980246 and parameters: {'lambda_l1': 0.007420204355802218, 'lambda_l2': 4.262250051476586, 'num_leaves': 58, 'num_iterations': 342, 'max_depth': 2, 'max_bin': 3, 'feature_fraction': 0.1204535044690288, 'bagging_fraction': 0.5965352459226402, 'bagging_freq': 6, 'min_data_in_leaf': 90, 'min_gain_to_split': 0.20267203511840967, 'learning_rate': 0.4204221747591528, 'min_sum_hessian_in_leaf': 0.8437471300085987}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:34,616] Trial 11 finished with value: 0.4298660085811994 and parameters: {'lambda_l1': 2.15875230630916e-08, 'lambda_l2': 5.988736656470861e-06, 'num_leaves': 93, 'num_iterations': 350, 'max_depth': 10, 'max_bin': 37, 'feature_fraction': 0.4293278641790155, 'bagging_fraction': 0.10337163858539752, 'bagging_freq': 1, 'min_data_in_leaf': 49, 'min_gain_to_split': 0.1539874010760088, 'learning_rate': 0.89119114469732, 'min_sum_hessian_in_leaf': 0.6526155451946885}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:36,842] Trial 12 finished with value: 0.3547509004964925 and parameters: {'lambda_l1': 3.6745756107945024e-08, 'lambda_l2': 1.6477754213749252e-08, 'num_leaves': 73, 'num_iterations': 338, 'max_depth': 7, 'max_bin': 8, 'feature_fraction': 0.4863187083228056, 'bagging_fraction': 0.32785969705572326, 'bagging_freq': 4, 'min_data_in_leaf': 76, 'min_gain_to_split': 0.10087502073819503, 'learning_rate': 0.49737824145425436, 'min_sum_hessian_in_leaf': 0.667487929011476}. Best is trial 4 with value: 0.24332338649331797.
# [I 2024-02-10 19:33:41,335] Trial 13 finished with value: 0.24329810333300586 and parameters: {'lambda_l1': 1.2457733021780304e-06, 'lambda_l2': 4.50418567282325e-06, 'num_leaves': 43, 'num_iterations': 407, 'max_depth': 10, 'max_bin': 34, 'feature_fraction': 0.578422300869688, 'bagging_fraction': 0.3944359388499147, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.2784560767235174, 'learning_rate': 0.043832149901975204, 'min_sum_hessian_in_leaf': 0.7058398459686344}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:46,559] Trial 14 finished with value: 0.32160533629730326 and parameters: {'lambda_l1': 6.927376939498329, 'lambda_l2': 1.654599628588092e-05, 'num_leaves': 43, 'num_iterations': 499, 'max_depth': 6, 'max_bin': 32, 'feature_fraction': 0.40339953926575706, 'bagging_fraction': 0.4737202829652903, 'bagging_freq': 2, 'min_data_in_leaf': 6, 'min_gain_to_split': 0.2874870247056387, 'learning_rate': 0.02011677726107347, 'min_sum_hessian_in_leaf': 0.875619252710286}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:53,470] Trial 15 finished with value: 0.278140205123559 and parameters: {'lambda_l1': 1.0734431900633677e-06, 'lambda_l2': 0.00045939489642794214, 'num_leaves': 45, 'num_iterations': 297, 'max_depth': 10, 'max_bin': 29, 'feature_fraction': 0.5203519163168457, 'bagging_fraction': 0.5971863315104788, 'bagging_freq': 5, 'min_data_in_leaf': 17, 'min_gain_to_split': 0.27887987302780143, 'learning_rate': 0.017729745286528212, 'min_sum_hessian_in_leaf': 0.7402039850426043}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:54,229] Trial 16 finished with value: 0.31823444235722426 and parameters: {'lambda_l1': 5.171990882162597e-07, 'lambda_l2': 2.6199643613670775e-06, 'num_leaves': 25, 'num_iterations': 187, 'max_depth': 2, 'max_bin': 13, 'feature_fraction': 0.7594508437633181, 'bagging_fraction': 0.35018636535417236, 'bagging_freq': 2, 'min_data_in_leaf': 18, 'min_gain_to_split': 0.23624678599806148, 'learning_rate': 0.33115549684337325, 'min_sum_hessian_in_leaf': 0.8934683642254196}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:55,840] Trial 17 finished with value: 0.28575262582631794 and parameters: {'lambda_l1': 0.00022540745769855647, 'lambda_l2': 7.760422846285199e-05, 'num_leaves': 58, 'num_iterations': 290, 'max_depth': 6, 'max_bin': 35, 'feature_fraction': 0.38168223493976594, 'bagging_fraction': 0.6943396000019333, 'bagging_freq': 7, 'min_data_in_leaf': 44, 'min_gain_to_split': 0.31485268076450706, 'learning_rate': 0.13545507800981066, 'min_sum_hessian_in_leaf': 0.7397671252309177}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:57,213] Trial 18 finished with value: 0.30541458388814 and parameters: {'lambda_l1': 0.00503282834859011, 'lambda_l2': 3.4894381100007206e-07, 'num_leaves': 73, 'num_iterations': 396, 'max_depth': 7, 'max_bin': 50, 'feature_fraction': 0.49599971209728716, 'bagging_fraction': 0.41816342412306795, 'bagging_freq': 5, 'min_data_in_leaf': 94, 'min_gain_to_split': 0.18224672518820736, 'learning_rate': 0.3826645352886618, 'min_sum_hessian_in_leaf': 0.709642391297654}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:33:58,890] Trial 19 finished with value: 0.2885186956981554 and parameters: {'lambda_l1': 5.036380649124991e-07, 'lambda_l2': 4.798478139661943e-06, 'num_leaves': 36, 'num_iterations': 375, 'max_depth': 9, 'max_bin': 25, 'feature_fraction': 0.3324626292788297, 'bagging_fraction': 0.3931651353115974, 'bagging_freq': 2, 'min_data_in_leaf': 18, 'min_gain_to_split': 0.35942889555802504, 'learning_rate': 0.22977235073497504, 'min_sum_hessian_in_leaf': 0.7972267808829304}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:34:00,991] Trial 20 finished with value: 0.3653334981616255 and parameters: {'lambda_l1': 4.532086737314039e-05, 'lambda_l2': 0.003614343374736404, 'num_leaves': 51, 'num_iterations': 454, 'max_depth': 3, 'max_bin': 12, 'feature_fraction': 0.4433464901745695, 'bagging_fraction': 0.2693722238869462, 'bagging_freq': 4, 'min_data_in_leaf': 75, 'min_gain_to_split': 0.2058173666964206, 'learning_rate': 0.10158207144985518, 'min_sum_hessian_in_leaf': 0.6127672033907531}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:34:05,430] Trial 21 finished with value: 0.26354944983032125 and parameters: {'lambda_l1': 1.5074996123673311e-06, 'lambda_l2': 0.0005725827727308499, 'num_leaves': 47, 'num_iterations': 301, 'max_depth': 10, 'max_bin': 29, 'feature_fraction': 0.5400143798381145, 'bagging_fraction': 0.5666634155756433, 'bagging_freq': 5, 'min_data_in_leaf': 18, 'min_gain_to_split': 0.2704219611453919, 'learning_rate': 0.03841431238348292, 'min_sum_hessian_in_leaf': 0.7176802419044457}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:34:09,146] Trial 22 finished with value: 0.25298081766777686 and parameters: {'lambda_l1': 4.015714662402184e-06, 'lambda_l2': 2.9248652087989588e-05, 'num_leaves': 51, 'num_iterations': 307, 'max_depth': 10, 'max_bin': 42, 'feature_fraction': 0.5245184008171617, 'bagging_fraction': 0.501909945708886, 'bagging_freq': 6, 'min_data_in_leaf': 15, 'min_gain_to_split': 0.25948216356835474, 'learning_rate': 0.05243800146636382, 'min_sum_hessian_in_leaf': 0.7001697987940038}. Best is trial 13 with value: 0.24329810333300586.
# [I 2024-02-10 19:34:10,490] Trial 23 finished with value: 0.24048762349495872 and parameters: {'lambda_l1': 1.772321578981252e-07, 'lambda_l2': 3.7278266607654035e-05, 'num_leaves': 33, 'num_iterations': 278, 'max_depth': 9, 'max_bin': 41, 'feature_fraction': 0.602724765459584, 'bagging_fraction': 0.48424597115836626, 'bagging_freq': 7, 'min_data_in_leaf': 6, 'min_gain_to_split': 0.16092894819035, 'learning_rate': 0.19697920182649736, 'min_sum_hessian_in_leaf': 0.7873008453754773}. Best is trial 23 with value: 0.24048762349495872.
# [I 2024-02-10 19:34:11,681] Trial 24 finished with value: 0.23676739591192214 and parameters: {'lambda_l1': 1.1659771625755315e-07, 'lambda_l2': 2.2649063631628167e-06, 'num_leaves': 35, 'num_iterations': 197, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.7104582702301379, 'bagging_fraction': 0.4544172915729512, 'bagging_freq': 8, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.13483217730856684, 'learning_rate': 0.18961634990043189, 'min_sum_hessian_in_leaf': 0.805184389061129}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:12,681] Trial 25 finished with value: 0.26921654134676654 and parameters: {'lambda_l1': 1.253254048922148e-07, 'lambda_l2': 1.4903562714870882e-06, 'num_leaves': 17, 'num_iterations': 195, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.7212735543502112, 'bagging_fraction': 0.5279307450626419, 'bagging_freq': 8, 'min_data_in_leaf': 34, 'min_gain_to_split': 0.17428080666806248, 'learning_rate': 0.1939164927493223, 'min_sum_hessian_in_leaf': 0.8115353138778221}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:14,258] Trial 26 finished with value: 0.2670487914764646 and parameters: {'lambda_l1': 1.0521384640216642e-08, 'lambda_l2': 1.5136595010958275e-07, 'num_leaves': 32, 'num_iterations': 159, 'max_depth': 8, 'max_bin': 46, 'feature_fraction': 0.5938390749884694, 'bagging_fraction': 0.38922905447467204, 'bagging_freq': 8, 'min_data_in_leaf': 13, 'min_gain_to_split': 0.3459396485460683, 'learning_rate': 0.09451353513676965, 'min_sum_hessian_in_leaf': 0.8830223813686753}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:15,144] Trial 27 finished with value: 0.26357989459080017 and parameters: {'lambda_l1': 1.2841562483480347e-07, 'lambda_l2': 4.078020243918179e-06, 'num_leaves': 33, 'num_iterations': 50, 'max_depth': 9, 'max_bin': 38, 'feature_fraction': 0.7581359766259772, 'bagging_fraction': 0.69804532614506, 'bagging_freq': 8, 'min_data_in_leaf': 26, 'min_gain_to_split': 0.16064565581613266, 'learning_rate': 0.18877865030596427, 'min_sum_hessian_in_leaf': 0.7769485296943387}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:16,300] Trial 28 finished with value: 0.2608655370190228 and parameters: {'lambda_l1': 1.354076082431459e-07, 'lambda_l2': 1.4156746647093966e-07, 'num_leaves': 21, 'num_iterations': 211, 'max_depth': 7, 'max_bin': 34, 'feature_fraction': 0.8288119828257186, 'bagging_fraction': 0.32902712979710713, 'bagging_freq': 7, 'min_data_in_leaf': 6, 'min_gain_to_split': 0.23146407097590332, 'learning_rate': 0.11663298489630668, 'min_sum_hessian_in_leaf': 0.8426841051280084}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:16,822] Trial 29 finished with value: 0.2930267200377175 and parameters: {'lambda_l1': 2.790899276584112e-07, 'lambda_l2': 5.691344833481796e-07, 'num_leaves': 16, 'num_iterations': 109, 'max_depth': 8, 'max_bin': 46, 'feature_fraction': 0.8699480628415086, 'bagging_fraction': 0.4327849279321888, 'bagging_freq': 9, 'min_data_in_leaf': 23, 'min_gain_to_split': 0.4243525148873421, 'learning_rate': 0.23325667306208367, 'min_sum_hessian_in_leaf': 0.7636495878275413}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:17,409] Trial 30 finished with value: 0.30646865393287037 and parameters: {'lambda_l1': 5.676523663411575e-08, 'lambda_l2': 1.0624150768422398e-06, 'num_leaves': 64, 'num_iterations': 98, 'max_depth': 9, 'max_bin': 38, 'feature_fraction': 0.6748290179941906, 'bagging_fraction': 0.5258295502214757, 'bagging_freq': 6, 'min_data_in_leaf': 41, 'min_gain_to_split': 0.5053340998843039, 'learning_rate': 0.25721808061489587, 'min_sum_hessian_in_leaf': 0.7784650251204258}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:18,491] Trial 31 finished with value: 0.25611347133277235 and parameters: {'lambda_l1': 2.2830225581432124e-06, 'lambda_l2': 9.881228998515325e-06, 'num_leaves': 38, 'num_iterations': 260, 'max_depth': 5, 'max_bin': 31, 'feature_fraction': 0.5720384194663235, 'bagging_fraction': 0.4479098128876195, 'bagging_freq': 7, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.15568830373320242, 'learning_rate': 0.29790086541365124, 'min_sum_hessian_in_leaf': 0.6908213214368453}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:19,433] Trial 32 finished with value: 0.25529456106930193 and parameters: {'lambda_l1': 3.9442877433724026e-07, 'lambda_l2': 8.195681455092325e-05, 'num_leaves': 29, 'num_iterations': 148, 'max_depth': 10, 'max_bin': 43, 'feature_fraction': 0.574495184221691, 'bagging_fraction': 0.44400277356818807, 'bagging_freq': 9, 'min_data_in_leaf': 14, 'min_gain_to_split': 0.11763034097258553, 'learning_rate': 0.3326477241420278, 'min_sum_hessian_in_leaf': 0.8268051012285083}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:21,251] Trial 33 finished with value: 0.24412658802141948 and parameters: {'lambda_l1': 1.1424558614626821e-08, 'lambda_l2': 1.2750382836920814e-05, 'num_leaves': 54, 'num_iterations': 268, 'max_depth': 4, 'max_bin': 48, 'feature_fraction': 0.662939388820141, 'bagging_fraction': 0.28617605030991866, 'bagging_freq': 1, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.22107873573774736, 'learning_rate': 0.1660362399205688, 'min_sum_hessian_in_leaf': 0.758083343293349}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:22,282] Trial 34 finished with value: 0.2711017870054205 and parameters: {'lambda_l1': 8.706585837651801e-06, 'lambda_l2': 1.7424223651636802e-06, 'num_leaves': 66, 'num_iterations': 173, 'max_depth': 3, 'max_bin': 27, 'feature_fraction': 0.4806110250108019, 'bagging_fraction': 0.3846506038334335, 'bagging_freq': 7, 'min_data_in_leaf': 11, 'min_gain_to_split': 0.10233008818815015, 'learning_rate': 0.2163778616570614, 'min_sum_hessian_in_leaf': 0.63284795510432}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:23,111] Trial 35 finished with value: 0.3089134068071406 and parameters: {'lambda_l1': 7.053079576814679e-08, 'lambda_l2': 5.61045482791049e-05, 'num_leaves': 46, 'num_iterations': 226, 'max_depth': 6, 'max_bin': 39, 'feature_fraction': 0.5798183242897831, 'bagging_fraction': 0.35408293199715907, 'bagging_freq': 10, 'min_data_in_leaf': 33, 'min_gain_to_split': 0.31796296528700074, 'learning_rate': 0.26166216477600035, 'min_sum_hessian_in_leaf': 0.8138944230582096}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:25,054] Trial 36 finished with value: 0.2738443558288598 and parameters: {'lambda_l1': 1.1466446172048995e-06, 'lambda_l2': 0.0001467932282599425, 'num_leaves': 37, 'num_iterations': 321, 'max_depth': 9, 'max_bin': 21, 'feature_fraction': 0.4594960763481541, 'bagging_fraction': 0.477723395630336, 'bagging_freq': 8, 'min_data_in_leaf': 22, 'min_gain_to_split': 0.14140891467497124, 'learning_rate': 0.1863409385847204, 'min_sum_hessian_in_leaf': 0.697647292087721}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:27,033] Trial 37 finished with value: 0.2939736798616792 and parameters: {'lambda_l1': 3.281866594126358e-05, 'lambda_l2': 1.8346868992366963e-05, 'num_leaves': 27, 'num_iterations': 243, 'max_depth': 8, 'max_bin': 34, 'feature_fraction': 0.638248383646574, 'bagging_fraction': 0.22269398172014243, 'bagging_freq': 3, 'min_data_in_leaf': 30, 'min_gain_to_split': 0.20678114434238679, 'learning_rate': 0.08217101632042645, 'min_sum_hessian_in_leaf': 0.599176618400406}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:29,315] Trial 38 finished with value: 0.24153972535063878 and parameters: {'lambda_l1': 2.1463058654501707e-07, 'lambda_l2': 2.783595069979413e-06, 'num_leaves': 42, 'num_iterations': 202, 'max_depth': 10, 'max_bin': 41, 'feature_fraction': 0.5467391373452892, 'bagging_fraction': 0.3033145200732645, 'bagging_freq': 2, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.14474546424163828, 'learning_rate': 0.15412461722735882, 'min_sum_hessian_in_leaf': 0.6577520987642422}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:30,815] Trial 39 finished with value: 0.30689946212846164 and parameters: {'lambda_l1': 2.7257301418406194e-07, 'lambda_l2': 8.161684832602465e-07, 'num_leaves': 20, 'num_iterations': 206, 'max_depth': 10, 'max_bin': 44, 'feature_fraction': 0.6030492734789217, 'bagging_fraction': 0.2943074677517828, 'bagging_freq': 2, 'min_data_in_leaf': 59, 'min_gain_to_split': 0.2455901257052566, 'learning_rate': 0.15300337132747338, 'min_sum_hessian_in_leaf': 0.7391783762669808}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:32,729] Trial 40 finished with value: 0.2649172630936157 and parameters: {'lambda_l1': 3.7591784246208854e-08, 'lambda_l2': 3.543754367710691e-06, 'num_leaves': 42, 'num_iterations': 127, 'max_depth': 9, 'max_bin': 40, 'feature_fraction': 0.7091557802542974, 'bagging_fraction': 0.22069953649265067, 'bagging_freq': 4, 'min_data_in_leaf': 11, 'min_gain_to_split': 0.1581645505680715, 'learning_rate': 0.07853778179564952, 'min_sum_hessian_in_leaf': 0.6569253892219312}. Best is trial 24 with value: 0.23676739591192214.
# [I 2024-02-10 19:34:35,753] Trial 41 finished with value: 0.2212275043828978 and parameters: {'lambda_l1': 1.2427127927303537e-07, 'lambda_l2': 1.0421423960345945e-05, 'num_leaves': 33, 'num_iterations': 280, 'max_depth': 10, 'max_bin': 48, 'feature_fraction': 0.5613379295279729, 'bagging_fraction': 0.3818429433753234, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.13276839252516934, 'learning_rate': 0.14386377706841422, 'min_sum_hessian_in_leaf': 0.5946064364443491}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:37,900] Trial 42 finished with value: 0.2337728026768801 and parameters: {'lambda_l1': 1.4071428160689314e-07, 'lambda_l2': 3.413109148751311e-05, 'num_leaves': 32, 'num_iterations': 281, 'max_depth': 10, 'max_bin': 50, 'feature_fraction': 0.5201336199521452, 'bagging_fraction': 0.3815430128071246, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.19785548986137383, 'learning_rate': 0.13882570065756644, 'min_sum_hessian_in_leaf': 0.5925595781738348}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:40,495] Trial 43 finished with value: 0.23452562425936815 and parameters: {'lambda_l1': 1.0423090023683957e-07, 'lambda_l2': 3.416733015404407e-05, 'num_leaves': 10, 'num_iterations': 282, 'max_depth': 10, 'max_bin': 48, 'feature_fraction': 0.5266558204821834, 'bagging_fraction': 0.31353268377111965, 'bagging_freq': 1, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.14141914774570696, 'learning_rate': 0.14322521449431433, 'min_sum_hessian_in_leaf': 0.5786445925146606}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:42,074] Trial 44 finished with value: 0.2895283416176385 and parameters: {'lambda_l1': 6.260047454842534e-08, 'lambda_l2': 3.653017665906518e-05, 'num_leaves': 4, 'num_iterations': 285, 'max_depth': 9, 'max_bin': 49, 'feature_fraction': 0.5056268406957419, 'bagging_fraction': 0.3590735227289377, 'bagging_freq': 1, 'min_data_in_leaf': 21, 'min_gain_to_split': 0.18970589706321328, 'learning_rate': 0.12143518669777531, 'min_sum_hessian_in_leaf': 0.47273529654465757}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:44,653] Trial 45 finished with value: 0.22352906241182616 and parameters: {'lambda_l1': 1.8731051376815104e-08, 'lambda_l2': 0.00023865140364740472, 'num_leaves': 10, 'num_iterations': 321, 'max_depth': 10, 'max_bin': 47, 'feature_fraction': 0.6329064272848755, 'bagging_fraction': 0.3175730056819508, 'bagging_freq': 1, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.1232632992249662, 'learning_rate': 0.19702598043519207, 'min_sum_hessian_in_leaf': 0.5732996326670821}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:47,913] Trial 46 finished with value: 0.23826880076021095 and parameters: {'lambda_l1': 2.1736937058752016e-08, 'lambda_l2': 0.0002256875596948741, 'num_leaves': 11, 'num_iterations': 371, 'max_depth': 10, 'max_bin': 47, 'feature_fraction': 0.44743305181366994, 'bagging_fraction': 0.25164684890465405, 'bagging_freq': 1, 'min_data_in_leaf': 14, 'min_gain_to_split': 0.11984285575680734, 'learning_rate': 0.15821290844591762, 'min_sum_hessian_in_leaf': 0.5584765493708763}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:50,781] Trial 47 finished with value: 0.2349206027663095 and parameters: {'lambda_l1': 2.6919215512088337e-08, 'lambda_l2': 1.4941433477640592e-05, 'num_leaves': 11, 'num_iterations': 322, 'max_depth': 10, 'max_bin': 50, 'feature_fraction': 0.6335143079626049, 'bagging_fraction': 0.3177071480783542, 'bagging_freq': 3, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.10400073230612163, 'learning_rate': 0.0685332073260261, 'min_sum_hessian_in_leaf': 0.584602251551994}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:53,309] Trial 48 finished with value: 0.33722646120769806 and parameters: {'lambda_l1': 1.0270372666259887e-08, 'lambda_l2': 1.3301796330051617e-05, 'num_leaves': 9, 'num_iterations': 319, 'max_depth': 10, 'max_bin': 50, 'feature_fraction': 0.6317747328660743, 'bagging_fraction': 0.3233084090993858, 'bagging_freq': 3, 'min_data_in_leaf': 25, 'min_gain_to_split': 0.20044260374256917, 'learning_rate': 0.014751350241147904, 'min_sum_hessian_in_leaf': 0.5096902003885273}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:54,479] Trial 49 finished with value: 0.3955651980218979 and parameters: {'lambda_l1': 2.3958399657898858e-08, 'lambda_l2': 0.00017209255959851037, 'num_leaves': 2, 'num_iterations': 357, 'max_depth': 10, 'max_bin': 47, 'feature_fraction': 0.557793788802932, 'bagging_fraction': 0.1575972483917278, 'bagging_freq': 1, 'min_data_in_leaf': 30, 'min_gain_to_split': 0.10018290311601803, 'learning_rate': 0.06910582924516975, 'min_sum_hessian_in_leaf': 0.5795082575357179}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:56,723] Trial 50 finished with value: 0.2673910766042895 and parameters: {'lambda_l1': 4.565902994973974e-08, 'lambda_l2': 0.000563013695292192, 'num_leaves': 14, 'num_iterations': 322, 'max_depth': 8, 'max_bin': 50, 'feature_fraction': 0.5395167960272125, 'bagging_fraction': 0.22769460749388487, 'bagging_freq': 3, 'min_data_in_leaf': 19, 'min_gain_to_split': 0.23329477255765235, 'learning_rate': 0.10712139255911549, 'min_sum_hessian_in_leaf': 0.5195180357716949}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:34:58,432] Trial 51 finished with value: 0.2447164503006753 and parameters: {'lambda_l1': 7.552067265031442e-08, 'lambda_l2': 8.748498691154408e-06, 'num_leaves': 7, 'num_iterations': 254, 'max_depth': 10, 'max_bin': 44, 'feature_fraction': 0.6239577408523652, 'bagging_fraction': 0.35654374237224545, 'bagging_freq': 2, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.133145808202855, 'learning_rate': 0.1317420429148716, 'min_sum_hessian_in_leaf': 0.6072349745934988}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:00,374] Trial 52 finished with value: 0.23397670634128861 and parameters: {'lambda_l1': 7.093122708379681e-07, 'lambda_l2': 2.1764966138287696e-05, 'num_leaves': 13, 'num_iterations': 238, 'max_depth': 9, 'max_bin': 47, 'feature_fraction': 0.6680525309948322, 'bagging_fraction': 0.3232424142905239, 'bagging_freq': 1, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.179280326674377, 'learning_rate': 0.22032201138069782, 'min_sum_hessian_in_leaf': 0.5550731765273772}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:02,759] Trial 53 finished with value: 0.2669812147988481 and parameters: {'lambda_l1': 7.039140089454856e-07, 'lambda_l2': 8.090851014782445e-05, 'num_leaves': 11, 'num_iterations': 240, 'max_depth': 10, 'max_bin': 48, 'feature_fraction': 0.49582851017379853, 'bagging_fraction': 0.3017826605758573, 'bagging_freq': 1, 'min_data_in_leaf': 15, 'min_gain_to_split': 0.18484072207518798, 'learning_rate': 0.06204045538912692, 'min_sum_hessian_in_leaf': 0.5786581962809646}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:03,977] Trial 54 finished with value: 0.26772246598031973 and parameters: {'lambda_l1': 5.281139112472776e-07, 'lambda_l2': 7.843694663296169e-06, 'num_leaves': 24, 'num_iterations': 345, 'max_depth': 10, 'max_bin': 48, 'feature_fraction': 0.6536037815430343, 'bagging_fraction': 0.2605096466502349, 'bagging_freq': 2, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.3063465312483308, 'learning_rate': 0.23867631608879075, 'min_sum_hessian_in_leaf': 0.5482121075501835}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:06,031] Trial 55 finished with value: 0.3012900384560158 and parameters: {'lambda_l1': 2.7638788354854705e-08, 'lambda_l2': 3.1142299852983874e-05, 'num_leaves': 99, 'num_iterations': 274, 'max_depth': 9, 'max_bin': 43, 'feature_fraction': 0.6107008253972921, 'bagging_fraction': 0.41436078508442387, 'bagging_freq': 1, 'min_data_in_leaf': 82, 'min_gain_to_split': 0.24799325878817796, 'learning_rate': 0.13274045267848317, 'min_sum_hessian_in_leaf': 0.4747923781970233}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:08,741] Trial 56 finished with value: 0.25241835897672954 and parameters: {'lambda_l1': 2.830355085986913e-07, 'lambda_l2': 1.8094199749906133e-05, 'num_leaves': 17, 'num_iterations': 305, 'max_depth': 10, 'max_bin': 50, 'feature_fraction': 0.41785797882826436, 'bagging_fraction': 0.323179909548696, 'bagging_freq': 2, 'min_data_in_leaf': 13, 'min_gain_to_split': 0.19134466712150833, 'learning_rate': 0.09128307853273351, 'min_sum_hessian_in_leaf': 0.6340489367579928}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:11,644] Trial 57 finished with value: 0.23110706597650071 and parameters: {'lambda_l1': 2.101616029089543e-08, 'lambda_l2': 6.393621254631412e-05, 'num_leaves': 13, 'num_iterations': 328, 'max_depth': 9, 'max_bin': 46, 'feature_fraction': 0.5259433575562598, 'bagging_fraction': 0.36614767670803017, 'bagging_freq': 1, 'min_data_in_leaf': 20, 'min_gain_to_split': 0.10418372871430878, 'learning_rate': 0.28165218632075373, 'min_sum_hessian_in_leaf': 0.5331217581817919}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:14,086] Trial 58 finished with value: 0.2569481813674187 and parameters: {'lambda_l1': 7.058499329913882e-08, 'lambda_l2': 0.0009331656683751194, 'num_leaves': 6, 'num_iterations': 391, 'max_depth': 8, 'max_bin': 46, 'feature_fraction': 0.5288170059855822, 'bagging_fraction': 0.3718535901015862, 'bagging_freq': 1, 'min_data_in_leaf': 17, 'min_gain_to_split': 0.265119243414361, 'learning_rate': 0.28274335536794015, 'min_sum_hessian_in_leaf': 0.5351182450714823}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:15,940] Trial 59 finished with value: 0.29799785899913617 and parameters: {'lambda_l1': 8.1503635427259e-07, 'lambda_l2': 0.00012291232851720316, 'num_leaves': 21, 'num_iterations': 229, 'max_depth': 9, 'max_bin': 43, 'feature_fraction': 0.4701905160734994, 'bagging_fraction': 0.34774854466990507, 'bagging_freq': 1, 'min_data_in_leaf': 65, 'min_gain_to_split': 0.2155263798290375, 'learning_rate': 0.21258307190763565, 'min_sum_hessian_in_leaf': 0.4455213855798623}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:18,348] Trial 60 finished with value: 0.23865043575241335 and parameters: {'lambda_l1': 2.5803645463991417e-06, 'lambda_l2': 5.98143018643824e-05, 'num_leaves': 13, 'num_iterations': 293, 'max_depth': 9, 'max_bin': 48, 'feature_fraction': 0.5609473957452423, 'bagging_fraction': 0.4050877263500211, 'bagging_freq': 2, 'min_data_in_leaf': 21, 'min_gain_to_split': 0.136886909448048, 'learning_rate': 0.21886370876365607, 'min_sum_hessian_in_leaf': 0.5446005379513437}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:19,702] Trial 61 finished with value: 0.3522138531051176 and parameters: {'lambda_l1': 1.704238515614941e-08, 'lambda_l2': 0.00026620295196074986, 'num_leaves': 2, 'num_iterations': 333, 'max_depth': 10, 'max_bin': 45, 'feature_fraction': 0.5116702035977949, 'bagging_fraction': 0.27396102730489086, 'bagging_freq': 1, 'min_data_in_leaf': 8, 'min_gain_to_split': 0.11306398793124407, 'learning_rate': 0.16909363834484575, 'min_sum_hessian_in_leaf': 0.5904244553324068}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:21,780] Trial 62 finished with value: 0.2413767220137811 and parameters: {'lambda_l1': 3.562497851727313e-08, 'lambda_l2': 2.605687425098244e-05, 'num_leaves': 9, 'num_iterations': 316, 'max_depth': 10, 'max_bin': 47, 'feature_fraction': 0.6037937190496525, 'bagging_fraction': 0.3866095939346341, 'bagging_freq': 3, 'min_data_in_leaf': 11, 'min_gain_to_split': 0.17033766310210424, 'learning_rate': 0.14208782537583076, 'min_sum_hessian_in_leaf': 0.5707146330246199}. Best is trial 41 with value: 0.2212275043828978.
# [I 2024-02-10 19:35:26,372] Trial 63 finished with value: 0.21439140960684977 and parameters: {'lambda_l1': 1.2783847703233447e-07, 'lambda_l2': 8.543374111746093e-06, 'num_leaves': 19, 'num_iterations': 359, 'max_depth': 9, 'max_bin': 50, 'feature_fraction': 0.6780255528584056, 'bagging_fraction': 0.3248557516027664, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.10415125552305078, 'learning_rate': 0.04666952215138398, 'min_sum_hessian_in_leaf': 0.6166145470652705}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:30,737] Trial 64 finished with value: 0.23197243861677305 and parameters: {'lambda_l1': 1.451463749323146e-07, 'lambda_l2': 5.921112998603994e-06, 'num_leaves': 19, 'num_iterations': 367, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.6831948879237664, 'bagging_fraction': 0.3419953724515882, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.17485220753865188, 'learning_rate': 0.03757631902826057, 'min_sum_hessian_in_leaf': 0.617231621841598}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:35,446] Trial 65 finished with value: 0.2287779452471272 and parameters: {'lambda_l1': 1.4607813057797e-07, 'lambda_l2': 6.625811391787766e-06, 'num_leaves': 28, 'num_iterations': 369, 'max_depth': 8, 'max_bin': 45, 'feature_fraction': 0.665903709101734, 'bagging_fraction': 0.4050735032768899, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.19056778175977196, 'learning_rate': 0.039828178798709035, 'min_sum_hessian_in_leaf': 0.6153266186576499}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:39,660] Trial 66 finished with value: 0.2346785756143202 and parameters: {'lambda_l1': 1.803753760589179e-07, 'lambda_l2': 4.686299529317242e-06, 'num_leaves': 28, 'num_iterations': 362, 'max_depth': 8, 'max_bin': 42, 'feature_fraction': 0.5843110728902132, 'bagging_fraction': 0.4279014783997107, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.22803347330795198, 'learning_rate': 0.04481615148616625, 'min_sum_hessian_in_leaf': 0.6150347477458982}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:46,026] Trial 67 finished with value: 0.2493892556294878 and parameters: {'lambda_l1': 3.9027375167021187e-07, 'lambda_l2': 6.3673538049059584e-06, 'num_leaves': 30, 'num_iterations': 420, 'max_depth': 7, 'max_bin': 36, 'feature_fraction': 0.681780164737397, 'bagging_fraction': 0.41692208780468654, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.2861879323394304, 'learning_rate': 0.01629206468477904, 'min_sum_hessian_in_leaf': 0.6299609974196364}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:49,922] Trial 68 finished with value: 0.25194483892655223 and parameters: {'lambda_l1': 1.5489886734116823e-07, 'lambda_l2': 1.6106028443710288e-06, 'num_leaves': 19, 'num_iterations': 386, 'max_depth': 9, 'max_bin': 44, 'feature_fraction': 0.6934711415556308, 'bagging_fraction': 0.3665145263473947, 'bagging_freq': 3, 'min_data_in_leaf': 16, 'min_gain_to_split': 0.17363776900843358, 'learning_rate': 0.036751323768692126, 'min_sum_hessian_in_leaf': 0.6656270788412701}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:53,747] Trial 69 finished with value: 0.4384628081726819 and parameters: {'lambda_l1': 4.956193837882611e-08, 'lambda_l2': 8.230372899947995e-06, 'num_leaves': 26, 'num_iterations': 429, 'max_depth': 8, 'max_bin': 4, 'feature_fraction': 0.6349573069905523, 'bagging_fraction': 0.39522472837701106, 'bagging_freq': 4, 'min_data_in_leaf': 13, 'min_gain_to_split': 0.129793919299325, 'learning_rate': 0.09552684704452329, 'min_sum_hessian_in_leaf': 0.6781350807497227}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:55,954] Trial 70 finished with value: 0.23478479789379678 and parameters: {'lambda_l1': 1.5533550534591048e-08, 'lambda_l2': 0.00010939149241885838, 'num_leaves': 23, 'num_iterations': 376, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.6540374761201743, 'bagging_fraction': 0.460838305230244, 'bagging_freq': 2, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.20825370570639581, 'learning_rate': 0.11333406321546924, 'min_sum_hessian_in_leaf': 0.6219228364955789}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:35:59,209] Trial 71 finished with value: 0.23816433070979723 and parameters: {'lambda_l1': 9.462464169774122e-08, 'lambda_l2': 4.406275074792859e-05, 'num_leaves': 14, 'num_iterations': 355, 'max_depth': 9, 'max_bin': 46, 'feature_fraction': 0.7365344164741482, 'bagging_fraction': 0.33927143184222264, 'bagging_freq': 2, 'min_data_in_leaf': 8, 'min_gain_to_split': 0.16987121144645367, 'learning_rate': 0.04725249918377658, 'min_sum_hessian_in_leaf': 0.5181659666415335}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:04,719] Trial 72 finished with value: 0.28670595369672214 and parameters: {'lambda_l1': 7.492140847231106e-07, 'lambda_l2': 3.147820107764939e-06, 'num_leaves': 23, 'num_iterations': 336, 'max_depth': 9, 'max_bin': 49, 'feature_fraction': 0.6828348006504076, 'bagging_fraction': 0.33624036882845015, 'bagging_freq': 1, 'min_data_in_leaf': 13, 'min_gain_to_split': 0.1892960570680822, 'learning_rate': 0.01215423882496577, 'min_sum_hessian_in_leaf': 0.5517746170854632}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:06,837] Trial 73 finished with value: 0.2687667543983743 and parameters: {'lambda_l1': 3.0712837846171265e-07, 'lambda_l2': 2.1634951899390054e-05, 'num_leaves': 17, 'num_iterations': 264, 'max_depth': 9, 'max_bin': 40, 'feature_fraction': 0.7461384115307441, 'bagging_fraction': 0.2944207690205627, 'bagging_freq': 1, 'min_data_in_leaf': 50, 'min_gain_to_split': 0.1266035005193531, 'learning_rate': 0.18414724805249516, 'min_sum_hessian_in_leaf': 0.6018114817262082}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:09,490] Trial 74 finished with value: 0.29813501079366633 and parameters: {'lambda_l1': 4.657528451423353e-08, 'lambda_l2': 1.0158005730304464e-05, 'num_leaves': 31, 'num_iterations': 404, 'max_depth': 8, 'max_bin': 42, 'feature_fraction': 0.6995112073790686, 'bagging_fraction': 0.3669177119129556, 'bagging_freq': 2, 'min_data_in_leaf': 100, 'min_gain_to_split': 0.15198265810734, 'learning_rate': 0.10550648690542569, 'min_sum_hessian_in_leaf': 0.6441841992925693}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:11,895] Trial 75 finished with value: 0.27407339292127064 and parameters: {'lambda_l1': 1.5960636154687744e-07, 'lambda_l2': 7.563566350142278e-05, 'num_leaves': 19, 'num_iterations': 368, 'max_depth': 8, 'max_bin': 16, 'feature_fraction': 0.6588667855166828, 'bagging_fraction': 0.43782505008308903, 'bagging_freq': 2, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.24013022425393174, 'learning_rate': 0.07591028616585649, 'min_sum_hessian_in_leaf': 0.5282171227422643}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:15,692] Trial 76 finished with value: 0.22186079266088946 and parameters: {'lambda_l1': 1.7065913282328214e-06, 'lambda_l2': 1.1188909661545645e-06, 'num_leaves': 35, 'num_iterations': 446, 'max_depth': 9, 'max_bin': 47, 'feature_fraction': 0.7191718833330597, 'bagging_fraction': 0.3806803160949056, 'bagging_freq': 1, 'min_data_in_leaf': 19, 'min_gain_to_split': 0.10246967111974788, 'learning_rate': 0.20049910308695576, 'min_sum_hessian_in_leaf': 0.5623977696987263}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:20,784] Trial 77 finished with value: 0.235407269222897 and parameters: {'lambda_l1': 1.6193698611149577e-08, 'lambda_l2': 1.0705726186685878e-06, 'num_leaves': 34, 'num_iterations': 492, 'max_depth': 7, 'max_bin': 49, 'feature_fraction': 0.7900044977581471, 'bagging_fraction': 0.39813278539359753, 'bagging_freq': 3, 'min_data_in_leaf': 20, 'min_gain_to_split': 0.1008856631560439, 'learning_rate': 0.0434413309300154, 'min_sum_hessian_in_leaf': 0.6183053761350502}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:23,350] Trial 78 finished with value: 0.2559183574889031 and parameters: {'lambda_l1': 1.4347315247843316e-06, 'lambda_l2': 2.1647368655916224e-06, 'num_leaves': 38, 'num_iterations': 429, 'max_depth': 9, 'max_bin': 45, 'feature_fraction': 0.7103480950751372, 'bagging_fraction': 0.3701278430800537, 'bagging_freq': 2, 'min_data_in_leaf': 30, 'min_gain_to_split': 0.15580995464843617, 'learning_rate': 0.1773798922788241, 'min_sum_hessian_in_leaf': 0.6755750060150757}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:26,688] Trial 79 finished with value: 0.23167849697106355 and parameters: {'lambda_l1': 9.013508854864936e-08, 'lambda_l2': 3.308844429954492e-07, 'num_leaves': 26, 'num_iterations': 442, 'max_depth': 10, 'max_bin': 46, 'feature_fraction': 0.5876729561712803, 'bagging_fraction': 0.41433704352152, 'bagging_freq': 1, 'min_data_in_leaf': 24, 'min_gain_to_split': 0.12817900916286154, 'learning_rate': 0.2554590377816351, 'min_sum_hessian_in_leaf': 0.597038768430116}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:30,066] Trial 80 finished with value: 0.22902154730273688 and parameters: {'lambda_l1': 7.89069125447662e-08, 'lambda_l2': 4.231236607200966e-07, 'num_leaves': 26, 'num_iterations': 458, 'max_depth': 8, 'max_bin': 40, 'feature_fraction': 0.5892595595579835, 'bagging_fraction': 0.471612299769017, 'bagging_freq': 1, 'min_data_in_leaf': 23, 'min_gain_to_split': 0.12519167576126788, 'learning_rate': 0.2667383678508552, 'min_sum_hessian_in_leaf': 0.5616394589629985}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:33,543] Trial 81 finished with value: 0.2302747464047155 and parameters: {'lambda_l1': 6.509647124928012e-08, 'lambda_l2': 4.3961024002815837e-07, 'num_leaves': 25, 'num_iterations': 460, 'max_depth': 8, 'max_bin': 46, 'feature_fraction': 0.5971518824037031, 'bagging_fraction': 0.42149231078631055, 'bagging_freq': 1, 'min_data_in_leaf': 24, 'min_gain_to_split': 0.12690137230870618, 'learning_rate': 0.26486049740937656, 'min_sum_hessian_in_leaf': 0.5669125915145393}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:36,943] Trial 82 finished with value: 0.23270450050116792 and parameters: {'lambda_l1': 8.414948724108926e-08, 'lambda_l2': 3.6969107553733097e-07, 'num_leaves': 26, 'num_iterations': 453, 'max_depth': 8, 'max_bin': 43, 'feature_fraction': 0.5888160334129936, 'bagging_fraction': 0.4569861408333856, 'bagging_freq': 1, 'min_data_in_leaf': 25, 'min_gain_to_split': 0.12421224512294383, 'learning_rate': 0.26149742897565925, 'min_sum_hessian_in_leaf': 0.5011047617290523}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:40,588] Trial 83 finished with value: 0.23228537545533282 and parameters: {'lambda_l1': 3.557327914489288e-08, 'lambda_l2': 4.6785868549102193e-07, 'num_leaves': 28, 'num_iterations': 475, 'max_depth': 7, 'max_bin': 41, 'feature_fraction': 0.613435981092116, 'bagging_fraction': 0.4921805825352267, 'bagging_freq': 1, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.1002103961679394, 'learning_rate': 0.3050726058532238, 'min_sum_hessian_in_leaf': 0.5650292863536495}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:43,685] Trial 84 finished with value: 0.23356005625222825 and parameters: {'lambda_l1': 2.6647638331966536e-07, 'lambda_l2': 2.606736353736467e-07, 'num_leaves': 24, 'num_iterations': 443, 'max_depth': 6, 'max_bin': 46, 'feature_fraction': 0.5655618088260577, 'bagging_fraction': 0.42355501610770613, 'bagging_freq': 1, 'min_data_in_leaf': 23, 'min_gain_to_split': 0.14827251405996994, 'learning_rate': 0.2504522762996299, 'min_sum_hessian_in_leaf': 0.5295099977934088}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:47,429] Trial 85 finished with value: 0.2395681678148683 and parameters: {'lambda_l1': 1.709312969138647e-08, 'lambda_l2': 7.201885899468657e-07, 'num_leaves': 35, 'num_iterations': 476, 'max_depth': 8, 'max_bin': 39, 'feature_fraction': 0.5854469369178199, 'bagging_fraction': 0.4693648322163019, 'bagging_freq': 1, 'min_data_in_leaf': 32, 'min_gain_to_split': 0.12539480289238303, 'learning_rate': 0.20325843614752684, 'min_sum_hessian_in_leaf': 0.6477676822086553}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:50,548] Trial 86 finished with value: 0.24332664981021696 and parameters: {'lambda_l1': 6.413342219194544e-08, 'lambda_l2': 1.270188919323035e-07, 'num_leaves': 39, 'num_iterations': 446, 'max_depth': 7, 'max_bin': 47, 'feature_fraction': 0.5449243662597761, 'bagging_fraction': 0.43905366607364354, 'bagging_freq': 1, 'min_data_in_leaf': 37, 'min_gain_to_split': 0.14549878031861813, 'learning_rate': 0.2704652798191283, 'min_sum_hessian_in_leaf': 0.5952479779407955}. Best is trial 63 with value: 0.21439140960684977.
# [I 2024-02-10 19:36:54,146] Trial 87 finished with value: 0.23203767054403715 and parameters: {'lambda_l1': 2.8838525501929412e-08, 'lambda_l2': 1.1474830728174895e-06, 'num_leaves': 30, 'num_iterations': 466, 'max_depth': 8, 'max_bin': 44, 'feature_fraction': 0.6188601947692243, 'bagging_fraction': 0.40810023769788806, 'bagging_freq': 1, 'min_data_in_leaf': 29, 'min_gain_to_split': 0.11551178550465795, 'learning_rate': 0.24323655755011178, 'min_sum_hessian_in_leaf': 0.5749481426576251}. Best is trial 63 with value: 0.21439140960684977.
# ...
# [I 2024-02-10 19:39:39,057] Trial 172 finished with value: 0.23665427898934938 and parameters: {'lambda_l1': 2.6915285044939764e-08, 'lambda_l2': 1.2079774706304782e-07, 'num_leaves': 39, 'num_iterations': 499, 'max_depth': 9, 'max_bin': 49, 'feature_fraction': 0.7309573382460407, 'bagging_fraction': 0.6383948648044445, 'bagging_freq': 4, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.1003080890540713, 'learning_rate': 0.47653063020872793, 'min_sum_hessian_in_leaf': 0.42094954287201697}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:40,921] Trial 173 finished with value: 0.21455585650587433 and parameters: {'lambda_l1': 8.406988534190755e-08, 'lambda_l2': 2.587262868667161e-07, 'num_leaves': 37, 'num_iterations': 480, 'max_depth': 9, 'max_bin': 50, 'feature_fraction': 0.7654567588302917, 'bagging_fraction': 0.6852254515056866, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.12721082361977587, 'learning_rate': 0.41644144275824035, 'min_sum_hessian_in_leaf': 0.49208253350021963}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:42,793] Trial 174 finished with value: 0.21865942679231373 and parameters: {'lambda_l1': 6.259009463839588e-08, 'lambda_l2': 2.4014139826501323e-07, 'num_leaves': 37, 'num_iterations': 479, 'max_depth': 9, 'max_bin': 50, 'feature_fraction': 0.7593693386774932, 'bagging_fraction': 0.698104577288234, 'bagging_freq': 1, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.1274568553739974, 'learning_rate': 0.4195250081765371, 'min_sum_hessian_in_leaf': 0.48831127033248223}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:44,659] Trial 175 finished with value: 0.218549222003257 and parameters: {'lambda_l1': 8.19014160079922e-08, 'lambda_l2': 4.204918765366096e-07, 'num_leaves': 33, 'num_iterations': 488, 'max_depth': 5, 'max_bin': 49, 'feature_fraction': 0.7279964531980363, 'bagging_fraction': 0.6776476066223385, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.14391593655813717, 'learning_rate': 0.43669844560300125, 'min_sum_hessian_in_leaf': 0.42636900556430213}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:47,023] Trial 176 finished with value: 0.22094472407950935 and parameters: {'lambda_l1': 3.576482126049413e-08, 'lambda_l2': 4.874865529324741e-08, 'num_leaves': 41, 'num_iterations': 472, 'max_depth': 9, 'max_bin': 50, 'feature_fraction': 0.6991117338000845, 'bagging_fraction': 0.6125923147234399, 'bagging_freq': 1, 'min_data_in_leaf': 12, 'min_gain_to_split': 0.1234716821099462, 'learning_rate': 0.40468097325699204, 'min_sum_hessian_in_leaf': 0.5003235341613536}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:48,533] Trial 177 finished with value: 0.23401735265190604 and parameters: {'lambda_l1': 1.021826046120888e-08, 'lambda_l2': 8.118928283436455e-08, 'num_leaves': 38, 'num_iterations': 460, 'max_depth': 2, 'max_bin': 49, 'feature_fraction': 0.7517747486250457, 'bagging_fraction': 0.5642437111128316, 'bagging_freq': 1, 'min_data_in_leaf': 10, 'min_gain_to_split': 0.11875477157369374, 'learning_rate': 0.47732274298632466, 'min_sum_hessian_in_leaf': 0.4714781077917379}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:49,788] Trial 178 finished with value: 0.25251031760375564 and parameters: {'lambda_l1': 1.9625656239414808e-08, 'lambda_l2': 2.4867838894448706e-07, 'num_leaves': 31, 'num_iterations': 480, 'max_depth': 4, 'max_bin': 48, 'feature_fraction': 0.8321454015925585, 'bagging_fraction': 0.6631454068319831, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.44019842911537915, 'learning_rate': 0.3901353470461428, 'min_sum_hessian_in_leaf': 0.43702588065602}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:51,246] Trial 179 finished with value: 0.2329802966340658 and parameters: {'lambda_l1': 9.683123679254332e-06, 'lambda_l2': 1.6906915929051368e-07, 'num_leaves': 42, 'num_iterations': 500, 'max_depth': 5, 'max_bin': 50, 'feature_fraction': 0.6866006495806749, 'bagging_fraction': 0.6344561458914093, 'bagging_freq': 2, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.14676008557826242, 'learning_rate': 0.3723162406263345, 'min_sum_hessian_in_leaf': 0.4776457273358057}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:52,609] Trial 180 finished with value: 0.41153929746425255 and parameters: {'lambda_l1': 1.0051361681129163e-07, 'lambda_l2': 3.778122318329115e-08, 'num_leaves': 40, 'num_iterations': 452, 'max_depth': 9, 'max_bin': 5, 'feature_fraction': 0.7681817649808944, 'bagging_fraction': 0.7513515695563849, 'bagging_freq': 1, 'min_data_in_leaf': 14, 'min_gain_to_split': 0.3309672929805255, 'learning_rate': 0.42772164944197133, 'min_sum_hessian_in_leaf': 0.4199140315855567}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:55,829] Trial 181 finished with value: 0.24871491802385864 and parameters: {'lambda_l1': 2.160452559839796e-08, 'lambda_l2': 1.297725201686688e-07, 'num_leaves': 33, 'num_iterations': 493, 'max_depth': 9, 'max_bin': 48, 'feature_fraction': 0.7883563309969293, 'bagging_fraction': 0.6513040793840538, 'bagging_freq': 1, 'min_data_in_leaf': 83, 'min_gain_to_split': 0.11705119643494745, 'learning_rate': 0.4628995328877676, 'min_sum_hessian_in_leaf': 0.4504367120661962}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:39:57,350] Trial 182 finished with value: 0.2430418390069396 and parameters: {'lambda_l1': 2.7890058993611667e-08, 'lambda_l2': 7.10839523319821e-08, 'num_leaves': 34, 'num_iterations': 486, 'max_depth': 9, 'max_bin': 49, 'feature_fraction': 0.7778828441426734, 'bagging_fraction': 0.6052515399200622, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.30151403997041537, 'learning_rate': 0.4934008719160426, 'min_sum_hessian_in_leaf': 0.45804363773177736}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:00,007] Trial 183 finished with value: 0.21183402823253536 and parameters: {'lambda_l1': 1.677999300201217e-08, 'lambda_l2': 1.2267892731865433e-07, 'num_leaves': 38, 'num_iterations': 472, 'max_depth': 9, 'max_bin': 47, 'feature_fraction': 0.8123820434043, 'bagging_fraction': 0.5794961445251833, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.10001173452058372, 'learning_rate': 0.4420261032897533, 'min_sum_hessian_in_leaf': 0.4906852608286893}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:02,320] Trial 184 finished with value: 0.2193552151179922 and parameters: {'lambda_l1': 1.6400415925459405e-08, 'lambda_l2': 2.0675747346362578e-07, 'num_leaves': 37, 'num_iterations': 470, 'max_depth': 9, 'max_bin': 47, 'feature_fraction': 0.8139968624063754, 'bagging_fraction': 0.5790086185907093, 'bagging_freq': 1, 'min_data_in_leaf': 11, 'min_gain_to_split': 0.1288475950985221, 'learning_rate': 0.4137133436976633, 'min_sum_hessian_in_leaf': 0.5018127071366263}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:04,197] Trial 185 finished with value: 0.21338891351698538 and parameters: {'lambda_l1': 3.659633245389534e-08, 'lambda_l2': 3.622478883680129e-07, 'num_leaves': 44, 'num_iterations': 462, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.7350800891424569, 'bagging_fraction': 0.5927235931261774, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.1375079500390436, 'learning_rate': 0.4417062813063883, 'min_sum_hessian_in_leaf': 0.48883733394039136}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:05,470] Trial 186 finished with value: 0.25289628476760867 and parameters: {'lambda_l1': 4.116044847772249e-05, 'lambda_l2': 3.6205838901645735e-07, 'num_leaves': 45, 'num_iterations': 461, 'max_depth': 3, 'max_bin': 49, 'feature_fraction': 0.7416442974194295, 'bagging_fraction': 0.5903031945868965, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.47724555584140055, 'learning_rate': 0.3792486642509042, 'min_sum_hessian_in_leaf': 0.4866891900945902}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:07,855] Trial 187 finished with value: 0.2498275049073259 and parameters: {'lambda_l1': 4.351006861082836e-06, 'lambda_l2': 9.938548854971534e-08, 'num_leaves': 43, 'num_iterations': 452, 'max_depth': 4, 'max_bin': 15, 'feature_fraction': 0.7142499506515804, 'bagging_fraction': 0.6204595523635758, 'bagging_freq': 1, 'min_data_in_leaf': 8, 'min_gain_to_split': 0.10023835937254248, 'learning_rate': 0.44504253128317134, 'min_sum_hessian_in_leaf': 0.42356660381601446}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:09,582] Trial 188 finished with value: 0.2126993917511611 and parameters: {'lambda_l1': 0.000705868820120537, 'lambda_l2': 2.4324515160446816e-08, 'num_leaves': 40, 'num_iterations': 444, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.7559544637289896, 'bagging_fraction': 0.5694118507051056, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.1413358122468563, 'learning_rate': 0.44281454301406065, 'min_sum_hessian_in_leaf': 0.440297471678785}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:11,312] Trial 189 finished with value: 0.2264080580057966 and parameters: {'lambda_l1': 0.0006991963833205037, 'lambda_l2': 2.1331615378942e-08, 'num_leaves': 39, 'num_iterations': 478, 'max_depth': 3, 'max_bin': 48, 'feature_fraction': 0.7326854228977233, 'bagging_fraction': 0.567811333236658, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.17534279693759233, 'learning_rate': 0.4279896845341955, 'min_sum_hessian_in_leaf': 0.4058092420061253}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:13,155] Trial 190 finished with value: 0.2131788624782754 and parameters: {'lambda_l1': 4.3832493215114803e-08, 'lambda_l2': 5.25958660642451e-08, 'num_leaves': 40, 'num_iterations': 465, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.8032987561063756, 'bagging_fraction': 0.5553173022956349, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.14072788148142334, 'learning_rate': 0.4781157054581884, 'min_sum_hessian_in_leaf': 0.5097391351351132}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:14,975] Trial 191 finished with value: 0.21310608252266056 and parameters: {'lambda_l1': 4.453501706528838e-08, 'lambda_l2': 6.578503009577369e-08, 'num_leaves': 40, 'num_iterations': 463, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.800864390485687, 'bagging_fraction': 0.5527705568961109, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.13872638103140933, 'learning_rate': 0.4731716152229503, 'min_sum_hessian_in_leaf': 0.5139382428099927}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:16,794] Trial 192 finished with value: 0.21872007978778613 and parameters: {'lambda_l1': 5.5134126659421446e-08, 'lambda_l2': 5.7981209410605255e-08, 'num_leaves': 40, 'num_iterations': 463, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.8070492601161587, 'bagging_fraction': 0.5444142103870471, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.14182709578667077, 'learning_rate': 0.48204241585517105, 'min_sum_hessian_in_leaf': 0.4899899142934379}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:18,522] Trial 193 finished with value: 0.217892807640935 and parameters: {'lambda_l1': 1.0685649240325485e-07, 'lambda_l2': 3.0987819092329825e-08, 'num_leaves': 36, 'num_iterations': 443, 'max_depth': 3, 'max_bin': 49, 'feature_fraction': 0.8510669526673851, 'bagging_fraction': 0.5548544612175978, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.1542820271175115, 'learning_rate': 0.4660343523217909, 'min_sum_hessian_in_leaf': 0.5158543833381078}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:20,045] Trial 194 finished with value: 0.2350936391677144 and parameters: {'lambda_l1': 4.5990972899394786e-08, 'lambda_l2': 4.562986865761497e-08, 'num_leaves': 38, 'num_iterations': 475, 'max_depth': 3, 'max_bin': 49, 'feature_fraction': 0.8309558134812195, 'bagging_fraction': 0.5723015576931362, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.27105476621574187, 'learning_rate': 0.4371918386692172, 'min_sum_hessian_in_leaf': 0.5232801166046961}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:21,910] Trial 195 finished with value: 0.2160699606225629 and parameters: {'lambda_l1': 0.00030242488882956537, 'lambda_l2': 1.755692884442484e-08, 'num_leaves': 41, 'num_iterations': 456, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.7965248343716065, 'bagging_fraction': 0.5827359871135117, 'bagging_freq': 1, 'min_data_in_leaf': 8, 'min_gain_to_split': 0.13655748899335743, 'learning_rate': 0.5177348315110751, 'min_sum_hessian_in_leaf': 0.5056055922136223}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:23,730] Trial 196 finished with value: 0.21970205188624198 and parameters: {'lambda_l1': 0.0005542756875570273, 'lambda_l2': 7.276543488897545e-08, 'num_leaves': 40, 'num_iterations': 448, 'max_depth': 3, 'max_bin': 48, 'feature_fraction': 0.8200924078964029, 'bagging_fraction': 0.5973345314176495, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'min_gain_to_split': 0.17225978684522297, 'learning_rate': 0.4771524417241829, 'min_sum_hessian_in_leaf': 0.4729042719631874}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:25,072] Trial 197 finished with value: 0.2757151993730279 and parameters: {'lambda_l1': 9.14731137634301e-05, 'lambda_l2': 4.537783194074089e-08, 'num_leaves': 36, 'num_iterations': 466, 'max_depth': 3, 'max_bin': 47, 'feature_fraction': 0.7638092871888802, 'bagging_fraction': 0.5433103998350822, 'bagging_freq': 1, 'min_data_in_leaf': 9, 'min_gain_to_split': 0.7726516508590114, 'learning_rate': 0.443852796764012, 'min_sum_hessian_in_leaf': 0.5144536174459069}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:27,033] Trial 198 finished with value: 0.21125038671550384 and parameters: {'lambda_l1': 7.258872621793636e-08, 'lambda_l2': 3.0572273085089766e-07, 'num_leaves': 42, 'num_iterations': 483, 'max_depth': 3, 'max_bin': 50, 'feature_fraction': 0.8651307909376943, 'bagging_fraction': 0.526672958264164, 'bagging_freq': 1, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.13232801381786782, 'learning_rate': 0.39739689784533266, 'min_sum_hessian_in_leaf': 0.46344768810997256}. Best is trial 109 with value: 0.21043521764375445.
# [I 2024-02-10 19:40:28,364] Trial 199 finished with value: 0.23777692220425192 and parameters: {'lambda_l1': 1.6542058812465972e-07, 'lambda_l2': 3.714114712148304e-07, 'num_leaves': 47, 'num_iterations': 484, 'max_depth': 3, 'max_bin': 48, 'feature_fraction': 0.9061430822021461, 'bagging_fraction': 0.5624568305569275, 'bagging_freq': 2, 'min_data_in_leaf': 7, 'min_gain_to_split': 0.15491834812147245, 'learning_rate': 0.4125430746423234, 'min_sum_hessian_in_leaf': 0.47851410613493184}. Best is trial 109 with value: 0.21043521764375445.
# Number of finished trials: 200
# Best trial:
#   Value: 0.21043521764375445
#   Params:
#     lambda_l1: 1.3587104575425579e-08
#     lambda_l2: 2.257877242310291e-07
#     num_leaves: 31
#     num_iterations: 485
#     max_depth: 9
#     max_bin: 50
#     feature_fraction: 0.7434423899698007
#     bagging_fraction: 0.618682893626946
#     bagging_freq: 1
#     min_data_in_leaf: 11
#     min_gain_to_split: 0.1183123677847924
#     learning_rate: 0.43604983047577056
#     min_sum_hessian_in_leaf: 0.44246137321948337

# %%
def read_param():
    fname = '../random-split/best-paramters_lgbr_random.txt'
    f0 = open(fname,'r')
    b = []
    for line in f0.readlines():
        a = line.split()
        a_ = [a[i] for i in range(len(a))]
        b.append(a_)
    f0.close()
    p1 = float(b[1][1]); p2 = float(b[2][1]); p3 = int(b[3][1]); p4 = int(b[4][1])
    p5 = int(b[5][1]); p6 = int(b[6][1]); p7 = float(b[7][1]); p8 = float(b[8][1])
    p9 = int(b[9][1]); p10 = int(b[10][1]); p11 = float(b[11][1]); p12 = float(b[12][1])
    p13 = float(b[13][1])
    return p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13

# %%
p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13 = read_param()
params = {"objective": 'regression', "metric": "root_mean_squared_error", "boosting_type": "gbdt", 
         'lambda_l1': p1, 'lambda_l2': p2, 'num_leaves': p3, 'num_iterations': p4, 
         'max_depth': p5, 'max_bin': p6, 'feature_fraction': p7, 'bagging_fraction': p8,
         'bagging_freq': p9, 'min_data_in_leaf': p10, 'min_gain_to_split': p11, 'learning_rate': p12,
         'min_sum_hessian_in_leaf': p13}
print(p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13)
# Out:
# 1.6207176580357287e-08 6.50531167525302e-08 14 432 8 50 0.5490618064841022 0.5680137984610684 1 9 0.1000151242891819 0.44223032903676884 0.562444561980657

# %%
## optimize over random states of KFold
rmse_cv_array = []
for i in range(0,100):
    print(f"Step {i}")
    # Initialize StratifiedKFold cross-validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=i)
    stratify_labels = train_df['conductivity_log_bin']
    lgbm = LGBMRegressor(**params, verbose=-1)
    # plsr = PLSRegression(n_components=ncomp, scale=True) ## don't use scale=True

    fold = 1
    # Loop over each fold
    rmse_val = []; rmse_train = []
    for train_index, val_index in skf.split(X_train_, stratify_labels):
        # print("Fold {}".format(fold))
        # Split the data
        X_train_fold, X_val_fold = X_train_[train_index], X_train_[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Fit the model on the training data
        lgbm.fit(X_train_fold, y_train_fold)

        y_pred_val_fold = lgbm.predict(X_val_fold)
        r2 = r2_score(y_val_fold, y_pred_val_fold); rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_val_fold)); mae = mean_absolute_error(y_val_fold, y_pred_val_fold)
        # print(f"Train set CV, R2 score: {r2}, RMSE: {rmse}, MAE: {mae}")
        rmse_train.append(rmse)

        ## predict on validation test
        y_pred_val = lgbm.predict(X_val_)
        r2 = r2_score(y_val, y_pred_val); rmse = np.sqrt(mean_squared_error(y_val, y_pred_val)); mae = mean_absolute_error(y_val, y_pred_val)
        # print(f"Validation set, R2 score: {r2}, RMSE: {rmse}, MAE: {mae}")
        rmse_val.append(rmse)

        fold += 1
    # print(f"RMSE train: {np.mean(rmse_train)} & RMSE val: {np.mean(rmse_val)}")
    rmse_cv_array.append(np.mean(rmse_train))

ind = min(range(len(rmse_cv_array)), key=rmse_cv_array.__getitem__)
print(rmse_cv_array[ind])
# Out:
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Step 10
# Step 11
# Step 12
# Step 13
# Step 14
# Step 15
# Step 16
# Step 17
# Step 18
# Step 19
# Step 20
# Step 21
# Step 22
# Step 23
# Step 24
# Step 25
# Step 26
# Step 27
# Step 28
# Step 29
# Step 30
# Step 31
# Step 32
# Step 33
# Step 34
# Step 35
# Step 36
# Step 37
# Step 38
# Step 39
# Step 40
# Step 41
# Step 42
# Step 43
# Step 44
# Step 45
# Step 46
# Step 47
# Step 48
# Step 49
# Step 50
# Step 51
# Step 52
# Step 53
# Step 54
# Step 55
# Step 56
# Step 57
# Step 58
# Step 59
# Step 60
# Step 61
# Step 62
# Step 63
# Step 64
# Step 65
# Step 66
# Step 67
# Step 68
# Step 69
# Step 70
# Step 71
# Step 72
# Step 73
# Step 74
# Step 75
# Step 76
# Step 77
# Step 78
# Step 79
# Step 80
# Step 81
# Step 82
# Step 83
# Step 84
# Step 85
# Step 86
# Step 87
# Step 88
# Step 89
# Step 90
# Step 91
# Step 92
# Step 93
# Step 94
# Step 95
# Step 96
# Step 97
# Step 98
# Step 99
# 0.205945622371906

# %%
## use the best random state to train the model
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=ind)
stratify_labels = train_df['conductivity_log_bin']

lgbm = LGBMRegressor(**params, verbose=-1)

fold = 1
# Loop over each fold
pred_train_array = []; pred_val_array = []; pred_test_array = []
for train_index, val_index in skf.split(X_train_, stratify_labels):
    X_train_fold, X_val_fold = X_train_[train_index], X_train_[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Fit the model on the training data
    lgbm.fit(X_train_fold, y_train_fold)

    y_pred_val_fold = lgbm.predict(X_val_fold)
    r2 = r2_score(y_val_fold, y_pred_val_fold); rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred_val_fold)); mae = mean_absolute_error(y_val_fold, y_pred_val_fold)
    
    y_pred_train = lgbm.predict(X_train_)
    pred_train_array.append(y_pred_train)

    ## predict on validation test
    y_pred_val = lgbm.predict(X_val_)
    pred_val_array.append(y_pred_val)

    # ## predict on test set
    y_pred_test = lgbm.predict(X_test_)
    pred_test_array.append(y_pred_test)

    ## save plsr model to pickle
    filename = f'./lgbm_cond_strat2_fold_{fold}.sav' ## change filename accordingly
    pickle.dump(lgbm, open(filename, 'wb'))
    fold += 1

## calculate the average of the predictions on train, val and test
y_pred_train_avg = np.mean(pred_train_array, axis=0); y_pred_val_avg = np.mean(pred_val_array, axis=0); y_pred_test_avg = np.mean(pred_test_array, axis=0)
r2_train = r2_score(y_train, y_pred_train_avg); rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train_avg)); mae_train = mean_absolute_error(y_train, y_pred_train_avg)
r2_val = r2_score(y_val, y_pred_val_avg); rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val_avg)); mae_val = mean_absolute_error(y_val, y_pred_val_avg)
r2_test = r2_score(y_test, y_pred_test_avg); rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test_avg)); mae_test = mean_absolute_error(y_test, y_pred_test_avg)
print(f"RMSE train: {rmse_train} & RMSE val: {rmse_val} & RMSE test: {rmse_test}")
print(f"R2 train: {r2_train} & R2 val: {r2_val} & R2 test: {r2_test}")
print(f"MAE train: {mae_train} & MAE val: {mae_val} & MAE test: {mae_test}")
# Out:
# RMSE train: 0.15253709781813488 & RMSE val: 0.21995599366448926 & RMSE test: 0.18581331611615554
# R2 train: 0.9567904972270097 & R2 val: 0.908337142704908 & R2 test: 0.9380304677487615
# MAE train: 0.0913866763582673 & MAE val: 0.11090849726776304 & MAE test: 0.10598035958027592

# %%
fig, ax = plt.subplots(figsize=(5,5))
xl = np.arange(-7.5,2.5,1)
yl = np.arange(-7.5,2.5,1)
plt.plot(yl, xl, linestyle='dashed', linewidth=2.0, color='black')  

# plt.tick_params(axis='both', direction='in')
plt.xlabel('True log $\sigma$',fontsize=12)
plt.ylabel('ML-predicted log $\sigma$',fontsize=12)
sns.scatterplot(x=y_train, y=y_pred_train, color="cyan", label='Train')
sns.scatterplot(x=y_val, y=y_pred_val, color="gray", label='Validation')
sns.scatterplot(x=y_test, y=y_pred_test, color="orange", label='Test')
# plt.grid()
plt.text(-5, -6, 'RMSE = {:.3f} / {:.3f} / {:.3f}'.format(rmse_train, rmse_val, rmse_test), color='blue')
plt.text(-5, -7, 'R$^2$ = {:.3f} / {:.3f} / {:.3f}'.format(r2_train, r2_val, r2_test), color='blue')
plt.legend(frameon=False)
plt.show()
# filename = save_fig_path + 'fgrp_lgbm_cv_1.jpg'
# plt.savefig(filename, dpi=300)

# %% [markdown]
# **Predict on OOD**

# %%
df_ood = pd.read_csv('./ood_qsar_fgrp_cond.csv')
df_ood.drop(columns='fr_func_grp_20_salt', inplace=True)
X_ood = df_ood.iloc[:,2:-1]
y_ood = df_ood.iloc[:,-1]
X_ood_std = std_scale.transform(X_ood)
X_ood_std = pd.DataFrame(X_ood_std, columns=X_ood.columns)
X_ood_ = np.array(X_ood_std)
df_ood
# Out:
#                     solv_comb_sm                       salt_smiles  \
# 0    C(COCCOCCOCC(F)(F)F)(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 1    C(COCCOCCOCC(F)(F)F)(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 2    C(COCCOCCOCC(F)(F)F)(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 3    C(COCCOCCOCC(F)(F)F)(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 4    C(COCCOCCOCC(F)(F)F)(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# ..                           ...                               ...
# 166         CS(=O)(=O)OCC(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 167         CS(=O)(=O)OCC(F)(F)F  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 168      CO[Si](C)(CCC(F)(F)F)OC  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 169      CO[Si](C)(CCC(F)(F)F)OC  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
# 170                      CCCOCCC  [Li+].[N-](S(=O)(=O)F)S(=O)(=O)F
#
#      fr_func_grp_1_solv  fr_func_grp_2_solv  fr_func_grp_3_solv  \
# 0                     0                   0                   0
# 1                     0                   0                   0
# 2                     0                   0                   0
# 3                     0                   0                   0
# 4                     0                   0                   0
# ..                  ...                 ...                 ...
# 166                   0                   0                   0
# 167                   0                   0                   0
# 168                   0                   0                   0
# 169                   0                   0                   0
# 170                   0                   0                   0
#
#      fr_func_grp_4_solv  fr_func_grp_5_solv  fr_func_grp_6_solv  \
# 0                     0                   0                   0
# 1                     0                   0                   0
# 2                     0                   0                   0
# 3                     0                   0                   0
# 4                     0                   0                   0
# ..                  ...                 ...                 ...
# 166                   0                   0                   0
# 167                   0                   0                   0
# 168                   0                   0                   0
# 169                   0                   0                   0
# 170                   0                   0                   0
#
#      fr_func_grp_7_solv  fr_func_grp_8_solv  ...  fr_func_grp_40_salt  \
# 0                     0                   0  ...                    0
# 1                     0                   0  ...                    0
# 2                     0                   0  ...                    0
# 3                     0                   0  ...                    0
# 4                     0                   0  ...                    0
# ..                  ...                 ...  ...                  ...
# 166                   0                   0  ...                    0
# 167                   0                   0  ...                    0
# 168                   0                   0  ...                    0
# 169                   0                   0  ...                    0
# 170                   0                   0  ...                    0
#
#      fr_func_grp_41_salt  fr_func_grp_42_salt  fr_func_grp_43_salt  \
# 0                      0                    0                    0
# 1                      0                    0                    0
# 2                      0                    0                    0
# 3                      0                    0                    0
# 4                      0                    0                    0
# ..                   ...                  ...                  ...
# 166                    0                    0                    0
# 167                    0                    0                    0
# 168                    0                    0                    0
# 169                    0                    0                    0
# 170                    0                    0                    0
#
#      num_heavy_atom_salt  num_rot_bond_salt     mw_salt  conc_salt  \
# 0                     10                  2  186.939685        1.0
# 1                     10                  2  186.939685        1.0
# 2                     10                  2  186.939685        1.0
# 3                     10                  2  186.939685        1.0
# 4                     10                  2  186.939685        1.0
# ..                   ...                ...         ...        ...
# 166                   10                  2  186.939685        1.2
# 167                   10                  2  186.939685        1.0
# 168                   10                  2  186.939685        1.0
# 169                   10                  2  186.939685        3.0
# 170                   10                  2  186.939685        1.8
#
#      temperature  conductivity_log
# 0             80          0.333390
# 1             70          0.297290
# 2             60          0.254010
# 3             50          0.202220
# 4             40          0.137990
# ..           ...               ...
# 166           25          0.503791
# 167           25          0.474216
# 168           25         -0.585027
# 169           25         -0.356547
# 170           25         -0.221849
#
# [171 rows x 105 columns]

# %%
## predict on ood & check performance
pred_array = []
for i in range(1,6):
    print(i)
    filename = f'./lgbm_cond_strat2_fold_{i}.sav'
    loaded_model = pickle.load(open(filename, 'rb'))
    y_pred_ood = loaded_model.predict(X_ood_)
    pred_array.append(y_pred_ood)

y_l = x_l = np.linspace(-6, -0.5, 100)
y_pred_ood_avg = np.mean(pred_array, axis=0)
y_pred_ood_avg = np.ravel(y_pred_ood_avg)
y_pred_ood_std = np.std(pred_array, axis=0)
y_pred_ood_std = np.ravel(y_pred_ood_std)
rmse_ood = np.sqrt(mean_squared_error(y_ood, y_pred_ood_avg)); mae_ood = mean_absolute_error(y_ood, y_pred_ood_avg)
# r2_ood = r2_score(y_ood, y_pred_ood_avg)
print(f"Avg RMSE ood: {rmse_ood}, Avg MAE ood: {mae_ood}")
# Out:
# 1
# 2
# 3
# 4
# 5
# Avg RMSE ood: 0.5280011384796394, Avg MAE ood: 0.42394065931395664
