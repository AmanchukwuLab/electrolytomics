# %% [markdown]
# ## Noteboook to generate stratified-II splot

# %% [markdown]
# #### Dataset: ionic conductivity (For SL models)

# %% [markdown]
# **Common log already generated in stratified-split-2 directory**

# %% [markdown]
# **Created on February 13th, 2024**

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler
import os, sys, argparse, pickle, random

# %%
# %%bash
# pwd
# ls -ltr
# Out:
# /Users/riteshk/Library/CloudStorage/Box-Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/lgbm_trials/stratified-split-2-cv_2
# total 1464
# -rw-r--r--  1 riteshk  staff  342499 Feb 13 19:26 train_qsar_stratII_cond.csv
# -rw-------@ 1 riteshk  staff  297575 Feb 13 19:26 cond_lgbm_strat2.ipynb
# -rw-------@ 1 riteshk  staff  104320 Feb 13 19:28 split_dataset_strat2_cond_sl.ipynb.ipynb

# %%
df_train_rand = pd.read_csv('../random-split/train_qsar_rand_cond.csv')
df_val_rand = pd.read_csv('../random-split/val_qsar_rand_cond.csv')
df_test_rand = pd.read_csv('../random-split/test_qsar_rand_cond.csv')
df_train_rand
# Out:
#                                            solv_comb_sm  \
# 0                                   CCOCCOCCF.O=C1OCCO1
# 1                                          CC1COC(=O)O1
# 2                              CC1COC(=O)O1.CCOC(=O)OCC
# 3                             COCCOC.COCCOCC(F)(F)C(F)F
# 4                                          CC1COC(=O)O1
# ...                                                 ...
# 8161  FC(F)C(F)(F)COC(F)(F)C(F)F.COC(=O)OCC(F)(F)F.O...
# 8162                               CCCCCCCCCC1COC(=O)O1
# 8163                                    COCCOCCOCCOCCOC
# 8164                           CC1COC(=O)O1.CCOC(=O)OCC
# 8165                            O=S1(=O)CCCC1.COCCOCCOC
#
#                                          salt_smiles  fr_func_grp_1_solv  \
# 0                           [Li+].F[P-](F)(F)(F)(F)F                   0
# 1                           [Li+].F[P-](F)(F)(F)(F)F                   0
# 2                           [Li+].F[P-](F)(F)(F)(F)F                   0
# 3     [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 4                           [Li+].F[P-](F)(F)(F)(F)F                   0
# ...                                              ...                 ...
# 8161                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 8162                   [Li+].C(F)(F)(F)S(=O)(=O)[O-]                   0
# 8163  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 8164                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 8165                       [Li+].F[As-](F)(F)(F)(F)F                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8161                   0                   0                   0
# 8162                   0                   0                   0
# 8163                   0                   0                   0
# 8164                   0                   0                   0
# 8165                   0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 8161                   0                   0                   0
# 8162                   0                   0                   0
# 8163                   0                   0                   0
# 8164                   0                   0                   0
# 8165                   0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_40_salt  fr_func_grp_41_salt  \
# 0                      0  ...                    0                    0
# 1                      0  ...                    0                    0
# 2                      0  ...                    0                    0
# 3                      0  ...                    0                    0
# 4                      0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 8161                   0  ...                    0                    0
# 8162                   0  ...                    0                    0
# 8163                   0  ...                    0                    0
# 8164                   0  ...                    0                    0
# 8165                   0  ...                    0                    0
#
#       fr_func_grp_42_salt  fr_func_grp_43_salt  num_heavy_atom_salt  \
# 0                       0                    0                    8
# 1                       0                    0                    8
# 2                       0                    0                    8
# 3                       0                    0                   16
# 4                       0                    0                    8
# ...                   ...                  ...                  ...
# 8161                    0                    0                    8
# 8162                    0                    0                    9
# 8163                    0                    0                   16
# 8164                    0                    0                    8
# 8165                    0                    0                    8
#
#       num_rot_bond_salt     mw_salt  conc_salt  temperature  conductivity_log
# 0                     0  144.964181     1.0000         15.0          0.819544
# 1                     0  144.964181     0.4800         -0.2          0.468166
# 2                     0  144.964181     0.4800        -29.5          0.157312
# 3                     2  279.917842     1.0000         40.0          0.806858
# 4                     0  144.964181     1.7000         25.0          0.707570
# ...                 ...         ...        ...          ...               ...
# 8161                  0  144.964181     1.2000         25.0          0.477121
# 8162                  0  148.952573     0.3000         25.0         -1.315155
# 8163                  2  279.917842     1.2700         30.0          0.513458
# 8164                  0  144.964181     0.6524         59.0          1.092370
# 8165                  0  188.912016     1.0000         40.0          0.899273
#
# [8166 rows x 106 columns]

# %%
df = pd.concat([df_train_rand, df_val_rand, df_test_rand], ignore_index=True)
df
# Out:
#                           solv_comb_sm  \
# 0                  CCOCCOCCF.O=C1OCCO1
# 1                         CC1COC(=O)O1
# 2             CC1COC(=O)O1.CCOC(=O)OCC
# 3            COCCOC.COCCOCC(F)(F)C(F)F
# 4                         CC1COC(=O)O1
# ...                                ...
# 10191  CC1CCCO1.O=C1OCCO1.CC1COC(=O)O1
# 10192           C1COB(OCCOB2OCCCO2)OC1
# 10193         CC1COC(=O)O1.CCOC(=O)OCC
# 10194                  COCCOCCOCCOCCOC
# 10195              CC1COC(=O)O1.COCCOC
#
#                                           salt_smiles  fr_func_grp_1_solv  \
# 0                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 1                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 2                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 3      [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 4                            [Li+].F[P-](F)(F)(F)(F)F                   0
# ...                                               ...                 ...
# 10191                       [Li+].F[As-](F)(F)(F)(F)F                   0
# 10192                          [Li+].[O-]Cl(=O)(=O)=O                   0
# 10193             CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F                   0
# 10194  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 10195                        [Li+].F[P-](F)(F)(F)(F)F                   0
#
#        fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 10191                   0                   0                   0
# 10192                   0                   0                   2
# 10193                   0                   0                   0
# 10194                   0                   0                   0
# 10195                   0                   0                   0
#
#        fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 10191                   0                   0                   0
# 10192                   0                   0                   0
# 10193                   0                   0                   0
# 10194                   0                   0                   0
# 10195                   0                   0                   0
#
#        fr_func_grp_8_solv  ...  fr_func_grp_40_salt  fr_func_grp_41_salt  \
# 0                       0  ...                    0                    0
# 1                       0  ...                    0                    0
# 2                       0  ...                    0                    0
# 3                       0  ...                    0                    0
# 4                       0  ...                    0                    0
# ...                   ...  ...                  ...                  ...
# 10191                   0  ...                    0                    0
# 10192                   0  ...                    0                    0
# 10193                   0  ...                    0                    0
# 10194                   0  ...                    0                    0
# 10195                   0  ...                    0                    0
#
#        fr_func_grp_42_salt  fr_func_grp_43_salt  num_heavy_atom_salt  \
# 0                        0                    0                    8
# 1                        0                    0                    8
# 2                        0                    0                    8
# 3                        0                    0                   16
# 4                        0                    0                    8
# ...                    ...                  ...                  ...
# 10191                    0                    0                    8
# 10192                    0                    0                    6
# 10193                    0                    1                   16
# 10194                    0                    0                   16
# 10195                    0                    0                    8
#
#        num_rot_bond_salt     mw_salt  conc_salt  temperature  conductivity_log
# 0                      0  144.964181   1.000000        15.00          0.819544
# 1                      0  144.964181   0.480000        -0.20          0.468166
# 2                      0  144.964181   0.480000       -29.50          0.157312
# 3                      2  279.917842   1.000000        40.00          0.806858
# 4                      0  144.964181   1.700000        25.00          0.707570
# ...                  ...         ...        ...          ...               ...
# 10191                  0  188.912016   1.000000       -30.00          0.550228
# 10192                  0   98.949060   1.000000        30.00         -3.790485
# 10193                  0  144.964181   1.160764        10.00          0.920819
# 10194                  2  279.917842   2.347062        50.04          0.468790
# 10195                  0  144.964181   0.300000        25.00          0.967402
#
# [10196 rows x 106 columns]

# %%
# df_train_add = pd.read_csv('./train_strat_add.csv')
# df_val_add = pd.read_csv('./val_strat_add.csv')
# df_test_add = pd.read_csv('./test_strat_add.csv')
# df_add = pd.concat([df_train_add, df_val_add, df_test_add], ignore_index=True)
# df_add
# Out:
#        solv_ratio_1  solv_ratio_2  solv_ratio_3  solv_ratio_4  mol_wt_solv_1  \
# 0               0.3           0.7           0.0           0.0     102.031694
# 1               0.8           0.2           0.0           0.0     102.031694
# 2               0.8           0.2           0.0           0.0     102.031694
# 3               0.6           0.4           0.0           0.0     102.031694
# 4               0.5           0.5           0.0           0.0      90.068080
# ...             ...           ...           ...           ...            ...
# 10191           0.7           0.3           0.0           0.0     102.031694
# 10192           0.4           0.6           0.0           0.0     102.031694
# 10193           0.3           0.7           0.0           0.0      88.016044
# 10194           0.5           0.5           0.0           0.0     108.068748
# 10195           0.5           0.5           0.0           0.0     102.031694
#
#        mol_wt_solv_2  mol_wt_solv_3  mol_wt_solv_4  mol_wt_salt  conc_salt  \
# 0          88.016044            0.0            0.0   275.123756   0.190698
# 1         118.062994            0.0            0.0   217.162493   1.304688
# 2         118.062994            0.0            0.0   217.162493   1.154882
# 3         118.062994            0.0            0.0   193.984627   0.240000
# 4          86.036779            0.0            0.0   151.980186   0.081500
# ...              ...            ...            ...          ...        ...
# 10191     118.062994            0.0            0.0   151.980186   0.565800
# 10192     118.062994            0.0            0.0   217.162493   0.074903
# 10193      86.036779            0.0            0.0   194.012536   1.000000
# 10194      88.016044            0.0            0.0   286.933298   1.000000
# 10195     118.062994            0.0            0.0   193.984627   0.390000
#
#        temperature
# 0           60.000
# 1           60.000
# 2           10.000
# 3           29.400
# 4           25.000
# ...            ...
# 10191       39.300
# 10192        0.000
# 10193      -30.352
# 10194      -10.000
# 10195       19.500
#
# [10196 rows x 11 columns]

# %%
# bins = [-7, -6, -5, -4, -3, -2, -1, 0, 1, 2]
bins = [-7, -4, -3, -2, -1, 0, 1, 2]
labels = np.arange(0, len(bins)-1, 1)
df['conductivity_log_bin'] = pd.cut(df['conductivity_log'], bins=bins, labels=labels)
df['conductivity_log_bin'].value_counts()
# Out:
# conductivity_log_bin
# 5    6516
# 4    1631
# 6    1435
# 3     496
# 2      82
# 1      29
# 0       7
# Name: count, dtype: int64

# %%
print(df['conductivity_log'].max())
print(df['conductivity_log'].min())
# Out:
# 1.8247114435787173
# -6.747146968539926

# %%
df_rest, df_test, y_rest, y_test = train_test_split(df, df['conductivity_log'], test_size=0.1, random_state=0, stratify=df['conductivity_log_bin'])
df_test
# Out:
#                   solv_comb_sm  \
# 1739    CC1COC(=O)O1.O=C1OCCO1
# 2150    CC1COC(=O)O1.O=C1OCCO1
# 8584  CC1COC(=O)O1.CCOC(=O)OCC
# 7642    CC1COC(=O)O1.O=C1OCCO1
# 9906                   C1CCOC1
# ...                        ...
# 1084  CC1COC(=O)O1.CCOC(=O)OCC
# 4441  CC1COC(=O)O1.CCOC(=O)OCC
# 7978       O=C1OCCO1.O=C1CCCO1
# 4515    C(CCC#N)CC#N.O=C1OCCO1
# 9544  CC1COC(=O)O1.CCOC(=O)OCC
#
#                                          salt_smiles  fr_func_grp_1_solv  \
# 1739                 [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 2150                 [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 8584                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 7642             CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F                   0
# 9906                            [Li+].[B-](F)(F)(F)F                   0
# ...                                              ...                 ...
# 1084                        [Li+].F[P-](F)(F)(F)(F)F                   0
# 4441                 [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 7978              [Li+].[B-](C(C(F)(F)F)(F)F)(F)(F)F                   0
# 4515  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# 9544        [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 1739                   0                   0                   0
# 2150                   0                   0                   0
# 8584                   0                   0                   0
# 7642                   0                   0                   0
# 9906                   0                   0                   0
# ...                  ...                 ...                 ...
# 1084                   0                   0                   0
# 4441                   0                   0                   0
# 7978                   0                   0                   0
# 4515                   0                   0                   0
# 9544                   0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 1739                   0                   0                   0
# 2150                   0                   0                   0
# 8584                   0                   0                   0
# 7642                   0                   0                   0
# 9906                   0                   0                   0
# ...                  ...                 ...                 ...
# 1084                   0                   0                   0
# 4441                   0                   0                   0
# 7978                   0                   0                   0
# 4515                   0                   0                   0
# 9544                   0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_41_salt  fr_func_grp_42_salt  \
# 1739                   0  ...                    0                    0
# 2150                   0  ...                    0                    0
# 8584                   0  ...                    0                    0
# 7642                   0  ...                    0                    0
# 9906                   0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 1084                   0  ...                    0                    0
# 4441                   0  ...                    0                    0
# 7978                   0  ...                    0                    0
# 4515                   0  ...                    0                    0
# 9544                   0  ...                    0                    0
#
#       fr_func_grp_43_salt  num_heavy_atom_salt  num_rot_bond_salt     mw_salt  \
# 1739                    1                   14                  0   87.003467
# 2150                    1                   14                  0   87.003467
# 8584                    0                    8                  0  144.964181
# 7642                    1                   16                  0  144.964181
# 9906                    0                    6                  0   87.003467
# ...                   ...                  ...                ...         ...
# 1084                    0                    8                  0  144.964181
# 4441                    1                   14                  0   87.003467
# 7978                    0                   12                  1  186.997080
# 4515                    0                   16                  2  279.917842
# 9544                    0                   14                  0  186.969171
#
#       conc_salt  temperature  conductivity_log  conductivity_log_bin
# 1739   1.139535       60.000          1.455510                     6
# 2150   0.500000       30.000          1.042752                     6
# 8584   0.897900       49.200          0.965672                     5
# 7642   0.511628        0.000          0.732234                     5
# 9906   0.046877       30.000         -0.670613                     4
# ...         ...          ...               ...                   ...
# 1084   0.565800       39.300          0.956553                     5
# 4441   0.074903        0.000          0.018261                     5
# 7978   1.000000      -30.352          0.355643                     5
# 4515   1.000000      -10.000          0.000000                     4
# 9544   0.390000       19.500          0.595540                     5
#
# [1020 rows x 107 columns]

# %%
req_len = len(df_test)
rat = req_len/len(df_rest)
df_train, df_val, y_train, y_val = train_test_split(df_rest, y_rest, test_size=rat, random_state=0, stratify=df_rest['conductivity_log_bin'])
df_val
# Out:
#                                    solv_comb_sm  \
# 539   C(C(C(F)F)(F)F)OC(C(F)F)(F)F.FC1COC(=O)O1
# 4614                   CC1COC(=O)O1.CCOC(=O)OCC
# 9561                   CC1COC(=O)O1.C1COC(=O)O1
# 4074                   CC1COC(=O)O1.CCOC(=O)OCC
# 1175                          C1(C(OC(=O)O1)F)F
# ...                                         ...
# 6771                   CC1COC(=O)O1.CCOC(=O)OCC
# 9526                                 C(CC#N)C#N
# 2342        CC1CCCO1.COCCOC.O=C1OCCO1.O=C1OCCO1
# 232                                CCOC(=O)OCCF
# 644                                CC1COC(=O)O1
#
#                                             salt_smiles  fr_func_grp_1_solv  \
# 539                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 4614           [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 9561           [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 4074                           [Li+].F[P-](F)(F)(F)(F)F                   0
# 1175     [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F                   0
# ...                                                 ...                 ...
# 6771           [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 9526  C[N+](C)(C)C.C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C...                   0
# 2342                          [Li+].F[As-](F)(F)(F)(F)F                   0
# 232                            [Li+].F[P-](F)(F)(F)(F)F                   0
# 644                            [Li+].F[P-](F)(F)(F)(F)F                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 539                    0                   0                   0
# 4614                   0                   0                   0
# 9561                   0                   0                   0
# 4074                   0                   0                   0
# 1175                   0                   0                   0
# ...                  ...                 ...                 ...
# 6771                   0                   0                   0
# 9526                   0                   0                   0
# 2342                   0                   0                   0
# 232                    0                   0                   0
# 644                    0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 539                    0                   0                   0
# 4614                   0                   0                   0
# 9561                   0                   0                   0
# 4074                   0                   0                   0
# 1175                   0                   0                   0
# ...                  ...                 ...                 ...
# 6771                   0                   0                   0
# 9526                   0                   0                   0
# 2342                   0                   0                   0
# 232                    0                   0                   0
# 644                    0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_41_salt  fr_func_grp_42_salt  \
# 539                    0  ...                    0                    0
# 4614                   0  ...                    0                    0
# 9561                   0  ...                    0                    0
# 4074                   0  ...                    0                    0
# 1175                   0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 6771                   0  ...                    0                    0
# 9526                   0  ...                    0                    0
# 2342                   0  ...                    0                    0
# 232                    0  ...                    0                    0
# 644                    0  ...                    0                    0
#
#       fr_func_grp_43_salt  num_heavy_atom_salt  num_rot_bond_salt     mw_salt  \
# 539                     0                    8                  0  144.964181
# 4614                    0                   14                  0  186.969171
# 9561                    0                   14                  0  186.969171
# 4074                    0                    8                  0  144.964181
# 1175                    0                   16                  2  279.917842
# ...                   ...                  ...                ...         ...
# 6771                    0                   14                  0  186.969171
# 9526                    1                   20                  2  279.917842
# 2342                    0                    8                  0  188.912016
# 232                     0                    8                  0  144.964181
# 644                     0                    8                  0  144.964181
#
#       conc_salt  temperature  conductivity_log  conductivity_log_bin
# 539    1.000000    25.000000          0.004321                     5
# 4614   0.350000    59.000000          0.846329                     5
# 9561   0.350000    19.500000          0.463270                     5
# 4074   0.670000   -10.000000          0.489676                     5
# 1175   0.750000    25.000000          0.255273                     5
# ...         ...          ...               ...                   ...
# 6771   0.310000    29.400000          0.653011                     5
# 9526   0.533046    19.989551          0.289963                     5
# 2342   1.000000   -20.000000          0.789581                     5
# 232    1.000000    19.596000          0.316390                     5
# 644    2.330000   -19.800000         -1.309981                     3
#
# [1020 rows x 107 columns]

# %%
df_train
# Out:
#                            solv_comb_sm  \
# 1134             CC1COC(=O)O1.O=C1OCCO1
# 6589           CC1COC(=O)O1.CCOC(=O)OCC
# 9285           CC1COC(=O)O1.CCOC(=O)OCC
# 932            CC1COC(=O)O1.CCOC(=O)OCC
# 6318                   COCCOC.O=C1CCCO1
# ...                                 ...
# 8453           CC1COC(=O)O1.CCOC(=O)OCC
# 3832                       CC1COC(=O)O1
# 6512                       CC1COC(=O)O1
# 6580  CC1COC(=O)O1.CCOC(=O)OC.COC(=O)OC
# 5581                       CCOC(=O)OCCF
#
#                                        salt_smiles  fr_func_grp_1_solv  \
# 1134           CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F                   0
# 6589               [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 9285               [B-](F)(F)(F)F.CC[N+](CC)(CC)CC                   0
# 932       [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 6318                      [Li+].F[P-](F)(F)(F)(F)F                   0
# ...                                            ...                 ...
# 8453                      [Li+].F[P-](F)(F)(F)(F)F                   0
# 3832  [Li+].F[P-](F)(F)(F)(F)F.COCCOCCOC.COCCOCCOC                   0
# 6512                          [Li+].[B-](F)(F)(F)F                   0
# 6580      [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2                   0
# 5581                      [Li+].F[P-](F)(F)(F)(F)F                   0
#
#       fr_func_grp_2_solv  fr_func_grp_3_solv  fr_func_grp_4_solv  \
# 1134                   0                   0                   0
# 6589                   0                   0                   0
# 9285                   0                   0                   0
# 932                    0                   0                   0
# 6318                   0                   0                   0
# ...                  ...                 ...                 ...
# 8453                   0                   0                   0
# 3832                   0                   0                   0
# 6512                   0                   0                   0
# 6580                   0                   0                   0
# 5581                   0                   0                   0
#
#       fr_func_grp_5_solv  fr_func_grp_6_solv  fr_func_grp_7_solv  \
# 1134                   0                   0                   0
# 6589                   0                   0                   0
# 9285                   0                   0                   0
# 932                    0                   0                   0
# 6318                   0                   0                   0
# ...                  ...                 ...                 ...
# 8453                   0                   0                   0
# 3832                   0                   0                   0
# 6512                   0                   0                   0
# 6580                   0                   0                   0
# 5581                   0                   0                   0
#
#       fr_func_grp_8_solv  ...  fr_func_grp_41_salt  fr_func_grp_42_salt  \
# 1134                   0  ...                    0                    0
# 6589                   0  ...                    0                    0
# 9285                   0  ...                    0                    0
# 932                    0  ...                    0                    0
# 6318                   0  ...                    0                    0
# ...                  ...  ...                  ...                  ...
# 8453                   0  ...                    0                    0
# 3832                   0  ...                    0                    0
# 6512                   0  ...                    0                    0
# 6580                   0  ...                    0                    0
# 5581                   0  ...                    0                    0
#
#       fr_func_grp_43_salt  num_heavy_atom_salt  num_rot_bond_salt     mw_salt  \
# 1134                    1                   16                  0  144.964181
# 6589                    1                   14                  0   87.003467
# 9285                    1                   14                  0   87.003467
# 932                     0                   14                  0  186.969171
# 6318                    0                    8                  0  144.964181
# ...                   ...                  ...                ...         ...
# 8453                    0                    8                  0  144.964181
# 3832                    0                   26                  0  144.964181
# 6512                    0                    6                  0   87.003467
# 6580                    0                   14                  0  186.969171
# 5581                    0                    8                  0  144.964181
#
#       conc_salt  temperature  conductivity_log  conductivity_log_bin
# 1134   0.190698       60.000          0.660961                     5
# 6589   1.304688       60.000          1.379852                     6
# 9285   1.154882       10.000          0.982081                     5
# 932    0.240000       29.400          0.598077                     5
# 6318   0.081500       25.000          0.504063                     5
# ...         ...          ...               ...                   ...
# 8453   1.230000       49.200          0.990060                     5
# 3832   0.273190       25.000          0.627673                     5
# 6512   0.000947       25.000         -1.582382                     3
# 6580   0.800000      -20.000          0.158661                     5
# 5581   1.000000        9.855          0.188084                     5
#
# [8156 rows x 107 columns]

# %%
df_train['conductivity_log_bin'].value_counts()
# Out:
# conductivity_log_bin
# 5    5212
# 4    1305
# 6    1148
# 3     397
# 2      66
# 1      23
# 0       5
# Name: count, dtype: int64

# %%
# zero_columns = df.columns[(df == 0).all()]
# zero_columns
# Out:
# Index(['fr_func_grp_20_salt'], dtype='object')

# %%
df_train.to_csv('./train_qsar_stratII_cond.csv', index=False)
df_val.to_csv('./val_qsar_stratII_cond.csv', index=False)
df_test.to_csv('./test_qsar_stratII_cond.csv', index=False)

# %%
# random_state = 0
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
# stratify_labels = df_train['conductivity_log_bin']
# curr_dir = os.getcwd()

# fold = 0   
# # Loop over each fold
# rmse_val = []; rmse_train = []
# for train_index, val_index in skf.split(df_train, stratify_labels):
#     print("Fold {}".format(fold))
#     fold_path = curr_dir + '/relu_epoch100_f5_e3_strat_cv_comm_1/' + 'fold_' + str(fold) ## change the directory accordingly
#     os.makedirs(fold_path, exist_ok=True)
#     # Split the data
#     df_train_fold, df_val_fold = df_train.iloc[train_index], df_train.iloc[val_index]
#     df_train_add_fold, df_val_add_fold = df_train_add.iloc[train_index], df_train_add.iloc[val_index]
#     df_train_comb_fold, df_val_comb_fold = df_train.iloc[train_index], df_train.iloc[val_index]

#     file_1 = fold_path + '/train_full.csv'; file_2 = fold_path + '/val_full.csv'
#     # file_1 = 'train_full.csv'; file_2 = 'val_full.csv'
#     file_3 = fold_path + '/train_features.csv'; file_4 = fold_path + '/val_features.csv'
#     # file_3 = 'train_features.csv'; file_4 = 'val_features.csv'
#     # os.chdir(fold_path)
#     print(fold_path)
#     df_train_comb_fold.to_csv(file_1, index=False); df_val_comb_fold.to_csv(file_2, index=False)
#     df_train_add_fold.to_csv(file_3, index=False); df_val_add_fold.to_csv(file_4, index=False)
#     # print(train_index)
#     ## copy val_strat_comv.csv and val_strat_add.csv to the fold directory
#     os.system('cp ./val_strat_comm.csv ' + fold_path + '/test_full.csv')
#     os.system('cp ./val_strat_add.csv ' + fold_path + '/test_features.csv')
#     fold += 1
#     # os.chdir(curr_dir)
# Out:
# Fold 0
# /home/ritesh/ExpanDrive/Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/stratified-split-2-cv/relu_epoch100_f5_e3_strat_cv_comm_1/fold_0
# Fold 1
# /home/ritesh/ExpanDrive/Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/stratified-split-2-cv/relu_epoch100_f5_e3_strat_cv_comm_1/fold_1
# Fold 2
# /home/ritesh/ExpanDrive/Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/stratified-split-2-cv/relu_epoch100_f5_e3_strat_cv_comm_1/fold_2
# Fold 3
# /home/ritesh/ExpanDrive/Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/stratified-split-2-cv/relu_epoch100_f5_e3_strat_cv_comm_1/fold_3
# Fold 4
# /home/ritesh/ExpanDrive/Box/Research-postdoc/liquid-electrolyte-ML/Science-rev-1/ionic-conductivity_2.1/dataset_v2.0/common-log-output/stratified-split-2-cv/relu_epoch100_f5_e3_strat_cv_comm_1/fold_4
